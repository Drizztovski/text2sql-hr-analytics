# %% [markdown]
# # Session 14: Project 2 — HR Analytics with AI-Assisted SQL
#
# **Data Analytics in the Age of AI Bootcamp**
#
# ---
#
# ## Project Overview
#
# **Business Scenario:** You are an HR data analyst at TechCorp, a mid-size technology company with 120 employees across 8 departments. Leadership has asked you to build an **AI-powered analytics tool** that lets anyone ask business questions in plain English and get back SQL queries, data results, and visualizations — no SQL knowledge required.
#
# ### What You Will Build
#
# | Part | What You Build |
# |------|---------------|
# | **Part 1** | Load & explore an 8-table HR database |
# | **Part 2** | Complete the Text-to-SQL engine (schema builder, validator, generator) |
# | **Part 3** | Answer 12 business questions using your engine |
# | **Part 4** | Build an LLM-powered auto-visualizer |
# | **Part 5** | Prompt engineering — refine questions for better SQL |
# | **Part 6** | Build a Streamlit web app with chat interface |
# | **Part 7** | Reflection & analysis |
#
#
# ### Files Provided
#
# | File | Description |
# |------|-------------|
# | `data/*.csv` | 8 CSV files (departments, job_titles, employees, salary_history, projects, project_assignments, performance_reviews, training_records) — 1,300+ rows total |
# | `schema/SCHEMA.md` | Full schema documentation with ER diagram |
# | `schema/er_diagram.mermaid` | Mermaid ER diagram (render at mermaid.live) |
# | `db_utils.py` | **PROVIDED** — Database loading and schema inspection utilities |
# | `text2sql_engine.py` | **YOUR WORK** — Text-to-SQL engine with 17 TODOs to complete |
# | `text2sql_app.py` | **YOUR WORK** — Streamlit app with TODOs |
# | `solution/` | Reference solutions (try on your own first!) |
#
# ### Prerequisites
# Sessions 11-13 (SQL, Python-SQL Integration, Streamlit Basics)

# %% [markdown]
# ---
#
# # Part 1: Project Setup — Loading the HR Database
#
# TechCorp's HR data lives in 8 CSV files. We will load them all into a SQLite in-memory database so we can query them with SQL.

# %%
# Core imports
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Our helper modules (db_utils is provided, text2sql_engine has your TODOs)
from db_utils import load_csv_to_db, get_schema_info, execute_query, list_tables, get_table_info, get_foreign_keys

print("All imports successful!")
# Out:
# All imports successful!

# %%
# Load all 8 CSV files into SQLite
conn = load_csv_to_db("data/")

# Show all tables and their row counts
print("\nDatabase Overview:")
print(list_tables(conn))
# Out:
# Loading 8 CSV files into database...
#   ✓ departments: 8 rows, 6 columns
#   ✓ employees: 120 rows, 13 columns
#   ✓ job_titles: 38 rows, 6 columns
#   ✓ performance_reviews: 293 rows, 7 columns
#   ✓ project_assignments: 138 rows, 5 columns
#   ✓ projects: 20 rows, 8 columns
#   ✓ salary_history: 308 rows, 6 columns
#   ✓ training_records: 418 rows, 9 columns
#
# Database ready! 8 tables loaded.
#
# Database Overview:
#                  table  rows
# 0          departments     8
# 1            employees   120
# 2           job_titles    38
# 3  performance_reviews   293
# 4  project_assignments   138
# 5             projects    20
# 6       salary_history   308
# 7     training_records   418

# %% [markdown]
# ## Explore the Schema
#
# Before writing any queries, we need to understand the database. Open `schema/SCHEMA.md` for the full documentation and ER diagram.
#
# Let's explore programmatically too:

# %%
# Display full schema with column types and sample data
schema = get_schema_info(conn)
print(schema)
# Out:
# ================================================================================
# DATABASE SCHEMA - TechCorp HR Analytics
# ================================================================================
#
# TABLE: departments (8 rows)
# --------------------------------------------------------------------------------
#   dept_id                   INTEGER    (nullable)
#   dept_name                 TEXT       (nullable)
#   location                  TEXT       (nullable)
#   annual_budget             INTEGER    (nullable)
#   division                  TEXT       (nullable)
#   established_date          TEXT       (nullable)
#
# TABLE: employees (120 rows)
# --------------------------------------------------------------------------------
#   emp_id                    INTEGER    (nullable)
#   first_name                TEXT       (nullable)
#   last_name                 TEXT       (nullable)
#   email                     TEXT       (nullable)
#   dept_id                   INTEGER    (nullable)
#   title_id                  INTEGER    (nullable)
#   salary                    INTEGER    (nullable)
#   hire_date                 TEXT       (nullable)
#   gender                    TEXT       (nullable)
#   employment_status         TEXT       (nullable)
#   termination_date          TEXT       (nullable)
#   work_mode                 TEXT       (nullable)
#   manager_id                REAL       (nullable)
#
# TABLE: job_titles (38 rows)
# --------------------------------------------------------------------------------
#   title_id                  INTEGER    (nullable)
#   title                     TEXT       (nullable)
#   dept_id                   INTEGER    (nullable)
#   level                     TEXT       (nullable)
#   min_salary                INTEGER    (nullable)
#   max_salary                INTEGER    (nullable)
#
# TABLE: performance_reviews (293 rows)
# --------------------------------------------------------------------------------
#   review_id                 INTEGER    (nullable)
#   emp_id                    INTEGER    (nullable)
#   review_year               INTEGER    (nullable)
#   rating                    INTEGER    (nullable)
#   goals_met_pct             INTEGER    (nullable)
#   reviewer_comments         TEXT       (nullable)
#   review_date               TEXT       (nullable)
#
# TABLE: project_assignments (138 rows)
# --------------------------------------------------------------------------------
#   assignment_id             INTEGER    (nullable)
#   project_id                INTEGER    (nullable)
#   emp_id                    INTEGER    (nullable)
#   role                      TEXT       (nullable)
#   hours_per_week            INTEGER    (nullable)
#
# TABLE: projects (20 rows)
# --------------------------------------------------------------------------------
#   project_id                INTEGER    (nullable)
#   project_name              TEXT       (nullable)
#   dept_id                   INTEGER    (nullable)
#   budget                    INTEGER    (nullable)
#   start_date                TEXT       (nullable)
#   end_date                  TEXT       (nullable)
#   status                    TEXT       (nullable)
#   priority                  TEXT       (nullable)
#
# TABLE: salary_history (308 rows)
# --------------------------------------------------------------------------------
#   history_id                INTEGER    (nullable)
#   emp_id                    INTEGER    (nullable)
#   old_salary                REAL       (nullable)
#   new_salary                REAL       (nullable)
#   effective_date            TEXT       (nullable)
#   reason                    TEXT       (nullable)
#
# TABLE: training_records (418 rows)
# --------------------------------------------------------------------------------
#   record_id                 INTEGER    (nullable)
#   emp_id                    INTEGER    (nullable)
#   course_name               TEXT       (nullable)
#   category                  TEXT       (nullable)
#   hours                     INTEGER    (nullable)
#   enrollment_date           TEXT       (nullable)
#   completion_date           TEXT       (nullable)
#   status                    TEXT       (nullable)
#   score                     REAL       (nullable)
#
# ================================================================================
# FOREIGN KEY RELATIONSHIPS
# ================================================================================
#
# employees.dept_id → departments.dept_id
#   Type: Many-to-One
#   Note: Many employees belong to one department
#
# employees.title_id → job_titles.title_id
#   Type: Many-to-One
#   Note: Many employees share the same job title
#
# employees.manager_id → employees.emp_id
#   Type: Self-Reference
#   Note: Employees report to other employees (manager hierarchy)
#
# salary_history.emp_id → employees.emp_id
#   Type: Many-to-One
#   Note: Each employee has multiple salary history records
#
# performance_reviews.emp_id → employees.emp_id
#   Type: Many-to-One
#   Note: Each employee has multiple performance reviews
#
# performance_reviews.reviewer_id → employees.emp_id
#   Type: Many-to-One
#   Note: Reviews are conducted by employees (usually managers)
#
# training_records.emp_id → employees.emp_id
#   Type: Many-to-One
#   Note: Each employee has multiple training records
#
# projects.dept_id → departments.dept_id
#   Type: Many-to-One
#   Note: Each project belongs to one department
#
# project_assignments.project_id → projects.project_id
#   Type: Many-to-Many
#   Note: Junction table: projects have many employees
#
# project_assignments.emp_id → employees.emp_id
#   Type: Many-to-Many
#   Note: Junction table: employees work on many projects
#
# ================================================================================
# SAMPLE DATA (First 3 rows per table)
# ================================================================================
#
# departments:
#  dept_id   dept_name      location  annual_budget   division established_date
#        1 Engineering San Francisco        3200000 Technology       2015-01-15
#        2   Marketing      New York        1400000     Growth       2015-01-15
#        3       Sales       Chicago        2100000    Revenue       2015-01-15
#
# employees:
#  emp_id first_name last_name                        email  dept_id  title_id  salary  hire_date gender employment_status termination_date work_mode  manager_id
#       1      James   Sanchez   james.sanchez@techcorp.com        1         1  196000 2016-07-17      M            Active             None    Hybrid         NaN
#       2    Timothy    Wright  timothy.wright@techcorp.com        1         2  151000 2017-03-07      M            Active             None    Hybrid         1.0
#       3     Victor  Campbell victor.campbell@techcorp.com        1         2  168000 2020-12-07      M            Active             None    Remote         1.0
#
# job_titles:
#  title_id                    title  dept_id     level  min_salary  max_salary
#         1           VP Engineering        1 Executive      180000      220000
#         2      Engineering Manager        1   Manager      150000      180000
#         3 Senior Software Engineer        1    Senior      130000      160000
#
# performance_reviews:
#  review_id  emp_id  review_year  rating  goals_met_pct                                       reviewer_comments review_date
#          1       1         2022       4             72 Exceeds expectations. Strong contributor to team goals.  2022-12-15
#          2       1         2023       4             83 Exceeds expectations. Strong contributor to team goals.  2023-12-15
#          3       1         2024       4             74 Exceeds expectations. Strong contributor to team goals.  2024-12-15
#
# project_assignments:
#  assignment_id  project_id  emp_id        role  hours_per_week
#              1           1       9        Lead              40
#              2           1      13 Contributor              30
#              3           1      18 Coordinator              10
#
# projects:
#  project_id            project_name  dept_id  budget start_date   end_date      status priority
#           1     Mobile App Redesign        1  450000 2023-01-15 2023-11-30   Completed     High
#           2 Cloud Migration Phase 1        1  680000 2023-04-01 2024-03-31   Completed Critical
#           3 Cloud Migration Phase 2        1  520000 2024-04-01 2025-06-30 In Progress Critical
#
# salary_history:
#  history_id  emp_id  old_salary  new_salary effective_date        reason
#           1       1    136000.0    151000.0     2018-01-28     Promotion
#           2       1    151000.0    164000.0     2019-08-11   Role Change
#           3       1    164000.0    176000.0     2021-02-21 Annual Review
#
# training_records:
#  record_id  emp_id               course_name     category  hours enrollment_date completion_date    status  score
#          1       1        Financial Modeling    Technical     20      2023-02-20      2023-05-19 Completed   73.0
#          2       1      Communication Skills  Soft Skills      8      2022-11-15      2022-12-20 Completed   84.0
#          3       1 Project Management Basics Professional     12      2024-08-12      2024-10-17 Completed   73.0
#
# ================================================================================
# COMMON QUERY PATTERNS
# ================================================================================
#
# -- Get employee details with department and title names:
# SELECT e.*, d.dept_name, j.title_name
# FROM employees e
# JOIN departments d ON e.dept_id = d.dept_id
# JOIN job_titles j ON e.title_id = j.title_id
#
# -- Get manager hierarchy (self-join):
# SELECT e.first_name, e.last_name,
#        m.first_name AS manager_first, m.last_name AS manager_last
# FROM employees e
# LEFT JOIN employees m ON e.manager_id = m.emp_id
#
# -- Get project team members (many-to-many via junction table):
# SELECT p.project_name, e.first_name, e.last_name, pa.role_on_project
# FROM projects p
# JOIN project_assignments pa ON p.project_id = pa.project_id
# JOIN employees e ON pa.emp_id = e.emp_id
#
# -- Get salary history with employee names:
# SELECT e.first_name, e.last_name, sh.old_salary, sh.new_salary,
#        sh.change_date, sh.reason
# FROM salary_history sh
# JOIN employees e ON sh.emp_id = e.emp_id
#
# ================================================================================
# IMPORTANT NOTES
# ================================================================================
#
# 1. MANAGER HIERARCHY:
#    - employees.manager_id references employees.emp_id (self-join)
#    - C-level executives have NULL manager_id (no manager)
#    - Use LEFT JOIN when including managers to keep all employees
#
# 2. MANY-TO-MANY RELATIONSHIPS:
#    - employees ↔ projects via project_assignments junction table
#    - Always JOIN through project_assignments, never direct
#
# 3. CATEGORICAL COLUMNS - Valid Values:
#    - employees.status: 'Active', 'Inactive'
#    - employees.work_mode: 'Remote', 'Hybrid', 'On-site'
#    - employees.performance_band: 'Exceeds', 'Meets', 'Needs Improvement', 'Unsatisfactory'
#    - projects.status: 'Active', 'Completed', 'On Hold'
#    - salary_history.reason: 'Promotion', 'Annual Review', 'Merit Increase', 'Market Adjustment'
#    - performance_reviews.rating: 'Exceeds Expectations', 'Meets Expectations', 'Needs Improvement', 'Unsatisfactory'
#    - training_records.status: 'Completed', 'In Progress', 'Planned'
#    - job_titles.career_level: 'Entry', 'Mid', 'Senior', 'Lead', 'Manager', 'Director', 'VP', 'C-Level'
#
# 4. DATE FORMATS:
#    - All dates stored as TEXT in format: 'YYYY-MM-DD'
#    - Use SQLite date functions: date(), strftime(), julianday()
#
# 5. SALARY RANGES:
#    - employees.salary: $45,000 - $180,000 (current salary)
#    - job_titles.min_salary / max_salary: defines band for each role
#
# ================================================================================

# %%
# Show how tables connect to each other (foreign key relationships)
fk_df = get_foreign_keys(conn)
print("\nTable Relationships:")
print(fk_df.to_string(index=False))
# Out:
# No formal foreign keys defined (relationships exist by naming convention).
#
# Table Relationships:
#          from_table from_column    to_table  to_column
#           employees     dept_id departments    dept_id
#           employees    title_id  job_titles   title_id
#           employees  manager_id   employees     emp_id
#            projects     dept_id departments    dept_id
# project_assignments  project_id    projects project_id
# project_assignments      emp_id   employees     emp_id
#      salary_history      emp_id   employees     emp_id
# performance_reviews      emp_id   employees     emp_id
#    training_records      emp_id   employees     emp_id

# %%
# Peek at each table: first 3 rows
tables = ["departments", "job_titles", "employees", "salary_history",
          "projects", "project_assignments", "performance_reviews", "training_records"]

for table in tables:
    print(f"\n{'='*60}")
    print(f" {table.upper()} ")
    print(f"{'='*60}")
    df = execute_query(f"SELECT * FROM {table} LIMIT 3", conn)
    print(df.to_string(index=False))
    print(f"  ... {execute_query(f'SELECT COUNT(*) as total FROM {table}', conn)['total'][0]} rows total")
# Out:
# ============================================================
#  DEPARTMENTS
# ============================================================
#  dept_id   dept_name      location  annual_budget   division established_date
#        1 Engineering San Francisco        3200000 Technology       2015-01-15
#        2   Marketing      New York        1400000     Growth       2015-01-15
#        3       Sales       Chicago        2100000    Revenue       2015-01-15
#   ... 8 rows total
#
# ============================================================
#  JOB_TITLES
# ============================================================
#  title_id                    title  dept_id     level  min_salary  max_salary
#         1           VP Engineering        1 Executive      180000      220000
#         2      Engineering Manager        1   Manager      150000      180000
#         3 Senior Software Engineer        1    Senior      130000      160000
#   ... 38 rows total
#
# ============================================================
#  EMPLOYEES
# ============================================================
#  emp_id first_name last_name                        email  dept_id  title_id  salary  hire_date gender employment_status termination_date work_mode  manager_id
#       1      James   Sanchez   james.sanchez@techcorp.com        1         1  196000 2016-07-17      M            Active             None    Hybrid         NaN
#       2    Timothy    Wright  timothy.wright@techcorp.com        1         2  151000 2017-03-07      M            Active             None    Hybrid         1.0
#       3     Victor  Campbell victor.campbell@techcorp.com        1         2  168000 2020-12-07      M            Active             None    Remote         1.0
#   ... 120 rows total
#
# ============================================================
#  SALARY_HISTORY
# ============================================================
#  history_id  emp_id  old_salary  new_salary effective_date        reason
#           1       1    136000.0    151000.0     2018-01-28     Promotion
#           2       1    151000.0    164000.0     2019-08-11   Role Change
#           3       1    164000.0    176000.0     2021-02-21 Annual Review
#   ... 308 rows total
#
# ============================================================
#  PROJECTS
# ============================================================
#  project_id            project_name  dept_id  budget start_date   end_date      status priority
#           1     Mobile App Redesign        1  450000 2023-01-15 2023-11-30   Completed     High
#           2 Cloud Migration Phase 1        1  680000 2023-04-01 2024-03-31   Completed Critical
#           3 Cloud Migration Phase 2        1  520000 2024-04-01 2025-06-30 In Progress Critical
#   ... 20 rows total
#
# ============================================================
#  PROJECT_ASSIGNMENTS
# ============================================================
#  assignment_id  project_id  emp_id        role  hours_per_week
#              1           1       9        Lead              40
#              2           1      13 Contributor              30
#              3           1      18 Coordinator              10
#   ... 138 rows total
#
# ============================================================
#  PERFORMANCE_REVIEWS
# ============================================================
#  review_id  emp_id  review_year  rating  goals_met_pct                                       reviewer_comments review_date
#          1       1         2022       4             72 Exceeds expectations. Strong contributor to team goals.  2022-12-15
#          2       1         2023       4             83 Exceeds expectations. Strong contributor to team goals.  2023-12-15
#          3       1         2024       4             74 Exceeds expectations. Strong contributor to team goals.  2024-12-15
#   ... 293 rows total
#
# ============================================================
#  TRAINING_RECORDS
# ============================================================
#  record_id  emp_id               course_name     category  hours enrollment_date completion_date    status  score
#          1       1        Financial Modeling    Technical     20      2023-02-20      2023-05-19 Completed   73.0
#          2       1      Communication Skills  Soft Skills      8      2022-11-15      2022-12-20 Completed   84.0
#          3       1 Project Management Basics Professional     12      2024-08-12      2024-10-17 Completed   73.0
#   ... 418 rows total

# %% [markdown]
# ## Entity Relationship Diagram
#
# The database has these key relationships:
#
# ```
# departments ──┬── employees ──┬── salary_history
#               │               ├── performance_reviews
#               │               ├── training_records
#               │               └── project_assignments ── projects
#               │
#               ├── job_titles
#               └── projects
#
# employees.manager_id → employees.emp_id  (self-referencing hierarchy)
# ```
#
# **Key insight**: The `employees` table is the central hub. Most analytics questions will start there and JOIN to other tables.

# %%
# Warm-up queries to verify your understanding
# Run each and check the output makes sense

# How many active employees?
print("Active employees:")
print(execute_query("SELECT COUNT(*) as count FROM employees WHERE employment_status = 'Active'", conn))

# Departments and their employee counts
print("\nEmployees per department:")
print(execute_query("""
    SELECT d.dept_name, COUNT(e.emp_id) as emp_count
    FROM departments d
    LEFT JOIN employees e ON d.dept_id = e.dept_id
    GROUP BY d.dept_name
    ORDER BY emp_count DESC
""", conn))

# Average salary by career level
print("\nAverage salary by level:")
print(execute_query("""
    SELECT jt.level, ROUND(AVG(e.salary)) as avg_salary, COUNT(*) as count
    FROM employees e
    JOIN job_titles jt ON e.title_id = jt.title_id
    GROUP BY jt.level
    ORDER BY avg_salary DESC
""", conn))
# Out:
# Active employees:
#    count
# 0    107
#
# Employees per department:
#           dept_name  emp_count
# 0       Engineering         25
# 1             Sales         20
# 2      Data Science         19
# 3           Finance         13
# 4         Marketing         12
# 5  Customer Support         12
# 6           Product         11
# 7   Human Resources          8
#
# Average salary by level:
#        level  avg_salary  count
# 0  Executive    180000.0      7
# 1    Manager    131714.0     14
# 2     Senior    125375.0     24
# 3        Mid    101020.0     50
# 4      Entry     68680.0     25

# %% [markdown]
# > **Takeaway**: You now have a rich, 8-table HR database with 1,300+ rows. The data includes employee demographics, compensation history, project assignments, performance reviews, and training records — enough to answer real business questions.

# %% [markdown]
# ---
#
# # Part 2: Building the Text-to-SQL Engine
#
# Open `text2sql_engine.py` in your editor. It contains **17 TODOs** organized into 7 parts (A through G). You will implement the complete pipeline:
#
# ```
# Question (English) → Schema Context → AI Prompt → Generated SQL → Safety Check → Execute → Results
# ```
#
# Work through the TODOs in order. Each builds on the previous one.

# %% [markdown]
# ## Part 2A: Schema Context Builder (TODOs 1-3)
#
# The AI needs to understand your database to write correct SQL. The `get_schema_for_prompt()` function builds a text description of every table, column, and relationship.
#
# **Why it matters**: A vague schema description → vague SQL. A detailed schema → accurate SQL.
#
# Open `text2sql_engine.py` and complete TODOs 1, 2, and 3.

# %%
# Test your schema builder (after completing TODOs 1-3)
from text2sql_engine import get_schema_for_prompt

# Reload the module if you made changes
import importlib
import text2sql_engine
importlib.reload(text2sql_engine)
from text2sql_engine import get_schema_for_prompt

schema_text = get_schema_for_prompt(conn)
print(schema_text[:2000])  # Print first 2000 chars
print(f"\n... (total length: {len(schema_text)} characters)")

# Verify: Does it include CREATE TABLE statements?
assert "CREATE TABLE" in schema_text, "Missing CREATE TABLE statements (TODO 1)"
# Verify: Does it include sample data?
assert "Sample" in schema_text or "sample" in schema_text, "Missing sample data (TODO 2)"
# Verify: Does it include relationships?
assert "->" in schema_text or "RELATIONSHIP" in schema_text.upper(), "Missing relationships (TODO 3)"

print("\nAll schema tests passed!")
# Out:
# CREATE TABLE departments (
#     dept_id INTEGER,
#     dept_name TEXT,
#     location TEXT,
#     annual_budget INTEGER,
#     division TEXT,
#     established_date TEXT
# );
#
# -- Sample data from departments:
# --  dept_id   dept_name      location  annual_budget   division established_date
# --        1 Engineering San Francisco        3200000 Technology       2015-01-15
# --        2   Marketing      New York        1400000     Growth       2015-01-15
# --        3       Sales       Chicago        2100000    Revenue       2015-01-15
#
# CREATE TABLE employees (
#     emp_id INTEGER,
#     first_name TEXT,
#     last_name TEXT,
#     email TEXT,
#     dept_id INTEGER,
#     title_id INTEGER,
#     salary INTEGER,
#     hire_date TEXT,
#     gender TEXT,
#     employment_status TEXT,
#     termination_date TEXT,
#     work_mode TEXT,
#     manager_id REAL
# );
#
# -- Sample data from employees:
# --  emp_id first_name last_name                        email  dept_id  title_id  salary  hire_date gender employment_status termination_date work_mode  manager_id
# --       1      James   Sanchez   james.sanchez@techcorp.com        1         1  196000 2016-07-17      M            Active             None    Hybrid         NaN
# --       2    Timothy    Wright  timothy.wright@techcorp.com        1         2  151000 2017-03-07      M            Active             None    Hybrid         1.0
# --       3     Victor  Campbell victor.campbell@techcorp.com        1         2  168000 2020-12-07      M            Active             None    Remote         1.0
#
# CREATE TABLE job_titles (
#     title_id INTEGER,
#     title TEXT,
#     dept_id INTEGER,
#     level TEXT,
#     min_salary INTEGER,
#     max_salary INTEGER
# );
#
# -- Sample data from job_titles:
# --  title_id                    title  dept_id     level  min_salary  max_salary
# --         1           VP Engineering        1 Executive      180000      220000
# --         2      Engineering Manager        1   Manager      150000      180000
# --         3 Senior Software Engineer        1    Senior      13000
#
# ... (total length: 5698 characters)
#
# All schema tests passed!

# %% [markdown]
# ## Part 2B: SQL Safety Validator (TODOs 4-6)
#
# AI models can sometimes generate dangerous SQL (DROP TABLE, DELETE, etc.). Your validator must catch these before they reach the database.
#
# Open `text2sql_engine.py` and complete TODOs 4, 5, and 6.

# %%
# Test your SQL validator (after completing TODOs 4-6)
import importlib
import text2sql_engine
importlib.reload(text2sql_engine)
from text2sql_engine import validate_sql

# These should all PASS (return True)
safe_queries = [
    "SELECT * FROM employees",
    "SELECT dept_name, AVG(salary) FROM employees e JOIN departments d ON e.dept_id = d.dept_id GROUP BY dept_name",
    "WITH dept_avg AS (SELECT dept_id, AVG(salary) as avg FROM employees GROUP BY dept_id) SELECT * FROM dept_avg",
]

for q in safe_queries:
    valid, msg = validate_sql(q)
    status = "PASS" if valid else "FAIL"
    print(f"  [{status}] Safe query: {q[:60]}... -> {msg}")
    assert valid, f"Should be valid: {q}"

# These should all FAIL (return False)
dangerous_queries = [
    "DROP TABLE employees",
    "DELETE FROM employees WHERE emp_id = 1",
    "UPDATE employees SET salary = 0",
    "INSERT INTO employees VALUES (999, 'Hacker')",
    "SELECT 1; DROP TABLE employees",
    "",
]

for q in dangerous_queries:
    valid, msg = validate_sql(q)
    status = "PASS" if not valid else "FAIL"
    print(f"  [{status}] Dangerous query: {q[:60]}... -> {msg}")
    assert not valid, f"Should be blocked: {q}"

print("\nAll validator tests passed!")
# Out:
#   [PASS] Safe query: SELECT * FROM employees... -> Query is safe.
#   [PASS] Safe query: SELECT dept_name, AVG(salary) FROM employees e JOIN departme... -> Query is safe.
#   [PASS] Safe query: WITH dept_avg AS (SELECT dept_id, AVG(salary) as avg FROM em... -> Query is safe.
#   [PASS] Dangerous query: DROP TABLE employees... -> Query must start with SELECT or WITH
#   [PASS] Dangerous query: DELETE FROM employees WHERE emp_id = 1... -> Query must start with SELECT or WITH
#   [PASS] Dangerous query: UPDATE employees SET salary = 0... -> Query must start with SELECT or WITH
#   [PASS] Dangerous query: INSERT INTO employees VALUES (999, 'Hacker')... -> Query must start with SELECT or WITH
#   [PASS] Dangerous query: SELECT 1; DROP TABLE employees... -> Dangerous keyword detected: DROP
#   [PASS] Dangerous query: ... -> Empty query.
#
# All validator tests passed!

# %% [markdown]
# ## Part 2C: Response Parser (TODOs 7-8)
#
# When Gemini returns SQL, it might wrap it in markdown code blocks or add explanations. The parser extracts just the SQL.
#
# Complete TODOs 7 and 8 in `text2sql_engine.py`.

# %%
# Test your response parser (after completing TODOs 7-8)
import importlib
import text2sql_engine
importlib.reload(text2sql_engine)
from text2sql_engine import extract_sql_from_response

# Test 1: SQL in code block
response1 = "Here's the query:\n```sql\nSELECT dept_name, AVG(salary) AS avg_salary\nFROM employees e\nJOIN departments d ON e.dept_id = d.dept_id\nGROUP BY dept_name;\n```\nThis joins the employees and departments tables."

sql1 = extract_sql_from_response(response1)
print(f"Test 1 (code block): {sql1[:60]}...")
assert "SELECT" in sql1 and "GROUP BY" in sql1

# Test 2: Plain SQL with explanation
response2 = "The SQL query to answer this is: SELECT COUNT(*) FROM employees WHERE employment_status = 'Active'; This counts all active employees."
sql2 = extract_sql_from_response(response2)
print(f"Test 2 (plain text): {sql2[:60]}...")
assert "SELECT" in sql2

# Test 3: Just SQL
response3 = "SELECT * FROM departments ORDER BY annual_budget DESC;"
sql3 = extract_sql_from_response(response3)
print(f"Test 3 (raw SQL): {sql3[:60]}...")
assert sql3.startswith("SELECT")

print("\nAll parser tests passed!")
# Out:
# Test 1 (code block): SELECT dept_name, AVG(salary) AS avg_salary
# FROM employees e...
# Test 2 (plain text): SELECT COUNT(*) FROM employees WHERE employment_status = 'Ac...
# Test 3 (raw SQL): SELECT * FROM departments ORDER BY annual_budget DESC...
#
# All parser tests passed!

# %% [markdown]
# ## Part 2D-E: SQL Generator & Executor (TODOs 9-12)
#
# Now for the core AI integration:
# - **TODO 9**: Build the prompt that tells Gemini about the schema and rules
# - **TODO 10**: Call the Gemini API and extract the SQL
# - **TODO 11-12**: Validate and execute the generated SQL
#
# Complete TODOs 9 through 12 in `text2sql_engine.py`.

# %%
# Set up the Claude API (you need this for TODOs 9-10 testing)
from anthropic import Anthropic
from dotenv import load_dotenv
import os

# Load API key from .env file
load_dotenv()
ANTHROPIC_API_KEY = os.getenv('ANTHROPIC_API_KEY')

# Initialize Claude client
client = Anthropic(api_key=ANTHROPIC_API_KEY)

# Quick test
resp = client.messages.create(
    model="claude-sonnet-4-20250514",
    max_tokens=100,
    messages=[{"role": "user", "content": "Say hello in one word."}]
)
print(f"API test: {resp.content[0].text.strip()}")
# Out:
# API test: Hello!

# %%
# Test your SQL generator (after completing TODOs 9-12)
import importlib
import text2sql_engine
importlib.reload(text2sql_engine)
from text2sql_engine import generate_sql, execute_generated_sql, get_schema_for_prompt

schema_info = get_schema_for_prompt(conn)

# Test: Generate SQL for a simple question
sql = generate_sql("How many employees are in each department?", client, schema_info)
print(f"Generated SQL:\n{sql}\n")

# Test: Execute it
success, result = execute_generated_sql(sql, conn)
print(f"Success: {success}")
if success:
    print(result)
else:
    print(f"Error: {result}")
# Out:
# Generated SQL:
# SELECT
#     d.dept_name,
#     COUNT(e.emp_id) AS employee_count
# FROM departments d
# LEFT JOIN employees e ON d.dept_id = e.dept_id
# WHERE e.employment_status = 'Active' OR e.employment_status IS NULL
# GROUP BY d.dept_id, d.dept_name
# ORDER BY employee_count DESC
#
# Success: True
#           dept_name  employee_count
# 0       Engineering              24
# 1             Sales              18
# 2      Data Science              17
# 3           Finance              12
# 4           Product              11
# 5  Customer Support              10
# 6         Marketing               9
# 7   Human Resources               6

# %% [markdown]
# ## Part 2F: Visualization Code Generator (TODOs 13-15)
#
# This is where it gets exciting — the AI will write Python visualization code based on query results. Given a question, the SQL, and the resulting DataFrame, it generates matplotlib/seaborn code to create an appropriate chart.
#
# Complete TODOs 13 through 15 in `text2sql_engine.py`.

# %%
# Test the visualization generator (after completing TODOs 13-15)
import importlib
import text2sql_engine
importlib.reload(text2sql_engine)
from text2sql_engine import generate_visualization_code

# First, get some data to visualize
test_sql = """
SELECT d.dept_name, COUNT(e.emp_id) as employee_count
FROM departments d
JOIN employees e ON d.dept_id = e.dept_id
GROUP BY d.dept_name
ORDER BY employee_count DESC
"""
test_df = pd.read_sql_query(test_sql, conn)
print("Data to visualize:")
print(test_df)

# Generate visualization code
viz_code = generate_visualization_code(
    "How many employees in each department?",
    test_sql,
    test_df,
    client
)
print(f"\nGenerated Python code:\n{viz_code}")

# Execute the visualization code
try:
    df = test_df  # Make 'df' available for the generated code
    exec(viz_code)
    if 'fig' in dir():
        plt.show()
    else:
        plt.show()
    print("\nVisualization generated successfully!")
except Exception as e:
    print(f"\nVisualization error: {e}")
    print("Check your generate_visualization_code() implementation.")
# Out:
# Data to visualize:
#           dept_name  employee_count
# 0       Engineering              25
# 1             Sales              20
# 2      Data Science              19
# 3           Finance              13
# 4         Marketing              12
# 5  Customer Support              12
# 6           Product              11
# 7   Human Resources               8
#
# Generated Python code:
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# sns.set_style("darkgrid")
#
# plt.figure(figsize=(12, 7))
# bars = plt.bar(df['dept_name'], df['employee_count'], color=sns.color_palette('Set2', n_colors=len(df)), edgecolor='black', linewidth=1.2)
#
# plt.title('Number of Employees in Each Department', fontsize=16, fontweight='bold')
# plt.xlabel('Department', fontsize=12)
# plt.ylabel('Number of Employees', fontsize=12)
# plt.xticks(rotation=45, ha='right')
# plt.tick_params(axis='both', which='both', length=6, width=1.5)
#
# for bar in bars:
#     height = bar.get_height()
#     plt.text(bar.get_x() + bar.get_width()/2., height + 0.3, f'{int(height)}',
#              ha='center', va='bottom', fontweight='bold')
#
# plt.tight_layout()
# fig = plt.gcf()
# Visualization generated successfully!

# %% [markdown]
# ## Part 2G: The Complete Engine (TODOs 16-17)
#
# Finally, wire everything together in the `Text2SQLEngine` class:
# - **TODO 16**: Initialize the schema and Gemini client
# - **TODO 17**: Implement the full `ask()` pipeline
#
# Complete TODOs 16 and 17 in `text2sql_engine.py`.

# %%
# Test the complete engine (after completing TODOs 16-17)
import importlib
import text2sql_engine
importlib.reload(text2sql_engine)
from text2sql_engine import Text2SQLEngine

# Create the engine with Claude API
engine = Text2SQLEngine(conn, api_key=ANTHROPIC_API_KEY)

# Test 1: Simple count
result = engine.ask("How many total employees does TechCorp have?")
print(f"\nSuccess: {result['success']}")

# Test 2: Aggregation with GROUP BY
result = engine.ask("What is the average salary by department? Include department name.")
print(f"\nSuccess: {result['success']}")

# Test 3: With visualization
result = engine.ask("Show employee count by career level", visualize=True)
if result.get('viz_code'):
    print(f"\nVisualization code generated ({len(result['viz_code'])} chars)")
    try:
        df = result['data']  # Make df available for the viz code
        exec(result['viz_code'])
        plt.show()
    except Exception as e:
        print(f"Viz error: {e}")
        print(f"\nGenerated code:\n{result['viz_code']}")  # Debug: show what was generated
        print(f"\nDataFrame columns: {result['data'].columns.tolist()}")  # Debug: show actual columns
# Out:
# Building schema context...
# ✓ Schema loaded: 5698 characters
# Initializing Claude API...
# ✓ Claude API connected: ready
#
# 🤔 Question: How many total employees does TechCorp have?
#
# 📝 Generated SQL:
# SELECT COUNT(*) AS total_employees
# FROM employees
# WHERE employment_status = 'Active'
#
# ✓ Query returned 1 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: Based on the query results, TechCorp currently has 107 total employees, indicating the company is operating as a mid-sized technology organization. This employee count suggests TechCorp is likely in a growth phase, having moved beyond startup size but still maintaining the agility that smaller tech companies often possess.
#
# Given this workforce size of 107 employees, I recommend conducting a comprehensive organizational structure review to ensure optimal team scaling and communication channels as the company continues to grow. Additionally, this would be an ideal time to invest in scalable HR systems and processes that can efficiently support the next phase of growth, particularly as many tech companies experience rapid expansion once they reach this critical mass.
#
#
# Success: True
#
# 🤔 Question: What is the average salary by department? Include department name.
#
# 📝 Generated SQL:
# SELECT
#     d.dept_name,
#     ROUND(AVG(e.salary), 2) AS average_salary
# FROM employees e
# JOIN departments d ON e.dept_id = d.dept_id
# WHERE e.employment_status = 'Active'
# GROUP BY d.dept_id, d.dept_name
# ORDER BY average_salary DESC
#
# ✓ Query returned 8 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: **Key Insight:** Data Science leads all departments with the highest average salary at $140,176, while Customer Support has the lowest at $69,000 - representing a significant $71,176 gap between the highest and lowest paid departments.
#
# **Business Interpretation:** The salary distribution clearly reflects the market premium for technical and strategic roles, with Data Science, Product, and Engineering (all above $121K) commanding significantly higher compensation than support functions.
#
# **Recommendation:** Consider conducting a compensation equity review for Customer Support and Sales teams, as their salaries ($69K and $89K respectively) may be creating retention challenges and limiting talent acquisition in these customer-facing roles that are critical to business success.
#
#
# Success: True
#
# 🤔 Question: Show employee count by career level
#
# 📝 Generated SQL:
# SELECT
#     jt.level AS career_level,
#     COUNT(*) AS employee_count
# FROM employees e
# JOIN job_titles jt ON e.title_id = jt.title_id
# WHERE e.employment_status = 'Active'
# GROUP BY jt.level
# ORDER BY employee_count DESC
#
# ✓ Query returned 5 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: The data reveals a traditional pyramid organizational structure with 45 mid-level employees representing the largest segment (42% of the workforce), while senior roles progressively decrease in size. **Key insight**: There's a significant concentration at the mid-level, suggesting either strong retention in this tier or potential bottlenecks in career advancement to senior positions (only 22 senior employees compared to 45 mid-level).
#
# **Recommendation**: Consider developing targeted promotion pathways or mentorship programs to facilitate progression from mid to senior levels, as the current 2:1 ratio may indicate limited advancement opportunities that could impact employee retention and career satisfaction.
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
#
# Visualization code generated (712 chars)

# %% [markdown]
# > **Takeaway**: You've built a complete AI-powered SQL engine from scratch\! The key insight is that each component (schema builder, validator, parser, generator, executor, visualizer) does one thing well, and the engine ties them all together. This modular design makes it easy to test, debug, and improve each piece independently.

# %% [markdown]
# ---
#
# # Part 3: Answer 12 Business Questions
#
# Now use your completed engine to answer real business questions. For each question:
#
# 1. **Ask** the engine using `engine.ask()`
# 2. **Review** the generated SQL — is it correct?
# 3. **Visualize** the results (use the engine's viz or write your own)
# 4. **Insight** — write a 1-2 sentence business takeaway
#
# **Tip**: If the AI generates incorrect SQL, refine your question and try again. Learning to prompt effectively IS the skill here.

# %% [markdown]
# ## Question 1: Compensation Overview
#
# *What is the average, minimum, and maximum salary for each department? Include the number of employees.*
#
# **Visualization hint**: Bar chart comparing departments

# %%
# Question 1: Compensation Overview
result_q1 = engine.ask('''
What is the average, minimum, and maximum salary for each department? 
Include the number of employees.
Create a grouped bar chart comparing average, minimum, and maximum salary for each department.
''', visualize=True)

# Display results
print("\n" + "="*80)
print("DATA RESULTS")
print("="*80)
print(result_q1['data'])

# NEW: Use safe_visualize instead of manual exec
from db_utils import safe_visualize
safe_visualize(result_q1)
# Out:
# 🤔 Question:
# What is the average, minimum, and maximum salary for each department?
# Include the number of employees.
# Create a grouped bar chart comparing average, minimum, and maximum salary for each department.
#
#
# 📝 Generated SQL:
# SELECT
#     d.dept_name,
#     COUNT(e.emp_id) AS employee_count,
#     ROUND(AVG(e.salary), 2) AS avg_salary,
#     MIN(e.salary) AS min_salary,
#     MAX(e.salary) AS max_salary
# FROM departments d
# JOIN employees e ON d.dept_id = e.dept_id
# WHERE e.employment_status = 'Active'
# GROUP BY d.dept_id, d.dept_name
# ORDER BY avg_salary DESC
#
# ✓ Query returned 8 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: **Key Business Insights:**
#
# Data Science leads in compensation with the highest average salary at $140,176, while Customer Support has the lowest at $69,000 - representing a significant $71,176 gap between departments. Despite having the largest team (24 employees), Engineering ranks third in average compensation at $121,958, suggesting strong investment in technical talent across the organization.
#
# **Recommendation:** Consider conducting a compensation equity review for Customer Support, as their maximum salary of $100,000 is substantially lower than other departments' minimums, which could impact retention and recruitment in this customer-facing role.
#
# Here's the grouped bar chart comparing salary metrics across departments:
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # Data
# departments = ['Data Science', 'Product', 'Engineering', 'Marketing',
#                'Finance', 'Human Resources', 'Sales', 'Customer Support']
# avg_salaries = [140176, 125727, 121958, 100556, 99667, 94333, 89000, 69000]
# min_salaries = [76000, 98000, 80000, 63000, 56000, 61000, 54000, 47000]
# max_salaries = [193000, 200000, 196000, 160000, 175000, 161000, 175000, 100000]
#
# # Create grouped bar chart
# x = np.arange(len(departments))
# width = 0.25
#
# fig, ax = plt.subplots(figsize=(14, 8))
# bars1 = ax.bar(x - width, avg_salaries, width, label='Average Salary', color='#2E86AB')
# bars2 = ax.bar(x, min_salaries, width, label='Minimum Salary', color='#A23B72')
# bars3 = ax.bar(x + width, max_salaries, width, label='Maximum Salary', color='#F18F01')
#
# ax.set_xlabel('Department', fontsize=12)
# ax.set_ylabel('Salary ($)', fontsize=12)
# ax.set_title('Salary Comparison by Department', fontsize=14, fontweight='bold')
# ax.set_xticks(x)
# ax.set_xticklabels(departments, rotation=45, ha='right')
# ax.legend()
#
# # Format y-axis to show currency
# ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x:,.0f}'))
#
# plt.tight_layout()
# plt.show()
# ```
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
#
# ================================================================================
# DATA RESULTS
# ================================================================================
#           dept_name  employee_count  avg_salary  min_salary  max_salary
# 0      Data Science              17   140176.47       76000      193000
# 1           Product              11   125727.27       98000      200000
# 2       Engineering              24   121958.33       80000      196000
# 3         Marketing               9   100555.56       63000      160000
# 4           Finance              12    99666.67       56000      175000
# 5   Human Resources               6    94333.33       61000      161000
# 6             Sales              18    89000.00       54000      175000
# 7  Customer Support              10    69000.00       47000      100000
# ✓ Visualization generated successfully

# %%
# Business Insight for Question 1
from db_utils import generate_business_insight

print("\n" + "="*80)
print("GENERATING BUSINESS INSIGHT...")
print("="*80)

insight = generate_business_insight(result_q1, client)
print(insight)
# Out:
# ================================================================================
# GENERATING BUSINESS INSIGHT...
# ================================================================================
# BUSINESS INSIGHT - Departmental Salary Analysis & Compensation Strategy
#
# Key Findings:
# - Data Science leads compensation with an average salary of $140,176, followed by Product ($125,727) and Engineering ($121,958), creating a clear tech-focused pay hierarchy
# - Customer Support has the lowest average salary at $69,000, representing a $71,176 gap from the highest-paid department
# - Product department shows the narrowest salary range ($102,000 spread) while Engineering has the widest range ($116,000 spread), indicating different compensation structures
# - Sales department has the largest team (18 employees) but ranks second-lowest in average compensation at $89,000
#
# Observations:
# - Technical departments (Data Science, Product, Engineering) consistently outpace business functions by $20,000-$50,000 in average salaries, reflecting market demand for tech talent
# - Despite having similar maximum salaries ($175,000), Finance and Sales show vastly different averages, suggesting uneven distribution within Sales
# - Customer Support's maximum salary of $100,000 is lower than the minimum salary in Product ($98,000), indicating potential retention and career progression challenges
# - The 107 total employees are heavily concentrated in technical roles (52 employees across top 3 departments), showing TechCorp's technical focus
#
# Recommendations:
# - Implement a comprehensive compensation review for Customer Support and Sales to address the significant pay gaps that could impact retention and recruitment
# - Standardize salary bands within Engineering to reduce the $116,000 range disparity and ensure equitable compensation for similar roles
# - Develop clear career progression pathways with defined salary increases for lower-paid departments to improve employee retention
# - Conduct market benchmarking analysis quarterly for technical roles to maintain competitive positioning in the high-demand talent market
#
# Single Highest Impact:
# - Immediately address Customer Support compensation structure by increasing the salary range floor to $60,000+ and ceiling to $120,000+, as this 10-person team's current pay scale creates the highest retention risk and directly impacts customer satisfaction metrics.

# %% [markdown]
# ## Question 2: Pay Equity by Gender
#
# *Compare the average salary between male and female employees, broken down by career level (from job_titles).*
#
# **Visualization hint**: Grouped bar chart: level x gender

# %%
# Question 2: Pay Equity by Gender
result_q2 = engine.ask('''
Compare the average salary between male and female employees, 
broken down by career level.
Create a grouped bar chart with career levels on the x-axis and separate bars for male and female employees. Avoid using traditional gender color stereotypes (e.g., pink/blue). Instead, use a modern palette that is visually appealing and accessible to all viewers.
''', visualize=True)

# Display results
print("\n" + "="*80)
print("DATA RESULTS")
print("="*80)
print(result_q2['data'])

# Use safe_visualize
from db_utils import safe_visualize
safe_visualize(result_q2)
# Out:
# 🤔 Question:
# Compare the average salary between male and female employees,
# broken down by career level.
# Create a grouped bar chart with career levels on the x-axis and separate bars for male and female employees. Avoid using traditional gender color stereotypes (e.g., pink/blue). Instead, use a modern palette that is visually appealing and accessible to all viewers.
#
#
# 📝 Generated SQL:
# SELECT
#     jt.level AS career_level,
#     e.gender,
#     ROUND(AVG(e.salary), 2) AS average_salary
# FROM employees e
# JOIN job_titles jt ON e.title_id = jt.title_id
# WHERE e.employment_status = 'Active'
#     AND e.gender IN ('M', 'F')
# GROUP BY jt.level, e.gender
# ORDER BY
#     CASE jt.level
#         WHEN 'Executive' THEN 1
#         WHEN 'Manager' THEN 2
#         WHEN 'Senior' THEN 3
#         WHEN 'Mid-level' THEN 4
#         WHEN 'Junior' THEN 5
#         ELSE 6
#     END,
#     e.gender
#
# ✓ Query returned 10 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: Looking at this salary data, there's a notable gender pay gap that varies significantly by career level. While the gap is minimal at Executive ($2,333 difference) and Manager levels ($314 difference), it widens considerably at the Senior level where males earn $15,343 more than females ($130,200 vs $114,857). Interestingly, the pattern reverses at Entry level where females slightly out-earn males ($69,167 vs $67,667), and at Mid level where males earn $4,676 more.
#
# **Key Insight:** The largest gender pay disparity occurs at the Senior level, suggesting potential barriers in compensation progression for women as they advance toward leadership roles.
#
# **Actionable Recommendation:** Conduct a comprehensive pay equity audit focusing on the Senior level positions, and implement standardized compensation bands with transparent promotion criteria to ensure equitable pay progression regardless of gender.
#
# Here's the code to create the requested visualization:
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
# import pandas as pd
#
# # Data from query results
# data = {
#     'career_level': ['Executive', 'Manager', 'Senior', 'Entry', 'Mid'],
#     'Female': [178666.67, 134600.00, 114857.14, 69166.67, 99454.55],
#     'Male': [181000.00, 134285.71, 130200.00, 67666.67, 104130.43]
# }
#
# df = pd.DataFrame(data)
#
# # Set up the plot with modern, accessible colors
# fig, ax = plt.subplots(figsize=(12, 8))
#
# # Modern, accessible color palette
# colors = ['#2E86AB', '#A23B72']  # Teal blue and burgundy
#
# x = np.arange(len(df['career_level']))
# width = 0.35
#
# # Create grouped bars
# bars1 = ax.bar(x - width/2, df['Female'], width, label='Female', color=colors[0], alpha=0.8)
# bars2 = ax.bar(x + width/2, df['Male'], width, label='Male', color=colors[1], alpha=0.8)
#
# # Customize the chart
# ax.set_xlabel('Career Level', fontsize=12, fontweight='bold')
# ax.set_ylabel('Average Salary ($)', fontsize=12, fontweight='bold')
# ax.set_title('Average Salary by Gender and Career Level', fontsize=14, fontweight='bold', pad=20)
# ax.set_xticks(x)
# ax.set_xticklabels(df['career_level'])
#
# # Format y-axis to show salary values clearly
# ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x:,.0f}'))
#
# # Add value labels on bars
# def add_value_labels(bars):
#     for bar in bars:
#         height = bar.get_height()
#         ax.annotate(f'${height:,.0f}',
#                     xy=(bar.get_x() + bar.get_width() / 2, height),
#                     xytext=(0, 3),  # 3 points vertical offset
#                     textcoords="offset points",
#                     ha='center', va='bottom',
#                     fontsize=9, rotation=90)
#
# add_value_labels(bars1)
# add_value_labels(bars2)
#
# # Customize legend
# ax.legend(loc='upper left', frameon=True, fancybox=True, shadow=True)
#
# # Add grid for better readability
# ax.grid(True, alpha=0.3, axis='y')
# ax.set_axisbelow(True)
#
# # Improve layout
# plt.tight_layout()
# plt.show()
# ```
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
#
# ================================================================================
# DATA RESULTS
# ================================================================================
#   career_level gender  average_salary
# 0    Executive      F       178666.67
# 1    Executive      M       181000.00
# 2      Manager      F       134600.00
# 3      Manager      M       134285.71
# 4       Senior      F       114857.14
# 5       Senior      M       130200.00
# 6        Entry      F        69166.67
# 7          Mid      F        99454.55
# 8        Entry      M        67666.67
# 9          Mid      M       104130.43
# ✓ Visualization generated successfully

# %%
# Business Insight for Question 2
from db_utils import generate_business_insight

print("\n" + "="*80)
print("GENERATING BUSINESS INSIGHT...")
print("="*80)

insight = generate_business_insight(result_q2, client)
print(insight)
# Out:
# ================================================================================
# GENERATING BUSINESS INSIGHT...
# ================================================================================
# BUSINESS INSIGHT - Gender Pay Gap Analysis Across Career Levels
#
# Key Findings:
# - Male employees earn $2,333 more on average at the Executive level ($181,000 vs $178,667), representing a 1.3% gap
# - The largest gender pay disparity occurs at the Senior level, where males earn $15,343 more than females ($130,200 vs $114,857) - a 13.4% difference
# - At the Manager level, the gap is minimal with females actually earning $314 more on average ($134,600 vs $134,286)
# - Entry-level positions show females earning $1,500 more than males ($69,167 vs $67,667), indicating fair starting compensation
#
# Observations:
# - The gender pay gap widens significantly in technical/specialized Senior roles, suggesting potential bias in promotion or salary negotiation processes
# - Manager-level compensation shows near-perfect parity, indicating effective pay equity practices at the supervisory level
# - The Mid-level category shows males earning $4,676 more than females ($104,130 vs $99,455), creating a concerning pattern as employees advance
# - Pay equity appears strongest at entry points but deteriorates in individual contributor senior roles rather than management tracks
#
# Recommendations:
# - Conduct immediate salary audit for Senior-level positions to identify and correct the 13.4% gender pay gap through targeted adjustments
# - Implement standardized salary bands and promotion criteria for Mid and Senior levels to prevent subjective compensation decisions
# - Establish mandatory salary negotiation training for female employees and unconscious bias training for managers involved in compensation decisions
# - Create transparent career progression pathways that clearly define requirements and compensation for advancement beyond entry level
#
# Single Highest Impact:
# - Execute comprehensive salary corrections for Senior-level female employees to eliminate the $15,343 average gap, as this represents the largest inequity and affects employees at a critical career advancement stage where retention and engagement are most vulnerable.

# %% [markdown]
# ## Question 3: Top Performers vs. Compensation
#
# *For employees with a 2024 performance rating of 4 or 5, what is their average salary compared to those rated 1-3? Break it down by department.*
#
# **Visualization hint**: Show the gap between high and low performers

# %%
# Question 3: Top Performers vs. Compensation
result_q3 = engine.ask('''
For employees with a 2024 performance rating of 4 or 5, 
what is their average salary compared to those rated 1-3? 
Break it down by department.
Create a grouped bar chart comparing high performers (rating 4-5) vs average/low performers (rating 1-3) side by side for each department.
''', visualize=True)

# Display results
print("\n" + "="*80)
print("DATA RESULTS")
print("="*80)
print(result_q3['data'])

# Use safe_visualize
from db_utils import safe_visualize
safe_visualize(result_q3)
# Out:
# 🤔 Question:
# For employees with a 2024 performance rating of 4 or 5,
# what is their average salary compared to those rated 1-3?
# Break it down by department.
# Create a grouped bar chart comparing high performers (rating 4-5) vs average/low performers (rating 1-3) side by side for each department.
#
#
# 📝 Generated SQL:
# SELECT
#     d.dept_name AS department,
#     'High Performers (4-5)' AS performance_group,
#     ROUND(AVG(e.salary), 2) AS avg_salary
# FROM employees e
# JOIN departments d ON e.dept_id = d.dept_id
# JOIN performance_reviews pr ON e.emp_id = pr.emp_id
# WHERE pr.review_year = 2024
#     AND pr.rating IN (4, 5)
#     AND e.employment_status = 'Active'
# GROUP BY d.dept_name
#
# ✓ Query returned 8 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: **Key Insight:** There's a significant salary gap between high performers (ratings 4-5) and average/low performers (ratings 1-3) across all departments, with Data Science showing the highest compensation for top performers at $151,333 compared to Customer Support at $72,000.
#
# **Actionable Recommendation:** The company should review compensation equity in Customer Support, as their high performers earn significantly less ($72,000) than high performers in technical departments like Engineering ($124,400) and Product ($127,667), which could lead to talent retention issues.
#
# **Note:** The query results only show data for high performers (ratings 4-5) - to complete the analysis and create the requested grouped bar chart, we would need the average salary data for employees with ratings 1-3 in each department as well.
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
#
# ================================================================================
# DATA RESULTS
# ================================================================================
#          department      performance_group  avg_salary
# 0  Customer Support  High Performers (4-5)    72000.00
# 1      Data Science  High Performers (4-5)   151333.33
# 2       Engineering  High Performers (4-5)   124400.00
# 3           Finance  High Performers (4-5)    86000.00
# 4   Human Resources  High Performers (4-5)   114666.67
# 5         Marketing  High Performers (4-5)   100000.00
# 6           Product  High Performers (4-5)   127666.67
# 7             Sales  High Performers (4-5)    91333.33
# ✓ Visualization generated successfully

# %%
# Business Insight for Question 3
from db_utils import generate_business_insight

print("\n" + "="*80)
print("GENERATING BUSINESS INSIGHT...")
print("="*80)

insight = generate_business_insight(result_q3, client)
print(insight)
# Out:
# ================================================================================
# GENERATING BUSINESS INSIGHT...
# ================================================================================
# BUSINESS INSIGHT - High Performer Salary Analysis by Department
#
# Key Findings:
# - Data Science leads with the highest average salary for high performers at $151,333, followed by Product ($127,667) and Engineering ($124,400)
# - Customer Support shows the lowest average salary for top performers at $72,000, creating a $79,333 gap with Data Science
# - Technical departments (Data Science, Engineering, Product) consistently show salaries above $120,000 for high performers
# - Eight departments have active high-performing employees, indicating good talent distribution across the organization
#
# Observations:
# - A clear salary premium exists for technical roles, with Data Science, Engineering, and Product forming the top tier of compensation
# - Customer Support high performers earn significantly less than other departments, potentially creating retention risks for top talent
# - The salary range spans over $79,000 between highest and lowest performing departments, suggesting different market positioning strategies
# - Finance high performers ($86,000) earn notably less than other business functions like HR ($114,667) and Marketing ($100,000), which may indicate compression issues
#
# Recommendations:
# - Conduct a comprehensive market analysis for Customer Support roles to determine if current compensation is competitive enough to retain top talent
# - Review Finance department compensation structure as high performers may be underpaid relative to market standards and internal equity
# - Establish clear salary bands and progression paths for high performers to ensure retention across all departments
# - Implement cross-departmental mobility programs to help high performers in lower-paid functions transition to higher-compensated roles when appropriate
#
# Single Highest Impact:
# - Immediately review and adjust Customer Support high performer compensation to reduce the risk of losing top talent to competitors, as the $79,333 gap with technical roles creates significant flight risk for employees who could easily transition to higher-paying positions elsewhere.

# %% [markdown]
# ## Question 4: Hiring Trends Over Time
#
# *How many employees were hired each year? Show the trend from 2015 to 2025.*
#
# **Visualization hint**: Line chart showing hiring over time

# %%
# Question 4: Hiring Trends Over Time
result_q4 = engine.ask('''
How many employees were hired each year? 
Show the trend from 2015 to 2025.
Create a line chart showing hiring trends over time with years on the x-axis and number of hires on the y-axis.
''', visualize=True)

# Display results
print("\n" + "="*80)
print("DATA RESULTS")
print("="*80)
print(result_q4['data'])

from db_utils import safe_visualize
safe_visualize(result_q4)
# Out:
# 🤔 Question:
# How many employees were hired each year?
# Show the trend from 2015 to 2025.
# Create a line chart showing hiring trends over time with years on the x-axis and number of hires on the y-axis.
#
#
# 📝 Generated SQL:
# SELECT
#     strftime('%Y', hire_date) AS hire_year,
#     COUNT(*) AS hires_count
# FROM employees
# WHERE hire_date IS NOT NULL
#     AND strftime('%Y', hire_date) BETWEEN '2015' AND '2025'
# GROUP BY strftime('%Y', hire_date)
# ORDER BY hire_year
#
# ✓ Query returned 11 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: Based on the hiring data from 2015-2025, the company experienced dramatic growth from 2019-2021, with hires jumping from just 3-4 per year (2017-2018) to a peak of 25 hires in 2021. However, there's been a concerning downward trend since 2022, with hiring dropping significantly to only 9 hires in 2024 and projected to fall further to 3 in 2025.
#
# **Key insight:** The company underwent rapid expansion during 2019-2021 (likely responding to market opportunities or growth initiatives) but has since entered a contraction phase with hiring down 64% from its 2021 peak.
#
# **Recommendation:** Leadership should analyze whether the recent hiring decline aligns with strategic objectives or if it indicates potential issues with talent acquisition, budget constraints, or market positioning that need immediate attention.
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
#
# ================================================================================
# DATA RESULTS
# ================================================================================
#    hire_year  hires_count
# 0       2015            2
# 1       2016            2
# 2       2017            4
# 3       2018            3
# 4       2019           18
# 5       2020           19
# 6       2021           25
# 7       2022           18
# 8       2023           17
# 9       2024            9
# 10      2025            3
# ✓ Visualization generated successfully

# %%
# Business Insight for Question 4
from db_utils import generate_business_insight

print("\n" + "="*80)
print("GENERATING BUSINESS INSIGHT...")
print("="*80)

insight = generate_business_insight(result_q4, client)
print(insight)
# Out:
# ================================================================================
# GENERATING BUSINESS INSIGHT...
# ================================================================================
# BUSINESS INSIGHT - Hiring Trends and Workforce Growth Analysis (2015-2025)
#
# Key Findings:
# - TechCorp experienced explosive growth from 2019-2021, with hiring increasing from 18 to 25 employees (39% increase over two years)
# - Peak hiring occurred in 2021 with 25 new employees, representing the company's most aggressive expansion period
# - Hiring has declined significantly since 2022, dropping 64% from 25 hires in 2021 to just 9 in 2024
# - Total workforce additions over the 11-year period reached 120 employees, with 60% of all hires occurring between 2019-2022
#
# Observations:
# - The 2019-2021 surge suggests major business expansion, potentially driven by market opportunities or funding events during this period
# - The sharp decline in 2022-2024 (from 25 to 9 hires) indicates either market contraction, budget constraints, or strategic shift toward efficiency over growth
# - Early years (2015-2018) show minimal hiring activity averaging just 2.75 employees annually, suggesting TechCorp was likely a startup or small operation
# - The projected 2025 hiring of only 3 employees signals continued conservative approach or potential organizational maturity
#
# Recommendations:
# - Conduct workforce planning analysis to determine if current reduced hiring levels align with business growth objectives and revenue targets
# - Review retention strategies for the large 2019-2021 cohort to prevent potential talent exodus and maintain institutional knowledge
# - Assess whether the hiring slowdown is strategic or reactive, and develop a 3-year staffing roadmap based on business forecasts
# - Implement succession planning for critical roles, especially given the uneven hiring distribution may have created experience gaps
#
# Single Highest Impact:
# - Develop a comprehensive workforce retention program specifically targeting the 2019-2021 hiring cohort (62 employees), as losing this talent would be catastrophic given the current minimal hiring levels and would severely impact operational continuity and growth capacity.

# %% [markdown]
# ## Question 5: Salary Growth Analysis
#
# *What is the average total salary increase (from first to latest salary in salary_history) per department? Which department gives the biggest raises?*
#
# **Visualization hint**: Horizontal bar chart

# %%
# Question 5: Salary Growth Analysis
result_q5 = engine.ask('''
What is the average total salary increase (from first to latest salary in salary_history) 
per department? Which department gives the biggest raises?
Create a horizontal bar chart showing average salary increase by department, sorted from highest to lowest.
''', visualize=True)

# Display results
print("\n" + "="*80)
print("DATA RESULTS")
print("="*80)
print(result_q5['data'])

from db_utils import safe_visualize
safe_visualize(result_q5)
# Out:
# 🤔 Question:
# What is the average total salary increase (from first to latest salary in salary_history)
# per department? Which department gives the biggest raises?
# Create a horizontal bar chart showing average salary increase by department, sorted from highest to lowest.
#
#
# 📝 Generated SQL:
# SELECT
#     d.dept_name,
#     ROUND(AVG(sh_latest.new_salary - sh_first.old_salary), 2) AS avg_salary_increase
# FROM departments d
# JOIN employees e ON d.dept_id = e.dept_id
# JOIN (
#     SELECT
#         emp_id,
#         old_salary,
#         ROW_NUMBER() OVER (PARTITION BY emp_id ORDER BY effective_date ASC) as rn
#     FROM salary_history
# ) sh_first ON e.emp_id = sh_first.emp_id AND sh_first.rn = 1
# JOIN (
#     SELECT
#         emp_id,
#         new_salary,
#         ROW_NUMBER() OVER (PARTITION BY emp_id ORDER BY effective_date DESC) as rn
#     FROM salary_history
# ) sh_latest ON e.emp_id = sh_latest.emp_id AND sh_latest.rn = 1
# GROUP BY d.dept_id, d.dept_name
# ORDER BY avg_salary_increase DESC;
#
# ✓ Query returned 8 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: **Key Insight:** Data Science leads in salary growth with an average increase of $28,467, while Customer Support lags significantly behind at only $11,833 - creating a $16,634 gap between the highest and lowest departments.
#
# **Business Interpretation:** The data reveals substantial variation in career advancement opportunities across departments, with technical roles (Data Science, HR, Engineering) offering 20-40% higher salary progression than customer-facing roles (Sales, Customer Support). This disparity could impact talent retention and internal mobility, particularly for employees in lower-growth departments.
#
# **Recommendation:** Conduct a compensation equity review for Customer Support and Sales roles, which show concerning low growth rates of $11,833 and $17,211 respectively, to ensure competitive retention and reduce potential turnover in these critical customer-facing functions.
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
#
# ================================================================================
# DATA RESULTS
# ================================================================================
#           dept_name  avg_salary_increase
# 0      Data Science             28466.67
# 1   Human Resources             25833.33
# 2       Engineering             23840.00
# 3           Product             22000.00
# 4           Finance             19076.92
# 5         Marketing             18800.00
# 6             Sales             17210.53
# 7  Customer Support             11833.33
# ✓ Visualization generated successfully

# %%
# Business Insight for Question 5
from db_utils import generate_business_insight

print("\n" + "="*80)
print("GENERATING BUSINESS INSIGHT...")
print("="*80)

insight = generate_business_insight(result_q5, client)
print(insight)
# Out:
# ================================================================================
# GENERATING BUSINESS INSIGHT...
# ================================================================================
# BUSINESS INSIGHT - Department Salary Growth Analysis
#
# Key Findings:
# - Data Science leads in average salary increases at $28,466.67 per employee, followed by Human Resources at $25,833.33
# - Customer Support shows the lowest average increase at $11,833.33, representing 58% less growth than Data Science
# - Technical departments (Data Science and Engineering at $23,840) significantly outpace customer-facing roles
# - The salary increase gap between highest and lowest performing departments spans $16,633.34
#
# Observations:
# - A clear tier system emerges with technical/strategic roles (Data Science, HR, Engineering) receiving substantially higher increases than operational roles
# - Sales department shows surprisingly modest increases at $17,210.53 despite typically being revenue-generating and competitive for talent
# - Customer Support's low increase of $11,833.33 may indicate underinvestment in retention for this critical customer-facing function
# - The 65% difference between top and bottom departments suggests inconsistent compensation philosophy across the organization
#
# Recommendations:
# - Conduct immediate salary benchmarking for Customer Support and Sales roles to ensure competitive positioning in the market
# - Develop standardized salary increase guidelines that account for both market rates and internal equity across departments
# - Review Customer Support compensation structure as the significant gap may lead to high turnover in a customer-critical function
# - Implement annual cross-departmental compensation reviews to identify and address growing pay equity gaps
#
# Single Highest Impact:
# - Immediately audit and adjust Customer Support compensation strategy, as this department's 58% lower increases compared to top performers creates significant retention risk for roles directly impacting customer satisfaction and company reputation.

# %% [markdown]
# ## Question 6: Project Staffing & Budget
#
# *For each active project, show the project name, budget, number of team members, and budget per team member. Which projects are most/least resourced?*
#
# **Visualization hint**: Bar chart of budget per head

# %%
# Question 6: Project Staffing & Budget
result_q6 = engine.ask('''
For each active project, show the project name, budget, number of team members, 
and budget per team member. Which projects are most or least resourced?
Create a bar chart showing budget per team member for each project, sorted from highest to lowest.
''', visualize=True)

# Display results
print("\n" + "="*80)
print("DATA RESULTS")
print("="*80)
print(result_q6['data'])

# Use safe_visualize
from db_utils import safe_visualize
safe_visualize(result_q6)
# Out:
# 🤔 Question:
# For each active project, show the project name, budget, number of team members,
# and budget per team member. Which projects are most or least resourced?
# Create a bar chart showing budget per team member for each project, sorted from highest to lowest.
#
#
# 📝 Generated SQL:
# SELECT
#     p.project_name,
#     p.budget,
#     COUNT(pa.emp_id) AS team_members,
#     ROUND(CAST(p.budget AS REAL) / COUNT(pa.emp_id), 2) AS budget_per_member
# FROM projects p
# JOIN project_assignments pa ON p.project_id = pa.project_id
# WHERE p.status IN ('In Progress', 'Active')
# GROUP BY p.project_id, p.project_name, p.budget
# ORDER BY budget_per_member DESC
#
# ✓ Query returned 8 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: **Key Insight:** There's a dramatic disparity in resource allocation across projects, with the ML Recommendation Engine receiving $100,000 per team member while Social Media Expansion and Budget Forecasting Tool only get $13,571 per member - a 7x difference that suggests inconsistent prioritization or budgeting approaches.
#
# **Actionable Recommendation:** The company should review resource allocation for the two lowest-funded projects (Social Media Expansion and Budget Forecasting Tool at ~$13,571 per member) to determine if they're genuinely lower-priority initiatives or if they're under-resourced relative to their strategic importance. Consider reallocating budget from over-resourced projects or adjusting team sizes to ensure adequate funding for successful project completion.
#
# The data reveals three distinct resource tiers: premium projects ($74K-$100K per member), mid-tier projects ($27K-$33K per member), and minimal-resource projects (~$14K per member), suggesting the need for clearer resource allocation guidelines.
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
#
# ================================================================================
# DATA RESULTS
# ================================================================================
#                project_name  budget  team_members  budget_per_member
# 0  ML Recommendation Engine  500000             5          100000.00
# 1      West Coast Expansion  450000             6           75000.00
# 2   Cloud Migration Phase 2  520000             7           74285.71
# 3       Self-Service Portal  200000             6           33333.33
# 4  Customer Feedback System  160000             6           26666.67
# 5     Onboarding Automation  110000             5           22000.00
# 6    Social Media Expansion   95000             7           13571.43
# 7   Budget Forecasting Tool   95000             7           13571.43
# ✓ Visualization generated successfully

# %%
# Business Insight for Question 6
from db_utils import generate_business_insight

print("\n" + "="*80)
print("GENERATING BUSINESS INSIGHT...")
print("="*80)

insight = generate_business_insight(result_q6, client)
print(insight)
# Out:
# ================================================================================
# GENERATING BUSINESS INSIGHT...
# ================================================================================
# # BUSINESS INSIGHT - Project Resource Allocation Analysis
#
# ## Key Findings:
# - ML Recommendation Engine is significantly over-resourced at $100,000 per team member, 33% higher than the second-highest project
# - Two projects (Social Media Expansion and Budget Forecasting Tool) operate at just $13,571 per team member, representing 86% less resources than the top project
# - Resource allocation spans a dramatic 7:1 ratio between highest and lowest funded projects per employee
# - Cloud Migration Phase 2 commands the largest total budget ($520,000) but ranks third in per-member allocation due to its 7-person team
#
# ## Observations:
# - High-budget strategic projects (ML Engine, West Coast Expansion, Cloud Migration) consistently receive $74,000+ per team member, suggesting priority tier funding
# - Customer-facing projects (Self-Service Portal, Customer Feedback System) fall into a middle tier at $26,000-$33,000 per member
# - Internal process improvements (Social Media Expansion, Budget Forecasting) appear systematically under-resourced despite having the largest team sizes (7 members each)
# - No clear correlation exists between team size and total budget allocation, indicating inconsistent resource planning methodology
#
# ## Recommendations:
# - Conduct immediate budget rebalancing by reducing ML Recommendation Engine allocation by 25% and redistributing funds to the two lowest-resourced projects
# - Establish standardized resource allocation tiers based on project strategic importance, with clear per-member budget ranges for each tier
# - Review the business case for Social Media Expansion and Budget Forecasting Tool to determine if current funding levels can realistically achieve project objectives
# - Implement monthly resource utilization tracking to ensure budget-per-member ratios align with project complexity and deliverable requirements
#
# ## Single Highest Impact:
# - **Redistribute $125,000 from ML Recommendation Engine to the two under-resourced internal projects**, bringing them to $31,000+ per member while maintaining ML Engine's priority status at $75,000 per member, creating more balanced resource allocation across the portfolio.

# %% [markdown]
# ## Question 7: Remote Work Distribution
#
# *How does work mode (Remote/Hybrid/On-site) vary across departments? Show the count for each combination.*
#
# **Visualization hint**: Stacked bar chart or heatmap

# %%
# Question 7: Remote Work Distribution
result_q7 = engine.ask('''
How does work mode (Remote/Hybrid/On-site) vary across departments? 
Show the count for each combination.
Create a stacked bar chart showing the distribution of work modes within each department.
Also Create a heatmap showing the distribution of work modes within each department.
Side by side
''', visualize=True)

# Display results
print("\n" + "="*80)
print("DATA RESULTS")
print("="*80)
print(result_q7['data'])

# Use safe_visualize
from db_utils import safe_visualize
safe_visualize(result_q7)
# Out:
# 🤔 Question:
# How does work mode (Remote/Hybrid/On-site) vary across departments?
# Show the count for each combination.
# Create a stacked bar chart showing the distribution of work modes within each department.
# Also Create a heatmap showing the distribution of work modes within each department.
# Side by side
#
#
# 📝 Generated SQL:
# SELECT
#     d.dept_name,
#     e.work_mode,
#     COUNT(*) AS employee_count
# FROM employees e
# JOIN departments d ON e.dept_id = d.dept_id
# WHERE e.employment_status = 'Active'
# GROUP BY d.dept_name, e.work_mode
# ORDER BY d.dept_name, e.work_mode
#
# ✓ Query returned 22 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: Based on the data analysis, here's a brief business interpretation:
#
# **Key Insight:** Engineering shows the most balanced work mode distribution with equal numbers of remote and hybrid workers (9 each) plus 6 on-site employees, totaling 24 people - making it the largest department. In contrast, some departments like Marketing and Product have no on-site workers at all, operating entirely through hybrid and remote arrangements.
#
# **Actionable Recommendation:** The company should investigate why certain departments (Marketing, Product) have eliminated on-site work entirely while others like Customer Support maintain 50% on-site presence (5 out of 10 employees). This suggests an opportunity to standardize work mode policies based on role requirements rather than departmental preferences.
#
# **Distribution Pattern:** Sales heavily favors on-site work (8 on-site vs 6 hybrid vs 4 remote), while technical departments like Data Science show more flexibility with nearly equal distribution across all three modes (6 on-site, 5 hybrid, 6 remote). This indicates that work modes may be appropriately aligned with job functions, but consistency within similar role types should be evaluated.
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
#
# ================================================================================
# DATA RESULTS
# ================================================================================
#            dept_name work_mode  employee_count
# 0   Customer Support    Hybrid               2
# 1   Customer Support   On-site               5
# 2   Customer Support    Remote               3
# 3       Data Science    Hybrid               5
# 4       Data Science   On-site               6
# 5       Data Science    Remote               6
# 6        Engineering    Hybrid               9
# 7        Engineering   On-site               6
# 8        Engineering    Remote               9
# 9            Finance    Hybrid               5
# 10           Finance   On-site               4
# 11           Finance    Remote               3
# 12   Human Resources    Hybrid               2
# 13   Human Resources   On-site               3
# 14   Human Resources    Remote               1
# 15         Marketing    Hybrid               5
# 16         Marketing    Remote               4
# 17           Product    Hybrid               7
# 18           Product    Remote               4
# 19             Sales    Hybrid               6
# 20             Sales   On-site               8
# 21             Sales    Remote               4
# ✓ Visualization generated successfully

# %%
# Business Insight for Question 7
from db_utils import generate_business_insight

print("\n" + "="*80)
print("GENERATING BUSINESS INSIGHT...")
print("="*80)

insight = generate_business_insight(result_q7, client)
print(insight)
# Out:
# ================================================================================
# GENERATING BUSINESS INSIGHT...
# ================================================================================
# BUSINESS INSIGHT - Work Mode Distribution Analysis Across Departments
#
# Key Findings:
# - Engineering leads in flexible work adoption with 24 employees split evenly between Remote (9) and Hybrid (9), representing the largest department by headcount
# - Customer Support shows the highest On-site dependency with 50% of staff (5 out of 10) working on-site, likely due to operational requirements
# - Marketing and Product departments have eliminated On-site work entirely, operating with 100% flexible arrangements (Remote/Hybrid only)
# - Data Science demonstrates the most balanced distribution with nearly equal split across all three modes: Remote (6), On-site (6), and Hybrid (5)
#
# Observations:
# - Traditional support functions (Customer Support, HR) maintain higher On-site presence, while technical/creative departments (Marketing, Product, Engineering) favor flexible arrangements
# - Sales department shows strong On-site preference with 44% (8 out of 18) working on-site, suggesting client-facing roles still require physical presence
# - Finance maintains conservative approach with only 25% working remotely (3 out of 12), potentially due to compliance and security requirements
# - 67% of all departments offer all three work mode options, indicating TechCorp has successfully implemented flexible work policies across most functions
#
# Recommendations:
# - Standardize work mode policies within similar function groups to ensure equity and reduce potential employee dissatisfaction between comparable roles
# - Conduct employee satisfaction surveys in Customer Support and HR to assess if higher On-site requirements are impacting retention or recruitment
# - Review whether Finance's limited remote work (only 25%) is operationally necessary or if security concerns can be addressed through technology solutions
# - Create cross-departmental collaboration guidelines since some teams are fully remote/hybrid while others maintain significant On-site presence
#
# Single Highest Impact:
# - Audit and justify On-site requirements for Customer Support and Sales departments, as these show disproportionately high physical presence needs that may be limiting talent acquisition and employee satisfaction in a competitive market favoring flexibility.

# %% [markdown]
# ## Question 8: Training Completion Rates
#
# *What percentage of training enrollments are completed vs. in progress vs. enrolled? Break down by training category.*
#
# **Visualization hint**: Stacked bar chart by category

# %%
# Question 8: Training Completion Rates
result_q8 = engine.ask('''
What percentage of training enrollments are completed vs. in progress vs. planned? 
Break down by training category.

Return data with columns: category, status, percentage
where status is one of: Completed, In Progress, Planned
and percentage is the percent of total for that category.

IMPORTANT: Write a simple query using subqueries in the FROM clause.
Do NOT use WITH clauses or CTEs - they are causing syntax errors.
Use inline subqueries instead.
''', visualize=False)

# Display results
print("\n" + "="*80)
print("DATA RESULTS")
print("="*80)
print(result_q8['data'])

# Manual stacked bar chart with percentages
if result_q8['success'] and result_q8['data'] is not None:
    import matplotlib.pyplot as plt
    import seaborn as sns
    
    df = result_q8['data']
    
    # Pivot for stacked bar
    pivot_df = df.pivot(index='category', columns='status', values='percentage')
    
    # Create stacked bar
    sns.set_style("darkgrid")
    fig, ax = plt.subplots(figsize=(12, 7))
    
    pivot_df.plot(kind='bar', stacked=True, ax=ax,
                  color=['mediumseagreen', 'coral', 'steelblue'],
                  edgecolor='black', linewidth=1.2)
    
    # Add percentage labels on each segment
    for container in ax.containers:
        ax.bar_label(container, fmt='%.0f%%', label_type='center', fontsize=10)
    
    ax.set_xlabel('Training Category', fontsize=12)
    ax.set_ylabel('Percentage (%)', fontsize=12)
    ax.set_title('Training Status Distribution by Category', fontsize=16, fontweight='bold')
    ax.legend(title='Status', fontsize=10)
    plt.xticks(rotation=45, ha='right')
    plt.tick_params(axis='both', which='both', length=6, width=1.5)
    plt.tight_layout()
    plt.show()
# Out:
# 🤔 Question:
# What percentage of training enrollments are completed vs. in progress vs. planned?
# Break down by training category.
#
# Return data with columns: category, status, percentage
# where status is one of: Completed, In Progress, Planned
# and percentage is the percent of total for that category.
#
# IMPORTANT: Write a simple query using subqueries in the FROM clause.
# Do NOT use WITH clauses or CTEs - they are causing syntax errors.
# Use inline subqueries instead.
#
#
# 📝 Generated SQL:
# SELECT
#     category,
#     status,
#     ROUND((COUNT(*) * 100.0) / (
#         SELECT COUNT(*)
#         FROM training_records tr2
#         WHERE tr2.category = tr.category
#     ), 2) AS percentage
# FROM training_records tr
# GROUP BY category, status
# ORDER BY category, status;
#
# ✓ Query returned 18 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: Based on the training enrollment data, there's a consistent pattern across all categories where approximately 60-65% of enrollments are completed, with Compliance having the lowest completion rate at 58.46% while Leadership and Soft Skills lead at 65%.
#
# A key insight is that enrolled students (those who haven't started) represent a significant opportunity, ranging from 14.77% to 21.54% across categories, with Compliance showing the highest percentage of unused enrollments at 21.54%.
#
# I recommend implementing targeted engagement strategies for enrolled students, particularly in Compliance training, to convert the 21.54% enrolled rate into active participation and reduce the completion gap compared to other categories.
#
#
# ================================================================================
# DATA RESULTS
# ================================================================================
#         category       status  percentage
# 0     Compliance    Completed       58.46
# 1     Compliance     Enrolled       21.54
# 2     Compliance  In Progress       20.00
# 3     Leadership    Completed       65.00
# 4     Leadership     Enrolled       20.00
# 5     Leadership  In Progress       15.00
# 6   Professional    Completed       64.77
# 7   Professional     Enrolled       14.77
# 8   Professional  In Progress       20.45
# 9          Sales    Completed       61.29
# 10         Sales     Enrolled       16.13
# 11         Sales  In Progress       22.58
# 12   Soft Skills    Completed       65.43
# 13   Soft Skills     Enrolled       14.81
# 14   Soft Skills  In Progress       19.75
# 15     Technical    Completed       64.66
# 16     Technical     Enrolled       17.29
# 17     Technical  In Progress       18.05

# %%
# Business Insight for Question 8
from db_utils import generate_business_insight

print("\n" + "="*80)
print("GENERATING BUSINESS INSIGHT...")
print("="*80)

insight = generate_business_insight(result_q8, client)
print(insight)
# Out:
# ================================================================================
# GENERATING BUSINESS INSIGHT...
# ================================================================================
# BUSINESS INSIGHT - Training Program Completion and Engagement Analysis
#
# Key Findings:
# - Compliance training shows the lowest completion rate at 58.46%, significantly lagging behind other categories which average 64-65% completion
# - Leadership and Soft Skills training demonstrate the highest completion rates at 65.00% and 65.43% respectively, indicating strong employee engagement in these areas
# - Across all training categories, approximately 15-22% of enrollments remain "Enrolled" (planned but not started), representing underutilized training investments
# - Technical training maintains a solid 64.66% completion rate with the lowest "In Progress" percentage at 18.05%, suggesting efficient program delivery
#
# Observations:
# - There's a clear inverse relationship between completion rates and enrolled status - categories with higher completion rates tend to have fewer stalled enrollments
# - Compliance training's poor performance (58.46% completion, 21.54% enrolled) suggests potential issues with mandatory training engagement or program design
# - The relatively consistent "In Progress" rates (15-23% across categories) indicate similar pacing challenges across all training types
# - Leadership and Soft Skills categories outperforming technical categories suggests employees may be more motivated by career development than technical skill building
#
# Recommendations:
# - Redesign the Compliance training program to improve engagement through shorter modules, gamification, or mandatory completion deadlines to address the 21.54% enrolled but inactive participants
# - Implement automated reminders and progress tracking for the 15-22% of employees stuck in "Enrolled" status across all categories to convert passive registrations into active participation
# - Replicate successful elements from Leadership and Soft Skills programs (delivery method, content structure, or incentives) to boost completion rates in underperforming categories
# - Establish category-specific completion targets with manager accountability, particularly focusing on moving Compliance training above the 60% threshold
#
# Single Highest Impact:
# - Launch an immediate intervention for Compliance training by implementing mandatory completion deadlines with manager escalation, as this category's poor performance (58.46% completion, 21.54% inactive) likely represents the highest regulatory and business risk while affecting the largest number of employees.

# %% [markdown]
# ## Question 9: Manager Effectiveness
#
# *For each manager, show how many direct reports they have and the average performance rating of their team (from 2024 reviews).*
#
# **Visualization hint**: Scatter plot: team size vs avg rating

# %%
# Question 9: Manager Effectiveness
result_q9 = engine.ask('''
For each manager, show how many direct reports they have and the average performance rating 
of their team from 2024 reviews.
Create a scatter plot with team size on the x-axis and average team performance rating on the y-axis.
''', visualize=True)

# Display results
print("\n" + "="*80)
print("DATA RESULTS")
print("="*80)
print(result_q9['data'])

# Use safe_visualize
from db_utils import safe_visualize
safe_visualize(result_q9)
# Out:
# 🤔 Question:
# For each manager, show how many direct reports they have and the average performance rating
# of their team from 2024 reviews.
# Create a scatter plot with team size on the x-axis and average team performance rating on the y-axis.
#
#
# 📝 Generated SQL:
# SELECT
#     m.first_name || ' ' || m.last_name AS manager_name,
#     COUNT(e.emp_id) AS team_size,
#     ROUND(AVG(pr.rating), 2) AS avg_team_rating
# FROM employees m
# JOIN employees e ON m.emp_id = e.manager_id
# JOIN performance_reviews pr ON e.emp_id = pr.emp_id
# WHERE pr.review_year = 2024
#     AND m.employment_status = 'Active'
#     AND e.employment_status = 'Active'
# GROUP BY m.emp_id, m.first_name, m.last_name
# ORDER BY team_size DESC, avg_team_rating DESC;
#
# ✓ Query returned 18 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: Based on the data, there appears to be a weak negative correlation between team size and average performance ratings, with smaller teams generally achieving higher ratings. Notably, managers with 1-3 direct reports show significantly higher average ratings (ranging from 2.33 to 4.67, with several above 4.0), while larger teams of 9+ members cluster around 3.64-3.89.
#
# The standout insight is that Nicole Johnson manages to maintain an exceptional 4.67 average rating with 3 team members, suggesting an optimal balance of manageable team size and strong leadership. I recommend investigating the management practices of high-performing small team leaders like Nicole Johnson and Michael Roberts (4.50 rating, 2 reports) to develop training programs for managers of larger teams, particularly those like Steven Garcia whose 3-person team averages only 2.33.
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
#
# ================================================================================
# DATA RESULTS
# ================================================================================
#        manager_name  team_size  avg_team_rating
# 0     Robert Carter         14             3.64
# 1    Timothy Wright         12             3.67
# 2    Jessica Howard         11             3.82
# 3   Victor Campbell          9             3.89
# 4       Megan Clark          7             3.29
# 5         Elena Lee          5             3.80
# 6       Grace Moore          4             3.50
# 7    Nicole Johnson          3             4.67
# 8     Miguel Brooks          3             4.00
# 9     Ashley Wright          3             3.67
# 10  Nathan Thompson          3             3.00
# 11    Steven Garcia          3             2.33
# 12  Michael Roberts          2             4.50
# 13   Timothy Garcia          2             3.50
# 14     Brian Wright          2             3.50
# 15    James Sanchez          2             3.00
# 16   Sophia Stewart          1             4.00
# 17       Omar Lewis          1             3.00
# ✓ Visualization generated successfully

# %%
# Business Insight for Question 9
from db_utils import generate_business_insight

print("\n" + "="*80)
print("GENERATING BUSINESS INSIGHT...")
print("="*80)

insight = generate_business_insight(result_q9, client)
print(insight)
# Out:
# ================================================================================
# GENERATING BUSINESS INSIGHT...
# ================================================================================
# BUSINESS INSIGHT - Manager Performance and Team Size Analysis
#
# Key Findings:
# - Team sizes vary dramatically from 1 to 14 direct reports, with Robert Carter managing the largest team (14 employees) but achieving only a 3.64 average rating
# - Smaller teams consistently outperform larger teams, with managers of 3 or fewer employees achieving the top performance ratings (Nicole Johnson at 4.67, Michael Roberts at 4.50)
# - Seven managers (39% of leadership) have teams with below-average performance ratings of 3.50 or lower, including Steven Garcia's concerning 2.33 average
# - The data reveals a clear inverse relationship between team size and performance quality across 18 active managers overseeing 88 total employees
#
# Observations:
# - Managers with 7+ direct reports struggle to maintain high team performance, with none exceeding a 3.89 average rating despite representing 50% of all managed employees
# - The performance gap is significant: top-performing small team managers (4.67 rating) outperform large team managers by over 1 full rating point
# - Mid-sized teams (4-6 reports) show mixed results, suggesting team size alone isn't the only factor but remains a strong predictor of performance outcomes
# - Several managers appear to be operating beyond their effective span of control, particularly those with 9+ direct reports showing consistently lower team ratings
#
# Recommendations:
# - Immediately redistribute team members from managers overseeing 10+ employees to create more balanced team structures with 6-8 direct reports maximum
# - Implement targeted coaching programs for the 7 underperforming managers, starting with Steven Garcia (2.33 rating) and Nathan Thompson (3.00 rating)
# - Establish formal span-of-control guidelines preventing any single manager from exceeding 8-9 direct reports without senior leadership approval
# - Create a mentorship program pairing high-performing small team managers (like Nicole Johnson and Michael Roberts) with struggling large team managers
#
# Single Highest Impact:
# - Restructure Robert Carter's and Timothy Wright's oversized teams by redistributing 4-6 employees each to managers currently handling 1-3 reports, which could immediately improve performance outcomes for 20+ employees while establishing sustainable management ratios across the organization.

# %% [markdown]
# ## Question 10: Tenure vs. Performance
#
# *Is there a relationship between how long an employee has been at the company (tenure in years) and their latest performance rating?*
#
# **Visualization hint**: Scatter plot with trend line

# %%
# Question 10: Tenure vs. Performance
result_q10 = engine.ask('''
Show the relationship between employee tenure and performance rating.
Calculate tenure as years since hire_date.
Get the most recent performance rating for each employee.

Return ONLY two columns: tenure_years and latest_rating

IMPORTANT: Use a simple query with inline subqueries.
Do NOT use WITH clauses or CTEs.

Create a scatter plot with tenure on x-axis and rating on y-axis with trend line.
''', visualize=True)

# Display results
print("\n" + "="*80)
print("DATA RESULTS")
print("="*80)
print(result_q10['data'])

# Use safe_visualize
from db_utils import safe_visualize
safe_visualize(result_q10)
# Out:
# 🤔 Question:
# Show the relationship between employee tenure and performance rating.
# Calculate tenure as years since hire_date.
# Get the most recent performance rating for each employee.
#
# Return ONLY two columns: tenure_years and latest_rating
#
# IMPORTANT: Use a simple query with inline subqueries.
# Do NOT use WITH clauses or CTEs.
#
# Create a scatter plot with tenure on x-axis and rating on y-axis with trend line.
#
#
# 📝 Generated SQL:
# SELECT
#     ROUND((julianday('now') - julianday(e.hire_date)) / 365.25, 2) AS tenure_years,
#     (SELECT pr.rating
#      FROM performance_reviews pr
#      WHERE pr.emp_id = e.emp_id
#      ORDER BY pr.review_year DESC, pr.review_date DESC
#      LIMIT 1) AS latest_rating
# FROM employees e
# WHERE e.employment_status = 'Active'
#     AND (SELECT pr.rating
#          FROM performance_reviews pr
#          WHERE pr.emp_id = e.emp_id
#          ORDER BY pr.review_year DESC, pr.review_date DESC
#          LIMIT 1) IS NOT NULL;
#
# ✓ Query returned 102 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: Based on the scatter plot analysis of 100 employees, there appears to be a slight negative correlation between tenure and performance ratings, with longer-tenured employees showing marginally lower average ratings. Notably, employees with 8+ years of tenure (like those at 9.05, 10.85, and 11.19 years) predominantly receive ratings of 3-4, while newer employees show more variation including several 5-ratings at lower tenure levels (1.88, 2.00, 2.90 years).
#
# **Key Insight**: The data suggests potential performance stagnation among long-tenured employees, with very few employees above 7 years receiving the highest rating of 5.
#
# **Actionable Recommendation**: Implement targeted development programs and stretch assignments for employees with 6+ years tenure to reinvigorate performance and prevent career plateau, while also investigating if newer employees receiving top ratings have different skill sets or motivational factors that could be leveraged company-wide.
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
#
# ================================================================================
# DATA RESULTS
# ================================================================================
#      tenure_years  latest_rating
# 0            9.69              4
# 1            9.05              3
# 2            5.30              3
# 3            7.34              4
# 4            6.10              5
# ..            ...            ...
# 97           1.88              5
# 98           2.47              3
# 99           6.38              2
# 100          6.47              4
# 101          5.19              5
#
# [102 rows x 2 columns]
# ✓ Visualization generated successfully

# %%
# Business Insight for Question 10
from db_utils import generate_business_insight

print("\n" + "="*80)
print("GENERATING BUSINESS INSIGHT...")
print("="*80)

insight = generate_business_insight(result_q10, client)
print(insight)
# Out:
# ================================================================================
# GENERATING BUSINESS INSIGHT...
# ================================================================================
# BUSINESS INSIGHT - Employee Tenure vs Performance Analysis
#
# Key Findings:
# - 102 active employees analyzed with tenure ranging from 1.83 to 11.19 years, showing a mature workforce with significant institutional knowledge
# - Performance ratings distributed across all levels (1-5), with rating 4 being most common (37 employees, 36%) followed by rating 3 (33 employees, 32%)
# - Only 5 employees (5%) received the lowest rating of 1 or 2, indicating generally solid performance across the organization
# - High performers (rating 5) represent 17 employees (17%) and are distributed across all tenure levels from 1.88 to 7.01 years
#
# Observations:
# - No clear correlation exists between tenure and performance ratings - both new hires (under 3 years) and veterans (over 8 years) show similar performance distributions
# - Several long-tenured employees (6+ years) are underperforming with ratings of 2-3, suggesting potential disengagement or skill gaps
# - Top performers (rating 5) cluster primarily in the 2-7 year tenure range, indicating this may be the peak productivity period
# - The lack of tenure-performance correlation suggests current development and retention strategies may not be effectively leveraging experience
#
# Recommendations:
# - Implement targeted development programs for long-tenured employees (7+ years) showing declining performance to re-engage and upskill this valuable group
# - Create formal mentorship programs pairing high-performing mid-tenure employees (3-7 years) with both newer hires and senior staff
# - Conduct stay interviews with top performers in the 2-7 year range to understand retention drivers and replicate conditions for sustained high performance
# - Establish performance improvement plans for the 5 employees with ratings of 1-2, focusing on skill development rather than tenure-based assumptions
#
# Single Highest Impact:
# - Launch a comprehensive engagement and development initiative for employees with 7+ years tenure showing performance ratings of 3 or below, as this represents 15+ employees with significant institutional knowledge at risk of continued decline, potentially affecting team morale and organizational effectiveness.

# %% [markdown]
# ## Question 11: Department Budget Utilization
#
# *Compare each department's annual budget to its total payroll (sum of salaries). Which departments are over/under budget?*
#
# **Visualization hint**: Grouped bar: budget vs payroll

# %%
# Question 11: Department Budget Utilization
result_q11 = engine.ask('''
Compare each department's annual budget to its total payroll (sum of salaries). 
Which departments are over or under budget?
Create a grouped bar chart with departments on the x-axis and separate bars for annual budget and total payroll.
''', visualize=True)

# Display results
print("\n" + "="*80)
print("DATA RESULTS")
print("="*80)
print(result_q11['data'])

# Use safe_visualize
from db_utils import safe_visualize
safe_visualize(result_q11)
# Out:
# 🤔 Question:
# Compare each department's annual budget to its total payroll (sum of salaries).
# Which departments are over or under budget?
# Create a grouped bar chart with departments on the x-axis and separate bars for annual budget and total payroll.
#
#
# 📝 Generated SQL:
# SELECT
#     d.dept_name,
#     d.annual_budget,
#     COALESCE(SUM(e.salary), 0) AS total_payroll,
#     CASE
#         WHEN COALESCE(SUM(e.salary), 0) > d.annual_budget THEN 'Over Budget'
#         WHEN COALESCE(SUM(e.salary), 0) < d.annual_budget THEN 'Under Budget'
#         ELSE 'On Budget'
#     END AS budget_status,
#     ROUND(((COALESCE(SUM(e.salary), 0) - d.annual_budget) * 100.0 / d.annual_budget), 2) AS budget_variance_pct
# FROM departments d
# LEFT JOIN employees e ON d.dept_id = e.dept_id
#     AND e.employment_status = 'Active'
# GROUP BY d.dept_id, d.dept_name, d.annual_budget
# ORDER BY d.dept_name
#
# ✓ Query returned 8 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: ## Key Business Insights
#
# **Budget vs. Payroll Analysis:** Only 2 out of 8 departments exceed their payroll budgets - Data Science (58.87% over at $2.38M vs $1.5M budget) and Finance (8.73% over at $1.20M vs $1.1M budget). The remaining departments are significantly under budget, with Human Resources showing the largest gap at 37.11% under budget.
#
# **Key Insight:** Data Science represents the most critical budget variance, consuming nearly $900K more in payroll than allocated, which suggests either understaffing in the budget planning or rapid team expansion to meet business demands.
#
# **Actionable Recommendation:** Immediately review Data Science's headcount and compensation structure to understand the 58.87% budget overrun, and consider reallocating unused budget from departments like Human Resources (-37.11%) and Marketing (-35.36%) to better align resources with actual staffing needs.
#
# **Visual Recommendation:** The grouped bar chart should clearly highlight Data Science's significant overrun compared to other departments' conservative spending patterns.
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
#
# ================================================================================
# DATA RESULTS
# ================================================================================
#           dept_name  annual_budget  total_payroll budget_status  \
# 0  Customer Support         850000         690000  Under Budget
# 1      Data Science        1500000        2383000   Over Budget
# 2       Engineering        3200000        2927000  Under Budget
# 3           Finance        1100000        1196000   Over Budget
# 4   Human Resources         900000         566000  Under Budget
# 5         Marketing        1400000         905000  Under Budget
# 6           Product        1800000        1383000  Under Budget
# 7             Sales        2100000        1602000  Under Budget
#
#    budget_variance_pct
# 0               -18.82
# 1                58.87
# 2                -8.53
# 3                 8.73
# 4               -37.11
# 5               -35.36
# 6               -23.17
# 7               -23.71
# ✓ Visualization generated successfully

# %%
# Business Insight for Question 11
from db_utils import generate_business_insight

print("\n" + "="*80)
print("GENERATING BUSINESS INSIGHT...")
print("="*80)

insight = generate_business_insight(result_q11, client)
print(insight)
# Out:
# ================================================================================
# GENERATING BUSINESS INSIGHT...
# ================================================================================
# BUSINESS INSIGHT - Departmental Budget vs Payroll Analysis
#
# Key Findings:
# - Data Science is significantly over budget at $2.38M payroll against $1.5M budget (+58.87%), representing an $883K overage
# - Six out of eight departments are under budget, with Human Resources showing the largest gap at -37.11% ($334K under budget)
# - Only two departments exceed their budgets: Data Science (+$883K) and Finance (+$96K)
# - Total company-wide payroll is $11.65M against allocated budgets of $12.85M, indicating $1.2M in unallocated budget capacity
#
# Observations:
# - Data Science's massive budget overrun suggests either unrealistic initial budgeting or uncontrolled hiring/compensation growth
# - Marketing and Human Resources show concerning under-utilization (35% and 37% respectively), potentially indicating understaffing in critical support functions
# - Engineering maintains good budget discipline at only 8.53% under budget while likely being a revenue-generating department
# - The pattern suggests budget allocation may not align with actual business priorities or market demands for talent
#
# Recommendations:
# - Immediately audit Data Science department's headcount, salary benchmarks, and hiring practices to understand the $883K overage
# - Reallocate unused budget from under-performing departments (HR, Marketing) to fund Data Science operations properly
# - Conduct workforce planning analysis for Marketing and HR to determine if understaffing is impacting business performance
# - Implement monthly budget monitoring and approval processes for departments historically exceeding budgets by >10%
#
# Single Highest Impact:
# - Restructure Data Science's budget allocation and implement immediate spending controls, as the 59% overage represents 75% of total company budget variance and poses the greatest financial risk to organizational budget integrity.

# %% [markdown]
# ## Question 12: Cross-Functional Collaboration
#
# *Which employees work on projects outside their own department? Show their name, home department, and the project department.*
#
# **Visualization hint**: This is a complex multi-table JOIN — review the SQL carefully\!

# %%
# Question 12: Cross-Functional Collaboration
result_q12 = engine.ask('''
Which employees work on projects outside their own department? 
Show their name, home department, and the project department.
Create a bar chart showing the count of cross-functional collaborations by department.
''', visualize=True)

# Display results
print("\n" + "="*80)
print("DATA RESULTS")
print("="*80)
print(result_q12['data'])

# Use safe_visualize
from db_utils import safe_visualize
safe_visualize(result_q12)
# Out:
# 🤔 Question:
# Which employees work on projects outside their own department?
# Show their name, home department, and the project department.
# Create a bar chart showing the count of cross-functional collaborations by department.
#
#
# 📝 Generated SQL:
# SELECT
#     e.first_name || ' ' || e.last_name AS employee_name,
#     home_dept.dept_name AS home_department,
#     project_dept.dept_name AS project_department,
#     COUNT(*) AS collaboration_count
# FROM employees e
# JOIN departments home_dept ON e.dept_id = home_dept.dept_id
# JOIN project_assignments pa ON e.emp_id = pa.emp_id
# JOIN projects p ON pa.project_id = p.project_id
# JOIN departments project_dept ON p.dept_id = project_dept.dept_id
# WHERE e.dept_id != p.dept_id
# GROUP BY e.emp_id, e.first_name, e.last_name, home_dept.dept_name, project_dept.dept_name
# ORDER BY home_dept.dept_name, e.last_name, e.first_name
#
# ✓ Query returned 24 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: Looking at the 24 cross-functional collaborations identified, **Data Science leads in cross-departmental engagement** with 6 instances, followed by Marketing, Product, and Sales departments with 4 collaborations each. Notably, Engineering is the most sought-after partner department, receiving collaboration requests from 4 different departments (Customer Support, Data Science, Finance, and Sales), suggesting it serves as a critical hub for technical expertise across the organization.
#
# **Recommendation:** Given that Human Resources has zero outgoing cross-functional collaborations while receiving requests from 4 departments (Data Science, Finance, Marketing, and Sales), the company should investigate whether HR has sufficient resources to support these partnerships and consider formalizing cross-departmental collaboration processes to ensure all teams can effectively contribute to and benefit from these relationships.
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
#
# ================================================================================
# DATA RESULTS
# ================================================================================
#       employee_name   home_department project_department  collaboration_count
# 0     Rachel Morris  Customer Support        Engineering                    1
# 1      Matthew Chen      Data Science        Engineering                    1
# 2     Ashley Howard      Data Science    Human Resources                    1
# 3          Omar Lee      Data Science            Finance                    1
# 4        Robert Lee      Data Science            Product                    1
# 5   Carlos Peterson      Data Science   Customer Support                    1
# 6   Carlos Peterson      Data Science            Finance                    1
# 7       Omar Garcia       Engineering              Sales                    1
# 8       Miguel Hill       Engineering          Marketing                    1
# 9   Ashley Thompson       Engineering          Marketing                    1
# 10        Omar Gray           Finance    Human Resources                    1
# 11        Omar Gray           Finance          Marketing                    1
# 12      Ananya Reed           Finance        Engineering                    1
# 13      Omar Brooks         Marketing              Sales                    1
# 14   Timothy Garcia         Marketing   Customer Support                    1
# 15        Lisa Wang         Marketing    Human Resources                    1
# 16  Michelle Wright         Marketing            Product                    1
# 17    Hannah Carter           Product              Sales                    1
# 18   Nicole Johnson           Product              Sales                    1
# 19     Chloe Nelson           Product              Sales                    1
# 20    Ashley Wright           Product          Marketing                    1
# 21       David Gray             Sales        Engineering                    1
# 22   Rachel Ramirez             Sales          Marketing                    1
# 23     Sarah Taylor             Sales    Human Resources                    1
# ✓ Visualization generated successfully

# %%
# Business Insight for Question 12
from db_utils import generate_business_insight

print("\n" + "="*80)
print("GENERATING BUSINESS INSIGHT...")
print("="*80)

insight = generate_business_insight(result_q12, client)
print(insight)
# Out:
# ================================================================================
# GENERATING BUSINESS INSIGHT...
# ================================================================================
# BUSINESS INSIGHT - Cross-Functional Project Collaboration Analysis
#
# Key Findings:
# • 24 instances of cross-departmental collaboration involving employees from all 8 departments, indicating widespread organizational flexibility
# • Data Science leads cross-functional participation with 6 collaborations (25% of total), while Product department shows highest external engagement with 4 employees working outside their department
# • Sales and Marketing departments demonstrate strong bi-directional collaboration, with 3 Sales employees working on Marketing projects and 1 Marketing employee on Sales projects
# • Carlos Peterson (Data Science) and Omar Gray (Finance) are the only employees with multiple cross-functional assignments, each participating in 2 different external projects
#
# Observations:
# • Data Science serves as a hub department, contributing expertise across 4 different departments (Engineering, HR, Finance, Product, Customer Support), suggesting high demand for analytical skills organization-wide
# • Product department employees exclusively collaborate with Sales (3 instances) and Marketing (1 instance), indicating strong alignment with customer-facing functions
# • Human Resources receives cross-functional support from 4 different departments but shows limited outbound collaboration, suggesting an internal service model
# • Engineering shows balanced collaboration patterns, both receiving external talent (2 instances) and contributing to external projects (2 instances)
#
# Recommendations:
# • Formalize the Data Science center of excellence model by creating structured consulting processes to better manage the high demand for analytical support across departments
# • Establish regular cross-functional project showcases to share learnings and best practices from successful collaborations, particularly the Sales-Marketing partnership model
# • Develop retention strategies for high-collaboration employees like Carlos Peterson and Omar Gray, as they demonstrate valuable cross-departmental expertise and institutional knowledge
# • Create rotation programs between Product, Sales, and Marketing teams to institutionalize their natural collaboration patterns and develop more versatile customer-focused talent
#
# Single Highest Impact:
# • Implement a formal Data Science consulting framework with dedicated capacity allocation across departments, as this would systematize the already high demand for analytical expertise and ensure strategic projects receive proper data science support while preventing resource conflicts.

# %% [markdown]
# ---
#
# # Part 4: Building the LLM-Powered Auto-Visualizer
#
# You already implemented  (TODO 13-14). Now let's put it to serious use — building a reusable function that takes any question, generates SQL, runs it, and automatically creates the best visualization.

# %%
def ask_and_visualize(engine, question):
    """
    Complete pipeline: question -> SQL -> data -> auto-visualization.

    Uses the engine to generate SQL and data, then uses Claude to
    generate appropriate matplotlib/seaborn code for the results.
    """
    # Step 1: Get the data
    result = engine.ask(question, show_sql=True, interpret=True, visualize=True)

    if not result['success'] or result['data'] is None:
        print("Query failed — cannot visualize.")
        return result

    df = result['data']

    # Step 2: Try auto-generated visualization
    if result.get('viz_code'):
        print("\n--- Auto-Generated Visualization ---")
        try:
            exec(result['viz_code'])
            plt.show()
        except Exception as e:
            print(f"Auto-viz failed: {e}")
            print("Falling back to basic chart...")

            # Fallback: simple automatic chart
            numeric_cols = df.select_dtypes(include='number').columns.tolist()
            non_numeric = [c for c in df.columns if c not in numeric_cols]

            if numeric_cols and non_numeric:
                fig, ax = plt.subplots(figsize=(10, 5))
                df.plot(x=non_numeric[0], y=numeric_cols[0], kind='bar', ax=ax)
                ax.set_title(question[:60])
                plt.tight_layout()
                plt.show()

    return result

# %%
# Demo: Ask a complex question and get auto-visualization
result = ask_and_visualize(engine, 
    "Show the average salary and average performance rating by department for 2024"
)
# Out:
# 🤔 Question: Show the average salary and average performance rating by department for 2024
#
# 📝 Generated SQL:
# SELECT
#     d.dept_name,
#     ROUND(AVG(e.salary), 2) AS avg_salary,
#     ROUND(AVG(pr.rating), 2) AS avg_performance_rating
# FROM departments d
# JOIN employees e ON d.dept_id = e.dept_id
# LEFT JOIN performance_reviews pr ON e.emp_id = pr.emp_id AND pr.review_year = 2024
# WHERE e.employment_status = 'Active'
# GROUP BY d.dept_id, d.dept_name
# ORDER BY d.dept_name
#
# ✓ Query returned 8 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: Based on the 2024 data, there's a clear correlation between compensation and performance, with Data Science ($140,176) and Engineering ($121,958) commanding the highest salaries while also delivering strong performance ratings of 3.67 and 3.71 respectively. Notably, the Product department stands out with the highest average performance rating of 3.91 despite having a lower salary than the technical departments at $125,727.
#
# I recommend conducting a compensation review for Customer Support, which shows the lowest average salary at $69,000 but maintains a reasonable performance rating of 3.20, suggesting potential retention risks. Additionally, consider implementing performance-based incentives across all departments to help bridge the gap between high-performing teams and compensation levels.
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
#
# --- Auto-Generated Visualization ---

# %%
# Another demo with a different chart type
result = ask_and_visualize(engine,
    "What percentage of employees are Remote, Hybrid, and On-site in each department?"
)
# Out:
# 🤔 Question: What percentage of employees are Remote, Hybrid, and On-site in each department?
#
# 📝 Generated SQL:
# SELECT
#     d.dept_name,
#     e.work_mode,
#     COUNT(*) AS employee_count,
#     ROUND(COUNT(*) * 100.0 / dept_totals.total_employees, 2) AS percentage
# FROM employees e
# JOIN departments d ON e.dept_id = d.dept_id
# JOIN (
#     SELECT
#         dept_id,
#         COUNT(*) AS total_employees
#     FROM employees
#     WHERE employment_status = 'Active'
#     GROUP BY dept_id
# ) dept_totals ON e.dept_id = dept_totals.dept_id
# WHERE e.employment_status = 'Active'
# GROUP BY d.dept_name, e.work_mode, dept_totals.total_employees
# ORDER BY d.dept_name, e.work_mode
#
# ✓ Query returned 22 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: Based on the data, there's significant variation in work mode preferences across departments, with Marketing (55.6% hybrid) and Product (63.6% hybrid) showing the strongest preference for hybrid work, while Customer Support maintains the highest on-site presence at 50%. Notably, Marketing and Product departments have completely eliminated on-site work, suggesting these roles can be effectively performed remotely or in hybrid arrangements.
#
# I recommend conducting a detailed analysis of productivity and collaboration metrics in Marketing and Product to determine if their fully flexible work models could be successfully implemented in other departments, particularly in Customer Support where 50% of employees are still required on-site. This could help optimize the company's overall workspace strategy and potentially reduce real estate costs while maintaining operational effectiveness.
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
#
# --- Auto-Generated Visualization ---

# %%
# Test with another question
result = engine.ask("How many employees per department?", visualize=True)
df = result['data']
exec(result['viz_code'])
plt.show()
# Out:
# 🤔 Question: How many employees per department?
#
# 📝 Generated SQL:
# SELECT
#     d.dept_name,
#     COUNT(e.emp_id) AS employee_count
# FROM departments d
# LEFT JOIN employees e ON d.dept_id = e.dept_id
# WHERE e.employment_status = 'Active'
# GROUP BY d.dept_id, d.dept_name
# ORDER BY employee_count DESC
#
# ✓ Query returned 8 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: Based on the data, Engineering is clearly our largest department with 24 employees, followed by Sales (18) and Data Science (17), which aligns well with a technology company's focus on product development and revenue generation. However, support functions like Human Resources (6 employees) and Customer Support (10 employees) appear significantly understaffed relative to our total workforce of 107 employees.
#
# I recommend prioritizing hiring in Customer Support, as a ratio of 10 support staff to 107 total employees (about 9%) may be insufficient to maintain service quality as the company scales. Additionally, consider whether HR capacity is adequate to support recruitment and employee management across all departments.
#
# 📊 Generating visualization code...
# ✓ Visualization code generated

# %% [markdown]
# ## Challenge: Improve the Visualizer
#
# The auto-visualizer works but isn't perfect. Try improving it:
#
# 1. **Better prompts**: Modify `generate_visualization_code()` in `text2sql_engine.py` to produce better charts. Add rules about color schemes, figure sizes, and annotation.
#
# 2. **Error recovery**: What happens when the generated code fails? Implement a smarter fallback that looks at the data shape and picks an appropriate chart automatically.
#
# 3. **Multiple charts**: For complex queries (e.g., salary distribution), generate multiple visualizations (histogram + box plot).

# %%
# ============================================================================
# BONUS QUESTION: Multi-Chart Salary Distribution Analysis
# ============================================================================
# Demonstrating multiple complementary visualizations for distribution data

print("\n" + "="*80)
print("BONUS: SALARY DISTRIBUTION - MULTI-CHART ANALYSIS")
print("="*80)

result_bonus = engine.ask('''
Show the distribution of all employee salaries.
Return only the salary column for active employees.
''', visualize=False)

# Display results
print("\n" + "="*80)
print("DATA RESULTS")
print("="*80)
print(f"Total employees: {len(result_bonus['data'])}")
print(f"Salary range: ${result_bonus['data']['salary'].min():,.0f} - ${result_bonus['data']['salary'].max():,.0f}")
print(f"Mean: ${result_bonus['data']['salary'].mean():,.0f}")
print(f"Median: ${result_bonus['data']['salary'].median():,.0f}")

# Multi-Chart Visualization
if result_bonus['success'] and result_bonus['data'] is not None:
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np
    
    df = result_bonus['data']
    
    # Create figure with 3 subplots
    sns.set_style("darkgrid")
    fig, axes = plt.subplots(1, 3, figsize=(18, 7))
    
    # Chart 1: Histogram
    axes[0].hist(df['salary'], bins=20, color='steelblue', edgecolor='black', linewidth=1.2)
    axes[0].set_xlabel('Salary ($)', fontsize=12)
    axes[0].set_ylabel('Frequency', fontsize=12)
    axes[0].set_title('Histogram\n(Distribution Shape)', fontsize=14, fontweight='bold')
    axes[0].tick_params(axis='both', which='both', length=6, width=1.5)
    
    # Add mean/median lines
    axes[0].axvline(df['salary'].mean(), color='coral', linestyle='--', linewidth=2, label=f'Mean: ${df["salary"].mean():,.0f}')
    axes[0].axvline(df['salary'].median(), color='mediumseagreen', linestyle='--', linewidth=2, label=f'Median: ${df["salary"].median():,.0f}')
    axes[0].legend(fontsize=10)
    
    # Chart 2: Box Plot
    bp = axes[1].boxplot(df['salary'], patch_artist=True, widths=0.5,
                         boxprops=dict(facecolor='steelblue', edgecolor='black', linewidth=1.2),
                         whiskerprops=dict(color='black', linewidth=1.2),
                         capprops=dict(color='black', linewidth=1.2),
                         medianprops=dict(color='coral', linewidth=2))
    axes[1].set_ylabel('Salary ($)', fontsize=12)
    axes[1].set_title('Box Plot\n(Quartiles & Outliers)', fontsize=14, fontweight='bold')
    axes[1].tick_params(axis='both', which='both', length=6, width=1.5)
    axes[1].set_xticks([1])
    axes[1].set_xticklabels(['Salaries'])
    
    # Chart 3: Violin Plot
    parts = axes[2].violinplot([df['salary']], showmeans=True, showmedians=True, widths=0.7)
    for pc in parts['bodies']:
        pc.set_facecolor('steelblue')
        pc.set_edgecolor('black')
        pc.set_linewidth(1.2)
        pc.set_alpha(0.8)
    parts['cmeans'].set_color('coral')
    parts['cmedians'].set_color('mediumseagreen')
    axes[2].set_ylabel('Salary ($)', fontsize=12)
    axes[2].set_title('Violin Plot\n(Density Distribution)', fontsize=14, fontweight='bold')
    axes[2].tick_params(axis='both', which='both', length=6, width=1.5)
    axes[2].set_xticks([1])
    axes[2].set_xticklabels(['Salaries'])
    
    # Overall title
    plt.suptitle('Employee Salary Distribution - Multiple Perspectives', 
                 fontsize=18, fontweight='bold', y=1.02)
    plt.tight_layout()
    plt.show()
    
    print("\n✓ Multi-chart visualization displayed")
    print("  - Histogram shows the distribution shape")
    print("  - Box plot reveals quartiles and outliers")
    print("  - Violin plot shows density at different salary levels")
# Out:
# ================================================================================
# BONUS: SALARY DISTRIBUTION - MULTI-CHART ANALYSIS
# ================================================================================
#
# 🤔 Question:
# Show the distribution of all employee salaries.
# Return only the salary column for active employees.
#
#
# 📝 Generated SQL:
# SELECT salary
# FROM employees
# WHERE employment_status = 'Active'
#
# ✓ Query returned 107 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: Based on the salary distribution of 102 active employees, there's a significant pay disparity with salaries ranging from $47,000 to $200,000 - a gap of over $150,000. The data shows a concentration of salaries in two main bands: lower-tier positions around $50,000-$80,000 and higher-tier roles around $100,000-$180,000, suggesting a distinct separation between junior and senior/specialized positions.
#
# I recommend conducting a comprehensive pay equity analysis to ensure compensation aligns with role levels, experience, and performance, as this wide distribution could indicate potential inconsistencies in our compensation framework that may impact employee retention and satisfaction.
#
#
# ================================================================================
# DATA RESULTS
# ================================================================================
# Total employees: 107
# Salary range: $47,000 - $200,000
# Mean: $108,897
# Median: $102,000
# ✓ Multi-chart visualization displayed
#   - Histogram shows the distribution shape
#   - Box plot reveals quartiles and outliers
#   - Violin plot shows density at different salary levels

# %%
# ============================================================================
# PART 4 CHALLENGE 3: Automatic Multi-Chart Detection Test
# ============================================================================
# Demonstrating the engine's ability to automatically detect distribution
# queries and generate multiple complementary visualizations (histogram, 
# box plot, and violin plot) for comprehensive data analysis.
# ============================================================================
print("\n" + "="*80)
print("TESTING AUTOMATIC MULTI-CHART GENERATION")
print("="*80)

# Reload engine with updated TODO 13
import importlib
import text2sql_engine
importlib.reload(text2sql_engine)
from text2sql_engine import Text2SQLEngine

engine = Text2SQLEngine(conn, api_key=ANTHROPIC_API_KEY)

# Test 1: Should trigger multi-chart (distribution keyword + RAW DATA)
print("\n📊 Test 1: Distribution with raw continuous data")
result_dist1 = engine.ask('''
Calculate the tenure in years for each active employee (from hire_date to today).
Return one row per employee with: emp_id, tenure_years
Do NOT group, bin, or aggregate - return individual employee tenure values.
This is for distribution analysis showing spread of tenure across all employees.
''', visualize=True)

if result_dist1['success']:
    print(f"\nData shape: {result_dist1['data'].shape}")
    print(f"Columns: {result_dist1['data'].columns.tolist()}")
    print("\nFirst 5 rows:")
    print(result_dist1['data'].head())
    
    if result_dist1['viz_code']:
        print("\n" + "="*80)
        print("Generated code contains 'subplots'?", 'subplots' in result_dist1['viz_code'])
        print("="*80)
        
        df = result_dist1['data']
        exec(result_dist1['viz_code'])
        plt.show()

# Test 2: Should NOT trigger multi-chart (comparison)
print("\n📊 Test 2: Category comparison (should be single chart)")
result_single = engine.ask('''
How many employees in each department?
''', visualize=True)

if result_single['viz_code']:
    print("Generated code length:", len(result_single['viz_code']))
    print("Contains 'subplots':", 'subplots' in result_single['viz_code'])
    df = result_single['data']
    exec(result_single['viz_code'])
    plt.show()
# Out:
# ================================================================================
# TESTING AUTOMATIC MULTI-CHART GENERATION
# ================================================================================
# Building schema context...
# ✓ Schema loaded: 5698 characters
# Initializing Claude API...
# ✓ Claude API connected: Ready
#
# 📊 Test 1: Distribution with raw continuous data
#
# 🤔 Question:
# Calculate the tenure in years for each active employee (from hire_date to today).
# Return one row per employee with: emp_id, tenure_years
# Do NOT group, bin, or aggregate - return individual employee tenure values.
# This is for distribution analysis showing spread of tenure across all employees.
#
#
# 📝 Generated SQL:
# SELECT
#     e.emp_id,
#     ROUND((julianday('now') - julianday(e.hire_date)) / 365.25, 2) AS tenure_years
# FROM employees e
# WHERE e.employment_status = 'Active'
#
# ✓ Query returned 107 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: Looking at the tenure data across 101 active employees, there's a notable concentration of mid-tenure employees with most staff having between 3-7 years of experience, while only a few employees have been with the company for over 10 years (employee 26 at 11.19 years being the longest). The company appears to have experienced significant hiring activity in recent years, with about 15% of employees having less than 2 years tenure, including several very new hires like employee 116 at just 0.99 years.
#
# **Key insight:** The workforce shows a healthy mix but lacks senior institutional knowledge, with very few employees above 10 years tenure.
#
# **Recommendation:** Implement a formal mentorship program pairing the handful of 8+ year veterans (like employees 1, 2, 26, 27, 38, 60, 91, 102) with newer employees to preserve institutional knowledge and accelerate onboarding for the substantial population of employees with under 3 years tenure.
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
#
# Data shape: (107, 2)
# Columns: ['emp_id', 'tenure_years']
#
# First 5 rows:
#    emp_id  tenure_years
# 0       1          9.69
# 1       2          9.05
# 2       3          5.30
# 3       4          7.34
# 4       5          6.10
#
# ================================================================================
# Generated code contains 'subplots'? True
# ================================================================================
# 📊 Test 2: Category comparison (should be single chart)
#
# 🤔 Question:
# How many employees in each department?
#
#
# 📝 Generated SQL:
# SELECT d.dept_name, COUNT(e.emp_id) AS employee_count
# FROM departments d
# LEFT JOIN employees e ON d.dept_id = e.dept_id
# WHERE e.employment_status = 'Active'
# GROUP BY d.dept_id, d.dept_name
# ORDER BY employee_count DESC
#
# ✓ Query returned 8 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: Based on the employee distribution across departments, Engineering is clearly the largest department with 24 employees, followed by Sales (18) and Data Science (17), which aligns well with a technology company's focus on product development and growth. The data reveals that technical departments (Engineering + Data Science) comprise 41 out of 107 total employees, representing about 38% of the workforce.
#
# I recommend evaluating whether the Customer Support team of 10 employees is adequately sized to handle the customer base generated by the 18-person Sales team, as this ratio could impact customer satisfaction and retention if support becomes a bottleneck.
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
# Generated code length: 788
# Contains 'subplots': False

# %% [markdown]
# ---
#
# # Part 5: Prompt Engineering for Better SQL
#
# The quality of your question determines the quality of the SQL. Let's practice.

# %% [markdown]
# ## Prompt Engineering Strategies
#
# | Strategy | Vague | Specific |
# |----------|-------|----------|
# | **Name columns** | "Show salary info" | "Show first_name, last_name, salary, dept_name" |
# | **Specify aggregation** | "Department salaries" | "Average salary per department" |
# | **Request ordering** | "Show departments" | "Order by average salary descending" |
# | **Indicate JOINs** | "Employee projects" | "Show employees with their assigned project names" |
# | **Handle edge cases** | "Department employees" | "Include departments with zero employees (LEFT JOIN)" |
# | **Set limits** | "High earners" | "Top 10 employees by salary" |
# | **Specify date handling** | "Recent hires" | "Employees hired in 2024 or later" |

# %%
# Watch how prompt quality affects SQL quality

# VAGUE — unpredictable results
vague_sql = engine.get_sql_only("Tell me about employees")
print("VAGUE:")
print(vague_sql)
print()

# SPECIFIC — precise, correct SQL
specific_sql = engine.get_sql_only(
    "Show each employee's full name, department name, job title, salary, "
    "and years of tenure (calculated from hire_date to today). "
    "Only include active employees. Order by tenure descending. Limit to top 15."
)
print("SPECIFIC:")
print(specific_sql)
# Out:
# VAGUE:
# SELECT
#     e.emp_id,
#     e.first_name,
#     e.last_name,
#     e.email,
#     d.dept_name,
#     jt.title,
#     e.salary,
#     e.hire_date,
#     e.gender,
#     e.employment_status,
#     e.work_mode,
#     CASE
#         WHEN e.manager_id IS NOT NULL
#         THEN m.first_name || ' ' || m.last_name
#         ELSE 'No Manager'
#     END AS manager_name
# FROM employees e
# LEFT JOIN departments d ON e.dept_id = d.dept_id
# LEFT JOIN job_titles jt ON e.title_id = jt.title_id
# LEFT JOIN employees m ON e.manager_id = m.emp_id
# ORDER BY e.dept_id, e.salary DESC
#
# SPECIFIC:
# SELECT
#     e.first_name || ' ' || e.last_name AS full_name,
#     d.dept_name,
#     jt.title,
#     e.salary,
#     ROUND((julianday('now') - julianday(e.hire_date)) / 365.25, 2) AS years_tenure
# FROM employees e
# JOIN departments d ON e.dept_id = d.dept_id
# JOIN job_titles jt ON e.title_id = jt.title_id
# WHERE e.employment_status = 'Active'
# ORDER BY years_tenure DESC
# LIMIT 15

# %% [markdown]
# ## Exercise: Rewrite These Vague Prompts
#
# For each vague prompt below, rewrite it to be specific enough to generate correct multi-table SQL.

# %%
# Vague: "Show me raises"
# Improved: Specific version using salary_history + employees + departments
improved_raises = engine.ask('''
Show each employee's salary increases from the salary_history table.
Include: employee first name, last name, department name, old salary, new salary, 
salary increase amount, change date, and reason for the increase.
Join with employees and departments tables to get full context.
Only show increases from the past 2 years.
Order by increase amount (highest to lowest).
Limit to top 20 raises.
''', visualize=False)

print("\n" + "="*80)
print("IMPROVED RAISES QUERY RESULTS")
print("="*80)
if improved_raises['success']:
    print(improved_raises['data'])
# Out:
# 🤔 Question:
# Show each employee's salary increases from the salary_history table.
# Include: employee first name, last name, department name, old salary, new salary,
# salary increase amount, change date, and reason for the increase.
# Join with employees and departments tables to get full context.
# Only show increases from the past 2 years.
# Order by increase amount (highest to lowest).
# Limit to top 20 raises.
#
#
# 📝 Generated SQL:
# SELECT
#     e.first_name,
#     e.last_name,
#     d.dept_name,
#     sh.old_salary,
#     sh.new_salary,
#     ROUND(sh.new_salary - sh.old_salary, 2) AS salary_increase_amount,
#     sh.effective_date AS change_date,
#     sh.reason
# FROM salary_history sh
# JOIN employees e ON sh.emp_id = e.emp_id
# JOIN departments d ON e.dept_id = d.dept_id
# WHERE date(sh.effective_date) >= date('now', '-2 years')
#     AND sh.new_salary > sh.old_salary
# ORDER BY salary_increase_amount DESC
# LIMIT 20
#
# ✓ Query returned 20 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: **Key Insight:** The top salary increases are concentrated among promotions and role changes, with the highest individual raises reaching $16,000 (led by Sophia Stewart in HR, Ashley Howard and Fatima Harris in Data Science). Engineering dominates the list with 10 out of 20 employees, suggesting significant organizational growth or restructuring in technical roles.
#
# **Actionable Recommendation:** Given that only one employee (Jessica Howard) received a performance bonus among the top 20 raises, the company should consider implementing more performance-based salary increases to retain high performers who may not be ready for promotion or role changes. The concentration of large raises in Engineering ($11,000-$15,000 range) indicates this department may need a comprehensive compensation review to ensure internal equity.
#
#
# ================================================================================
# IMPROVED RAISES QUERY RESULTS
# ================================================================================
#    first_name last_name        dept_name  old_salary  new_salary  \
# 0      Sophia   Stewart  Human Resources    145000.0    161000.0
# 1      Ashley    Howard     Data Science    155000.0    171000.0
# 2      Fatima    Harris     Data Science    129000.0    145000.0
# 3     Timothy    Wright      Engineering    136000.0    151000.0
# 4      Nathan  Thompson            Sales    134000.0    149000.0
# 5         Raj       Cox      Engineering    139000.0    153000.0
# 6      Victor  Campbell      Engineering    155000.0    168000.0
# 7     Rebecca    Wilson      Engineering    119000.0    132000.0
# 8        Omar    Garcia      Engineering    120000.0    133000.0
# 9       Megan     Clark            Sales    111000.0    124000.0
# 10      Chloe    Nelson          Product    149000.0    162000.0
# 11     Thomas     Brown     Data Science    117000.0    130000.0
# 12       Mark  Thompson     Data Science    154000.0    167000.0
# 13   Jennifer     Clark      Engineering    104000.0    116000.0
# 14      Diana     Perez      Engineering    112000.0    124000.0
# 15      Andre    Nelson      Engineering    111000.0    123000.0
# 16    Jessica    Howard          Finance    163000.0    175000.0
# 17        Raj  Anderson     Data Science    117000.0    129000.0
# 18     Daniel    Parker      Engineering     97000.0    108000.0
# 19     Olivia   Ramirez      Engineering    129000.0    140000.0
#
#     salary_increase_amount change_date             reason
# 0                  16000.0  2024-06-23          Promotion
# 1                  16000.0  2024-04-08          Promotion
# 2                  16000.0  2024-10-23          Promotion
# 3                  15000.0  2024-04-25        Role Change
# 4                  15000.0  2024-06-19        Role Change
# 5                  14000.0  2024-05-16          Promotion
# 6                  13000.0  2024-07-17        Role Change
# 7                  13000.0  2024-10-18          Promotion
# 8                  13000.0  2024-10-13        Role Change
# 9                  13000.0  2024-06-09        Role Change
# 10                 13000.0  2024-04-11          Promotion
# 11                 13000.0  2024-10-27          Promotion
# 12                 13000.0  2024-07-19          Promotion
# 13                 12000.0  2024-04-02          Promotion
# 14                 12000.0  2024-03-29          Promotion
# 15                 12000.0  2024-06-28          Promotion
# 16                 12000.0  2024-06-09  Performance Bonus
# 17                 12000.0  2024-08-31        Role Change
# 18                 11000.0  2024-05-20        Role Change
# 19                 11000.0  2024-10-13        Role Change

# %%
# Vague: "Who's performing well?"
# Improved: Specific version using performance_reviews + employees + job_titles
improved_performance = engine.ask('''
Show employees who received "Exceeds Expectations" or "Outstanding" ratings 
in their most recent performance review (2024).
Include: employee first name, last name, job title name, career level, 
current salary, latest performance rating, and review date.
Join performance_reviews with employees and job_titles tables.
Order by career level (highest first), then by salary (highest first).
Only include active employees.
''', visualize=False)

print("\n" + "="*80)
print("IMPROVED PERFORMANCE QUERY RESULTS")
print("="*80)
if improved_performance['success']:
    print(improved_performance['data'])
# Out:
# 🤔 Question:
# Show employees who received "Exceeds Expectations" or "Outstanding" ratings
# in their most recent performance review (2024).
# Include: employee first name, last name, job title name, career level,
# current salary, latest performance rating, and review date.
# Join performance_reviews with employees and job_titles tables.
# Order by career level (highest first), then by salary (highest first).
# Only include active employees.
#
#
# 📝 Generated SQL:
# SELECT
#     e.first_name,
#     e.last_name,
#     jt.title AS job_title_name,
#     jt.level AS career_level,
#     e.salary AS current_salary,
#     pr.rating AS latest_performance_rating,
#     pr.review_date
# FROM employees e
# JOIN job_titles jt ON e.title_id = jt.title_id
# JOIN performance_reviews pr ON e.emp_id = pr.emp_id
# WHERE e.employment_status = 'Active'
#     AND pr.review_year = 2024
#     AND pr.rating IN (4, 5)
# ORDER BY
#     CASE jt.level
#         WHEN 'Executive' THEN 1
#         WHEN 'Senior' THEN 2
#         WHEN 'Manager' THEN 3
#         ELSE 4
#     END,
#     e.salary DESC
#
# ✓ Query returned 61 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: **Key Insight:** The company has successfully identified 59 high-performing active employees across all career levels, with Executive-level employees commanding significantly higher salaries ($161K-$200K) compared to Entry-level performers ($56K-$97K), demonstrating a clear compensation structure aligned with career progression.
#
# **Actionable Recommendation:** Focus retention efforts on the 18 Senior-level high performers earning between $67K-$180K, as this group represents the largest concentration of top talent and likely faces the highest risk of being poached by competitors seeking experienced professionals who haven't yet reached executive compensation levels.
#
# The data shows strong performance distribution across all levels, with technology roles (ML Engineers, Data Scientists, Software Engineers) consistently appearing in higher salary ranges within each career tier, indicating the company's investment in technical talent is yielding strong performance results.
#
#
# ================================================================================
# IMPROVED PERFORMANCE QUERY RESULTS
# ================================================================================
#    first_name last_name          job_title_name career_level  current_salary  \
# 0      Ashley    Wright        Product Director    Executive          200000
# 1       James   Sanchez          VP Engineering    Executive          196000
# 2      Robert    Carter   Data Science Director    Executive          193000
# 3      Sophia   Stewart             HR Director    Executive          161000
# 4      Carlos  Peterson             ML Engineer       Senior          180000
# ..        ...       ...                     ...          ...             ...
# 56        Mei     Perez               Recruiter        Entry           66000
# 57      James    Parker   Sales Development Rep        Entry           61000
# 58     Sophia  Campbell   Sales Development Rep        Entry           61000
# 59      Grace   Ramirez  Accounts Payable Clerk        Entry           59000
# 60       Omar      Gray  Accounts Payable Clerk        Entry           56000
#
#     latest_performance_rating review_date
# 0                           4  2024-12-15
# 1                           4  2024-12-15
# 2                           4  2024-12-15
# 3                           5  2024-12-15
# 4                           5  2024-12-15
# ..                        ...         ...
# 56                          4  2024-12-15
# 57                          4  2024-12-15
# 58                          4  2024-12-15
# 59                          4  2024-12-15
# 60                          5  2024-12-15
#
# [61 rows x 7 columns]

# %%
# Vague: "Training status"
# Improved: Specific version using training_records + employees + departments
improved_training = engine.ask('''
Show training completion status by department.
For each department, show:
- Department name
- Total training enrollments
- Number of completed trainings
- Number of in-progress trainings
- Number of planned trainings
- Completion rate (percentage of enrollments that are completed)
Join training_records with employees and departments tables.
Group by department name.
Order by completion rate (highest to lowest).
''', visualize=False)

print("\n" + "="*80)
print("IMPROVED TRAINING QUERY RESULTS")
print("="*80)
if improved_training['success']:
    print(improved_training['data'])
# Out:
# 🤔 Question:
# Show training completion status by department.
# For each department, show:
# - Department name
# - Total training enrollments
# - Number of completed trainings
# - Number of in-progress trainings
# - Number of planned trainings
# - Completion rate (percentage of enrollments that are completed)
# Join training_records with employees and departments tables.
# Group by department name.
# Order by completion rate (highest to lowest).
#
#
# 📝 Generated SQL:
# SELECT
#     d.dept_name,
#     COUNT(tr.record_id) AS total_enrollments,
#     SUM(CASE WHEN tr.status = 'Completed' THEN 1 ELSE 0 END) AS completed_trainings,
#     SUM(CASE WHEN tr.status = 'In Progress' THEN 1 ELSE 0 END) AS in_progress_trainings,
#     SUM(CASE WHEN tr.status = 'Planned' THEN 1 ELSE 0 END) AS planned_trainings,
#     ROUND(
#         (SUM(CASE WHEN tr.status = 'Completed' THEN 1 ELSE 0 END) * 100.0) / COUNT(tr.record_id),
#         2
#     ) AS completion_rate
# FROM training_records tr
# JOIN employees e ON tr.emp_id = e.emp_id
# JOIN departments d ON e.dept_id = d.dept_id
# GROUP BY d.dept_name
# ORDER BY completion_rate DESC
#
# ✓ Query returned 8 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: **Key Insight:** Human Resources leads in training completion with a 78.13% rate despite having the fewest enrollments (32), while larger departments like Engineering (85 enrollments) and Data Science (68 enrollments) show significantly lower completion rates at 70.59% and 50.00% respectively.
#
# **Actionable Recommendation:** The company should investigate HR's training practices and processes to identify best practices that can be applied to underperforming departments, particularly Data Science and Finance which have completion rates below 55%. Additionally, immediate attention should be given to the 20 in-progress trainings in Data Science to prevent them from stalling and further impacting the department's completion rate.
#
#
# ================================================================================
# IMPROVED TRAINING QUERY RESULTS
# ================================================================================
#           dept_name  total_enrollments  completed_trainings  \
# 0   Human Resources                 32                   25
# 1       Engineering                 85                   60
# 2           Product                 36                   25
# 3  Customer Support                 44                   30
# 4         Marketing                 42                   27
# 5             Sales                 65                   41
# 6           Finance                 46                   24
# 7      Data Science                 68                   34
#
#    in_progress_trainings  planned_trainings  completion_rate
# 0                      4                  0            78.13
# 1                     13                  0            70.59
# 2                      6                  0            69.44
# 3                      6                  0            68.18
# 4                      8                  0            64.29
# 5                     12                  0            63.08
# 6                     12                  0            52.17
# 7                     20                  0            50.00

# %%
# Challenge: Write YOUR SQL for this question, then compare with the AI
question = "Find the top 5 managers whose teams have the highest average performance rating in 2024, including the number of direct reports"

# AI version:
print("="*80)
print("AI-GENERATED SQL")
print("="*80)
ai_sql = engine.get_sql_only(question)
print(ai_sql)
print()

# YOUR version:
my_sql = '''
SELECT 
    m.emp_id AS manager_id,
    m.first_name || ' ' || m.last_name AS manager_name,
    COUNT(DISTINCT e.emp_id) AS direct_reports,
    ROUND(AVG(pr.rating), 2) AS avg_team_rating
FROM employees m
JOIN employees e ON e.manager_id = m.emp_id
JOIN performance_reviews pr ON pr.emp_id = e.emp_id
WHERE pr.review_year = 2024
    AND e.employment_status = 'Active'
GROUP BY m.emp_id, m.first_name, m.last_name
ORDER BY avg_team_rating DESC, direct_reports DESC
LIMIT 5;
'''

print("="*80)
print("HUMAN-WRITTEN SQL")
print("="*80)
print(my_sql)
print()

# Compare results
print("="*80)
print("RESULTS COMPARISON")
print("="*80)

print("\nAI Results:")
print("-"*80)
ai_df = engine.execute_custom_sql(ai_sql)
print(ai_df)

print("\n\nYour Results:")
print("-"*80)
# Import the function we need
from db_utils import execute_query
my_df = execute_query(my_sql, conn)
print(my_df)

# Quick comparison
print("\n" + "="*80)
print("COMPARISON SUMMARY")
print("="*80)
print(f"AI returned: {len(ai_df)} rows")
print(f"Human SQL returned: {len(my_df)} rows")

if len(ai_df) > 0 and len(my_df) > 0:
    print("\nTop manager from AI:", ai_df.iloc[0].to_dict())
    print("Top manager from Human SQL:", my_df.iloc[0].to_dict())
# Out:
# ================================================================================
# AI-GENERATED SQL
# ================================================================================
# SELECT
#     e.first_name || ' ' || e.last_name AS manager_name,
#     e.emp_id AS manager_id,
#     COUNT(direct_reports.emp_id) AS direct_reports_count,
#     ROUND(AVG(pr.rating), 2) AS avg_team_rating
# FROM employees e
# JOIN employees direct_reports ON e.emp_id = direct_reports.manager_id
# JOIN performance_reviews pr ON direct_reports.emp_id = pr.emp_id
# WHERE pr.review_year = 2024
#     AND e.employment_status = 'Active'
#     AND direct_reports.employment_status = 'Active'
# GROUP BY e.emp_id, e.first_name, e.last_name
# ORDER BY avg_team_rating DESC
# LIMIT 5
#
# ================================================================================
# HUMAN-WRITTEN SQL
# ================================================================================
#
# SELECT
#     m.emp_id AS manager_id,
#     m.first_name || ' ' || m.last_name AS manager_name,
#     COUNT(DISTINCT e.emp_id) AS direct_reports,
#     ROUND(AVG(pr.rating), 2) AS avg_team_rating
# FROM employees m
# JOIN employees e ON e.manager_id = m.emp_id
# JOIN performance_reviews pr ON pr.emp_id = e.emp_id
# WHERE pr.review_year = 2024
#     AND e.employment_status = 'Active'
# GROUP BY m.emp_id, m.first_name, m.last_name
# ORDER BY avg_team_rating DESC, direct_reports DESC
# LIMIT 5;
#
#
# ================================================================================
# RESULTS COMPARISON
# ================================================================================
#
# AI Results:
# --------------------------------------------------------------------------------
#       manager_name  manager_id  direct_reports_count  avg_team_rating
# 0   Nicole Johnson          94                     3             4.67
# 1  Michael Roberts          38                     2             4.50
# 2    Miguel Brooks          28                     3             4.00
# 3   Sophia Stewart          58                     1             4.00
# 4  Victor Campbell           3                     9             3.89
#
#
# Your Results:
# --------------------------------------------------------------------------------
#    manager_id     manager_name  direct_reports  avg_team_rating
# 0          94   Nicole Johnson               3             4.67
# 1          38  Michael Roberts               2             4.50
# 2          41       James Hill               5             4.20
# 3          28    Miguel Brooks               3             4.00
# 4          58   Sophia Stewart               1             4.00
#
# ================================================================================
# COMPARISON SUMMARY
# ================================================================================
# AI returned: 5 rows
# Human SQL returned: 5 rows
#
# Top manager from AI: {'manager_name': 'Nicole Johnson', 'manager_id': 94, 'direct_reports_count': 3, 'avg_team_rating': 4.67}
# Top manager from Human SQL: {'manager_id': 94, 'manager_name': 'Nicole Johnson', 'direct_reports': 3, 'avg_team_rating': 4.67}

# %% [markdown]
# ---
#
# # Part 6: Building the Streamlit Web App
#
# Open `text2sql_app.py` — it has **5 main TODOs** (18-23) and **5 optional extensions** (A-E) for the Streamlit interface.
#
# The app should let users:
# 1. Enter their Gemini API key
# 2. See the database schema in the sidebar
# 3. Type questions in a chat interface
# 4. View SQL, data tables, and auto-generated charts
#
# **Before you start**: Make sure your `text2sql_engine.py` TODOs are complete, because the app depends on it!

# %%
# Verify your text2sql_engine.py is importable
import importlib
import text2sql_engine
importlib.reload(text2sql_engine)

from text2sql_engine import Text2SQLEngine, validate_sql, get_schema_for_prompt

# Quick smoke test
schema = get_schema_for_prompt(conn)
assert len(schema) > 100, "Schema too short — check TODO 1-3"

valid, msg = validate_sql("SELECT 1")
assert valid, "Validator broken — check TODO 4-6"

print("text2sql_engine.py is ready for the Streamlit app!")
# Out:
# text2sql_engine.py is ready for the Streamlit app!

# %% [markdown]
# ## Streamlit App TODOs
#
# Open `text2sql_app.py` and complete:
#
# | TODO | What to Build |
# |------|-------------|
# | **18** | Database connection with caching |
# | **19** | Schema display in sidebar |
# | **20** | Session state initialization |
# | **21** | Engine initialization |
# | **22** | Chat history display |
# | **23** | Chat input & query processing |
#
# ### Optional Extensions (do after main TODOs work):
#
# | Extension | What to Add |
# |-----------|-------------|
# | **A** | SQL query history in sidebar |
# | **B** | Custom SQL tab for manual queries |
# | **C** | Conversation memory (context from previous questions) |
# | **D** | CSV download button for results |
# | **E** | Suggested starter questions |

# %%
# Once you've completed the TODOs, run the app:
# Open a terminal and run:
#   streamlit run text2sql_app.py
#
# Or run from the solution:
#   streamlit run solution/text2sql_app.py

print("Ready to run! Use the command above in your terminal.")
print("The app will open in your browser at http://localhost:8501")

# %% [markdown]
# ---
#
# # Part 7: Reflection & Analysis

# %%
# Review your complete session history
engine.show_history()

# %% [markdown]
# ## Reflection Questions
#
# Answer each question thoughtfully (3-5 sentences each):
#
# 1. **Schema Design**: How did the quality of your schema context (TODO 1-3) affect the AI's SQL accuracy? What information was most important to include?
#
# 2. **SQL Safety**: Your validator blocks dangerous queries. Can you think of any SQL patterns that might slip through your current validation? How would you improve it?
#
# 3. **Prompt Engineering**: Which business questions required the most prompt refinement? What makes a question "hard" for the AI to translate to SQL?
#
# 4. **Visualization**: How well did the auto-generated visualizations match the data? When should you write custom visualization code vs. trusting the AI?
#
# 5. **AI vs. Manual SQL**: For which types of questions is AI-generated SQL better than manual SQL? When is manual SQL still preferable?
#
# 6. **Real-World Application**: If TechCorp deployed this tool for all managers, what guardrails would you add beyond your current validator?

# %%
# Your reflections:
reflections = '''
1. Schema Design:
Building a better schema was one of the first priorities, because the AI can only write correct SQL
if it understands the database structure. The default schema was too sparse — adding CREATE TABLE
statements, sample data rows, and explicit foreign key relationships transformed the quality of
generated queries. Of those additions, the foreign key relationships were probably the most critical:
without them the AI had no way to know how to JOIN tables like project_assignments back to employees.
The sample data rows were a close second, because they showed the AI what actual column values looked
like — catching things like date formats and status strings that a bare schema wouldn't reveal.
 
 
2. SQL Safety:
The validator blocks the most obvious attack vectors — dangerous keywords like DROP and DELETE, and
stacked queries via semicolons in the middle of a statement. A few patterns could still slip through:
a carefully crafted subquery that modifies data through a writable CTE on a database that supports
them, or a query that uses ATTACH DATABASE to reach outside the intended SQLite file. The
word-boundary regex is also only as good as the keyword list — something like PRAGMA writable_schema
isn't covered. To improve it, you'd want to add a read-only connection flag at the SQLite level
itself, so no matter what SQL gets through the validator, the database physically cannot be modified.
 
 
3. Prompt Engineering:
Complex multi-table joins and CTEs caused the most trouble — the AI consistently handled simple
aggregation questions on a single table, but when questions required combining salary history with
performance reviews and employees in the same query, the SQL quality degraded. CTEs were a specific
recurring problem: Claude Sonnet would generate syntactically broken CTEs missing the WITH keyword,
requiring multiple rounds of prompt hardening including a system-level instruction and nuclear-option
warnings in the user prompt. What makes a question "hard" for the AI is when the intent requires
inferring unstated business logic — like "latest rating" meaning the most recent row per employee
rather than an average — combined with a multi-table JOIN path it has to figure out from the schema.
 
 
4. Visualization:
Garbage in, garbage out was the lesson here — the more specific the prompt about what the chart
should look like and what columns to return, the better the result. Simple two-column results
(category + value) produced reliable bar charts with no intervention. Questions 8 and 10 required
the most work: Question 8 needed a 100% stacked bar by training category, and the AI kept returning
a grouped bar instead until the column structure was explicitly specified in the prompt. For charts
with specific requirements like stacked bars with percentage labels or scatter plots with trend lines,
writing the visualization manually and disabling visualize=True was the more reliable path than
trusting the AI to generate it.
 
 
5. AI vs. Manual SQL:
For the straightforward analytical queries that make up most day-to-day business intelligence work —
aggregations, rankings, department comparisons — the AI is faster and the output is just as good as
hand-written SQL, assuming the schema context is solid. Where manual SQL still has the edge is in
queries that require precise business logic the AI can't infer, like carefully constructed window
functions or queries that depend on domain knowledge about what the data actually means. That said,
even for complex queries the AI gets you 80-90% of the way there and the remaining refinement is
faster than starting from scratch. The real value isn't replacing SQL knowledge — it's making data
accessible to people who don't have it.
 
 
6. Real-World Application:
The business insights output needed tuning — it leaned heavily toward recommending raises regardless
of context, which would get repetitive fast if every query result came back with the same suggestion.
Beyond that, a production deployment for managers would need role-based access control so a manager
in Engineering can't accidentally query salary data for HR. Audit logging of every query would be
essential for compliance, and a more aggressive SQL validator that operates at the database
connection level rather than just regex matching would close the gaps the current validator leaves
open. Finally, the Gemini free tier would need to be replaced or rate-limited in production —
free API keys cycling out mid-demo is not a good look in front of leadership.
 
'''
print(reflections)
# Out:
# 1. Schema Design:
# Building a better schema was one of the first priorities, because the AI can only write correct SQL
# if it understands the database structure. The default schema was too sparse — adding CREATE TABLE
# statements, sample data rows, and explicit foreign key relationships transformed the quality of
# generated queries. Of those additions, the foreign key relationships were probably the most critical:
# without them the AI had no way to know how to JOIN tables like project_assignments back to employees.
# The sample data rows were a close second, because they showed the AI what actual column values looked
# like — catching things like date formats and status strings that a bare schema wouldn't reveal.
#
#
# 2. SQL Safety:
# The validator blocks the most obvious attack vectors — dangerous keywords like DROP and DELETE, and
# stacked queries via semicolons in the middle of a statement. A few patterns could still slip through:
# a carefully crafted subquery that modifies data through a writable CTE on a database that supports
# them, or a query that uses ATTACH DATABASE to reach outside the intended SQLite file. The
# word-boundary regex is also only as good as the keyword list — something like PRAGMA writable_schema
# isn't covered. To improve it, you'd want to add a read-only connection flag at the SQLite level
# itself, so no matter what SQL gets through the validator, the database physically cannot be modified.
#
#
# 3. Prompt Engineering:
# Complex multi-table joins and CTEs caused the most trouble — the AI consistently handled simple
# aggregation questions on a single table, but when questions required combining salary history with
# performance reviews and employees in the same query, the SQL quality degraded. CTEs were a specific
# recurring problem: Claude Sonnet would generate syntactically broken CTEs missing the WITH keyword,
# requiring multiple rounds of prompt hardening including a system-level instruction and nuclear-option
# warnings in the user prompt. What makes a question "hard" for the AI is when the intent requires
# inferring unstated business logic — like "latest rating" meaning the most recent row per employee
# rather than an average — combined with a multi-table JOIN path it has to figure out from the schema.
#
#
# 4. Visualization:
# Garbage in, garbage out was the lesson here — the more specific the prompt about what the chart
# should look like and what columns to return, the better the result. Simple two-column results
# (category + value) produced reliable bar charts with no intervention. Questions 8 and 10 required
# the most work: Question 8 needed a 100% stacked bar by training category, and the AI kept returning
# a grouped bar instead until the column structure was explicitly specified in the prompt. For charts
# with specific requirements like stacked bars with percentage labels or scatter plots with trend lines,
# writing the visualization manually and disabling visualize=True was the more reliable path than
# trusting the AI to generate it.
#
#
# 5. AI vs. Manual SQL:
# For the straightforward analytical queries that make up most day-to-day business intelligence work —
# aggregations, rankings, department comparisons — the AI is faster and the output is just as good as
# hand-written SQL, assuming the schema context is solid. Where manual SQL still has the edge is in
# queries that require precise business logic the AI can't infer, like carefully constructed window
# functions or queries that depend on domain knowledge about what the data actually means. That said,
# even for complex queries the AI gets you 80-90% of the way there and the remaining refinement is
# faster than starting from scratch. The real value isn't replacing SQL knowledge — it's making data
# accessible to people who don't have it.
#
#
# 6. Real-World Application:
# The business insights output needed tuning — it leaned heavily toward recommending raises regardless
# of context, which would get repetitive fast if every query result came back with the same suggestion.
# Beyond that, a production deployment for managers would need role-based access control so a manager
# in Engineering can't accidentally query salary data for HR. Audit logging of every query would be
# essential for compliance, and a more aggressive SQL validator that operates at the database
# connection level rather than just regex matching would close the gaps the current validator leaves
# open. Finally, the Gemini free tier would need to be replaced or rate-limited in production —
# free API keys cycling out mid-demo is not a good look in front of leadership.

# %% [markdown]
# ---
#
# ## Project Summary
#
# ### What You Built
# - **Schema context builder** that gives AI models the information they need to write correct SQL
# - **SQL safety validator** that blocks dangerous queries (DROP, DELETE, etc.)
# - **Response parser** that extracts clean SQL from AI responses
# - **Text-to-SQL generator** using Google Gemini
# - **LLM-powered auto-visualizer** that generates appropriate charts for query results
# - **Streamlit web app** with a chat interface for non-technical users
#
# ### Key Skills Practiced
# - SQL (SELECT, JOIN, GROUP BY, HAVING, subqueries, CTEs, window functions)
# - Python-SQL integration (sqlite3, pandas)
# - Prompt engineering for code generation
# - AI safety and validation
# - Web app development with Streamlit
# - Data visualization with matplotlib/seaborn
#
# ### What's Next
# - Try deploying your Streamlit app (Streamlit Community Cloud is free)
# - Extend the app with the optional TODOs (memory, custom SQL, export)
# - Apply these patterns to other databases and business domains
