# %% [markdown]
# # Session 14: Project 2 — HR Analytics with AI-Assisted SQL
#
# **Data Analytics in the Age of AI Bootcamp**
#
# ---
#
# ## Project Overview
#
# **Business Scenario:** You are an HR data analyst at TechCorp, a mid-size technology company with 120 employees across 8 departments. Leadership has asked you to build an **AI-powered analytics tool** that lets anyone ask business questions in plain English and get back SQL queries, data results, and visualizations — no SQL knowledge required.
#
# ### What You Will Build
#
# | Part | What You Build |
# |------|---------------|
# | **Part 1** | Load & explore an 8-table HR database |
# | **Part 2** | Complete the Text-to-SQL engine (schema builder, validator, generator) |
# | **Part 3** | Answer 12 business questions using your engine |
# | **Part 4** | Build an LLM-powered auto-visualizer |
# | **Part 5** | Prompt engineering — refine questions for better SQL |
# | **Part 6** | Build a Streamlit web app with chat interface |
# | **Part 7** | Reflection & analysis |
#
#
# ### Files Provided
#
# | File | Description |
# |------|-------------|
# | `data/*.csv` | 8 CSV files (departments, job_titles, employees, salary_history, projects, project_assignments, performance_reviews, training_records) — 1,300+ rows total |
# | `schema/SCHEMA.md` | Full schema documentation with ER diagram |
# | `schema/er_diagram.mermaid` | Mermaid ER diagram (render at mermaid.live) |
# | `db_utils.py` | **PROVIDED** — Database loading and schema inspection utilities |
# | `text2sql_engine.py` | **YOUR WORK** — Text-to-SQL engine with 17 TODOs to complete |
# | `text2sql_app.py` | **YOUR WORK** — Streamlit app with TODOs |
# | `solution/` | Reference solutions (try on your own first!) |
#
# ### Prerequisites
# Sessions 11-13 (SQL, Python-SQL Integration, Streamlit Basics)

# %% [markdown]
# ---
#
# # Part 1: Project Setup — Loading the HR Database
#
# TechCorp's HR data lives in 8 CSV files. We will load them all into a SQLite in-memory database so we can query them with SQL.

# %%
# Core imports
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Our helper modules (db_utils is provided, text2sql_engine has your TODOs)
from db_utils import load_csv_to_db, get_schema_info, execute_query, list_tables, get_table_info, get_foreign_keys

print("All imports successful!")
# Out:
# All imports successful!

# %%
# Load all 8 CSV files into SQLite
conn = load_csv_to_db("data/")

# Show all tables and their row counts
print("\nDatabase Overview:")
print(list_tables(conn))
# Out:
# Loading 8 CSV files into database...
#   ✓ departments: 8 rows, 6 columns
#   ✓ employees: 120 rows, 13 columns
#   ✓ job_titles: 38 rows, 6 columns
#   ✓ performance_reviews: 293 rows, 7 columns
#   ✓ project_assignments: 138 rows, 5 columns
#   ✓ projects: 20 rows, 8 columns
#   ✓ salary_history: 308 rows, 6 columns
#   ✓ training_records: 418 rows, 9 columns
#
# Database ready! 8 tables loaded.
#
# Database Overview:
#                  table  rows
# 0          departments     8
# 1            employees   120
# 2           job_titles    38
# 3  performance_reviews   293
# 4  project_assignments   138
# 5             projects    20
# 6       salary_history   308
# 7     training_records   418

# %% [markdown]
# ## Explore the Schema
#
# Before writing any queries, we need to understand the database. Open `schema/SCHEMA.md` for the full documentation and ER diagram.
#
# Let's explore programmatically too:

# %%
# Display full schema with column types and sample data
schema = get_schema_info(conn)
print(schema)
# Out:
# ================================================================================
# DATABASE SCHEMA - TechCorp HR Analytics
# ================================================================================
#
# TABLE: departments (8 rows)
# --------------------------------------------------------------------------------
#   dept_id                   INTEGER    (nullable)
#   dept_name                 TEXT       (nullable)
#   location                  TEXT       (nullable)
#   annual_budget             INTEGER    (nullable)
#   division                  TEXT       (nullable)
#   established_date          TEXT       (nullable)
#
# TABLE: employees (120 rows)
# --------------------------------------------------------------------------------
#   emp_id                    INTEGER    (nullable)
#   first_name                TEXT       (nullable)
#   last_name                 TEXT       (nullable)
#   email                     TEXT       (nullable)
#   dept_id                   INTEGER    (nullable)
#   title_id                  INTEGER    (nullable)
#   salary                    INTEGER    (nullable)
#   hire_date                 TEXT       (nullable)
#   gender                    TEXT       (nullable)
#   employment_status         TEXT       (nullable)
#   termination_date          TEXT       (nullable)
#   work_mode                 TEXT       (nullable)
#   manager_id                REAL       (nullable)
#
# TABLE: job_titles (38 rows)
# --------------------------------------------------------------------------------
#   title_id                  INTEGER    (nullable)
#   title                     TEXT       (nullable)
#   dept_id                   INTEGER    (nullable)
#   level                     TEXT       (nullable)
#   min_salary                INTEGER    (nullable)
#   max_salary                INTEGER    (nullable)
#
# TABLE: performance_reviews (293 rows)
# --------------------------------------------------------------------------------
#   review_id                 INTEGER    (nullable)
#   emp_id                    INTEGER    (nullable)
#   review_year               INTEGER    (nullable)
#   rating                    INTEGER    (nullable)
#   goals_met_pct             INTEGER    (nullable)
#   reviewer_comments         TEXT       (nullable)
#   review_date               TEXT       (nullable)
#
# TABLE: project_assignments (138 rows)
# --------------------------------------------------------------------------------
#   assignment_id             INTEGER    (nullable)
#   project_id                INTEGER    (nullable)
#   emp_id                    INTEGER    (nullable)
#   role                      TEXT       (nullable)
#   hours_per_week            INTEGER    (nullable)
#
# TABLE: projects (20 rows)
# --------------------------------------------------------------------------------
#   project_id                INTEGER    (nullable)
#   project_name              TEXT       (nullable)
#   dept_id                   INTEGER    (nullable)
#   budget                    INTEGER    (nullable)
#   start_date                TEXT       (nullable)
#   end_date                  TEXT       (nullable)
#   status                    TEXT       (nullable)
#   priority                  TEXT       (nullable)
#
# TABLE: salary_history (308 rows)
# --------------------------------------------------------------------------------
#   history_id                INTEGER    (nullable)
#   emp_id                    INTEGER    (nullable)
#   old_salary                REAL       (nullable)
#   new_salary                REAL       (nullable)
#   effective_date            TEXT       (nullable)
#   reason                    TEXT       (nullable)
#
# TABLE: training_records (418 rows)
# --------------------------------------------------------------------------------
#   record_id                 INTEGER    (nullable)
#   emp_id                    INTEGER    (nullable)
#   course_name               TEXT       (nullable)
#   category                  TEXT       (nullable)
#   hours                     INTEGER    (nullable)
#   enrollment_date           TEXT       (nullable)
#   completion_date           TEXT       (nullable)
#   status                    TEXT       (nullable)
#   score                     REAL       (nullable)
#
# ================================================================================
# FOREIGN KEY RELATIONSHIPS
# ================================================================================
#
# employees.dept_id → departments.dept_id
#   Type: Many-to-One
#   Note: Many employees belong to one department
#
# employees.title_id → job_titles.title_id
#   Type: Many-to-One
#   Note: Many employees share the same job title
#
# employees.manager_id → employees.emp_id
#   Type: Self-Reference
#   Note: Employees report to other employees (manager hierarchy)
#
# salary_history.emp_id → employees.emp_id
#   Type: Many-to-One
#   Note: Each employee has multiple salary history records
#
# performance_reviews.emp_id → employees.emp_id
#   Type: Many-to-One
#   Note: Each employee has multiple performance reviews
#
# performance_reviews.reviewer_id → employees.emp_id
#   Type: Many-to-One
#   Note: Reviews are conducted by employees (usually managers)
#
# training_records.emp_id → employees.emp_id
#   Type: Many-to-One
#   Note: Each employee has multiple training records
#
# projects.dept_id → departments.dept_id
#   Type: Many-to-One
#   Note: Each project belongs to one department
#
# project_assignments.project_id → projects.project_id
#   Type: Many-to-Many
#   Note: Junction table: projects have many employees
#
# project_assignments.emp_id → employees.emp_id
#   Type: Many-to-Many
#   Note: Junction table: employees work on many projects
#
# ================================================================================
# SAMPLE DATA (First 3 rows per table)
# ================================================================================
#
# departments:
#  dept_id   dept_name      location  annual_budget   division established_date
#        1 Engineering San Francisco        3200000 Technology       2015-01-15
#        2   Marketing      New York        1400000     Growth       2015-01-15
#        3       Sales       Chicago        2100000    Revenue       2015-01-15
#
# employees:
#  emp_id first_name last_name                        email  dept_id  title_id  salary  hire_date gender employment_status termination_date work_mode  manager_id
#       1      James   Sanchez   james.sanchez@techcorp.com        1         1  196000 2016-07-17      M            Active             None    Hybrid         NaN
#       2    Timothy    Wright  timothy.wright@techcorp.com        1         2  151000 2017-03-07      M            Active             None    Hybrid         1.0
#       3     Victor  Campbell victor.campbell@techcorp.com        1         2  168000 2020-12-07      M            Active             None    Remote         1.0
#
# job_titles:
#  title_id                    title  dept_id     level  min_salary  max_salary
#         1           VP Engineering        1 Executive      180000      220000
#         2      Engineering Manager        1   Manager      150000      180000
#         3 Senior Software Engineer        1    Senior      130000      160000
#
# performance_reviews:
#  review_id  emp_id  review_year  rating  goals_met_pct                                       reviewer_comments review_date
#          1       1         2022       4             72 Exceeds expectations. Strong contributor to team goals.  2022-12-15
#          2       1         2023       4             83 Exceeds expectations. Strong contributor to team goals.  2023-12-15
#          3       1         2024       4             74 Exceeds expectations. Strong contributor to team goals.  2024-12-15
#
# project_assignments:
#  assignment_id  project_id  emp_id        role  hours_per_week
#              1           1       9        Lead              40
#              2           1      13 Contributor              30
#              3           1      18 Coordinator              10
#
# projects:
#  project_id            project_name  dept_id  budget start_date   end_date      status priority
#           1     Mobile App Redesign        1  450000 2023-01-15 2023-11-30   Completed     High
#           2 Cloud Migration Phase 1        1  680000 2023-04-01 2024-03-31   Completed Critical
#           3 Cloud Migration Phase 2        1  520000 2024-04-01 2025-06-30 In Progress Critical
#
# salary_history:
#  history_id  emp_id  old_salary  new_salary effective_date        reason
#           1       1    136000.0    151000.0     2018-01-28     Promotion
#           2       1    151000.0    164000.0     2019-08-11   Role Change
#           3       1    164000.0    176000.0     2021-02-21 Annual Review
#
# training_records:
#  record_id  emp_id               course_name     category  hours enrollment_date completion_date    status  score
#          1       1        Financial Modeling    Technical     20      2023-02-20      2023-05-19 Completed   73.0
#          2       1      Communication Skills  Soft Skills      8      2022-11-15      2022-12-20 Completed   84.0
#          3       1 Project Management Basics Professional     12      2024-08-12      2024-10-17 Completed   73.0
#
# ================================================================================
# COMMON QUERY PATTERNS
# ================================================================================
#
# -- Get employee details with department and title names:
# SELECT e.*, d.dept_name, j.title_name
# FROM employees e
# JOIN departments d ON e.dept_id = d.dept_id
# JOIN job_titles j ON e.title_id = j.title_id
#
# -- Get manager hierarchy (self-join):
# SELECT e.first_name, e.last_name,
#        m.first_name AS manager_first, m.last_name AS manager_last
# FROM employees e
# LEFT JOIN employees m ON e.manager_id = m.emp_id
#
# -- Get project team members (many-to-many via junction table):
# SELECT p.project_name, e.first_name, e.last_name, pa.role_on_project
# FROM projects p
# JOIN project_assignments pa ON p.project_id = pa.project_id
# JOIN employees e ON pa.emp_id = e.emp_id
#
# -- Get salary history with employee names:
# SELECT e.first_name, e.last_name, sh.old_salary, sh.new_salary,
#        sh.change_date, sh.reason
# FROM salary_history sh
# JOIN employees e ON sh.emp_id = e.emp_id
#
# ================================================================================
# IMPORTANT NOTES
# ================================================================================
#
# 1. MANAGER HIERARCHY:
#    - employees.manager_id references employees.emp_id (self-join)
#    - C-level executives have NULL manager_id (no manager)
#    - Use LEFT JOIN when including managers to keep all employees
#
# 2. MANY-TO-MANY RELATIONSHIPS:
#    - employees ↔ projects via project_assignments junction table
#    - Always JOIN through project_assignments, never direct
#
# 3. CATEGORICAL COLUMNS - Valid Values:
#    - employees.status: 'Active', 'Inactive'
#    - employees.work_mode: 'Remote', 'Hybrid', 'On-site'
#    - employees.performance_band: 'Exceeds', 'Meets', 'Needs Improvement', 'Unsatisfactory'
#    - projects.status: 'Active', 'Completed', 'On Hold'
#    - salary_history.reason: 'Promotion', 'Annual Review', 'Merit Increase', 'Market Adjustment'
#    - performance_reviews.rating: 'Exceeds Expectations', 'Meets Expectations', 'Needs Improvement', 'Unsatisfactory'
#    - training_records.status: 'Completed', 'In Progress', 'Planned'
#    - job_titles.career_level: 'Entry', 'Mid', 'Senior', 'Lead', 'Manager', 'Director', 'VP', 'C-Level'
#
# 4. DATE FORMATS:
#    - All dates stored as TEXT in format: 'YYYY-MM-DD'
#    - Use SQLite date functions: date(), strftime(), julianday()
#
# 5. SALARY RANGES:
#    - employees.salary: $45,000 - $180,000 (current salary)
#    - job_titles.min_salary / max_salary: defines band for each role
#
# ================================================================================

# %%
# Show how tables connect to each other (foreign key relationships)
fk_df = get_foreign_keys(conn)
print("\nTable Relationships:")
print(fk_df.to_string(index=False))
# Out:
# No formal foreign keys defined (relationships exist by naming convention).
#
# Table Relationships:
#          from_table from_column    to_table  to_column
#           employees     dept_id departments    dept_id
#           employees    title_id  job_titles   title_id
#           employees  manager_id   employees     emp_id
#            projects     dept_id departments    dept_id
# project_assignments  project_id    projects project_id
# project_assignments      emp_id   employees     emp_id
#      salary_history      emp_id   employees     emp_id
# performance_reviews      emp_id   employees     emp_id
#    training_records      emp_id   employees     emp_id

# %%
# Peek at each table: first 3 rows
tables = ["departments", "job_titles", "employees", "salary_history",
          "projects", "project_assignments", "performance_reviews", "training_records"]

for table in tables:
    print(f"\n{'='*60}")
    print(f" {table.upper()} ")
    print(f"{'='*60}")
    df = execute_query(f"SELECT * FROM {table} LIMIT 3", conn)
    print(df.to_string(index=False))
    print(f"  ... {execute_query(f'SELECT COUNT(*) as total FROM {table}', conn)['total'][0]} rows total")
# Out:
# ============================================================
#  DEPARTMENTS
# ============================================================
#  dept_id   dept_name      location  annual_budget   division established_date
#        1 Engineering San Francisco        3200000 Technology       2015-01-15
#        2   Marketing      New York        1400000     Growth       2015-01-15
#        3       Sales       Chicago        2100000    Revenue       2015-01-15
#   ... 8 rows total
#
# ============================================================
#  JOB_TITLES
# ============================================================
#  title_id                    title  dept_id     level  min_salary  max_salary
#         1           VP Engineering        1 Executive      180000      220000
#         2      Engineering Manager        1   Manager      150000      180000
#         3 Senior Software Engineer        1    Senior      130000      160000
#   ... 38 rows total
#
# ============================================================
#  EMPLOYEES
# ============================================================
#  emp_id first_name last_name                        email  dept_id  title_id  salary  hire_date gender employment_status termination_date work_mode  manager_id
#       1      James   Sanchez   james.sanchez@techcorp.com        1         1  196000 2016-07-17      M            Active             None    Hybrid         NaN
#       2    Timothy    Wright  timothy.wright@techcorp.com        1         2  151000 2017-03-07      M            Active             None    Hybrid         1.0
#       3     Victor  Campbell victor.campbell@techcorp.com        1         2  168000 2020-12-07      M            Active             None    Remote         1.0
#   ... 120 rows total
#
# ============================================================
#  SALARY_HISTORY
# ============================================================
#  history_id  emp_id  old_salary  new_salary effective_date        reason
#           1       1    136000.0    151000.0     2018-01-28     Promotion
#           2       1    151000.0    164000.0     2019-08-11   Role Change
#           3       1    164000.0    176000.0     2021-02-21 Annual Review
#   ... 308 rows total
#
# ============================================================
#  PROJECTS
# ============================================================
#  project_id            project_name  dept_id  budget start_date   end_date      status priority
#           1     Mobile App Redesign        1  450000 2023-01-15 2023-11-30   Completed     High
#           2 Cloud Migration Phase 1        1  680000 2023-04-01 2024-03-31   Completed Critical
#           3 Cloud Migration Phase 2        1  520000 2024-04-01 2025-06-30 In Progress Critical
#   ... 20 rows total
#
# ============================================================
#  PROJECT_ASSIGNMENTS
# ============================================================
#  assignment_id  project_id  emp_id        role  hours_per_week
#              1           1       9        Lead              40
#              2           1      13 Contributor              30
#              3           1      18 Coordinator              10
#   ... 138 rows total
#
# ============================================================
#  PERFORMANCE_REVIEWS
# ============================================================
#  review_id  emp_id  review_year  rating  goals_met_pct                                       reviewer_comments review_date
#          1       1         2022       4             72 Exceeds expectations. Strong contributor to team goals.  2022-12-15
#          2       1         2023       4             83 Exceeds expectations. Strong contributor to team goals.  2023-12-15
#          3       1         2024       4             74 Exceeds expectations. Strong contributor to team goals.  2024-12-15
#   ... 293 rows total
#
# ============================================================
#  TRAINING_RECORDS
# ============================================================
#  record_id  emp_id               course_name     category  hours enrollment_date completion_date    status  score
#          1       1        Financial Modeling    Technical     20      2023-02-20      2023-05-19 Completed   73.0
#          2       1      Communication Skills  Soft Skills      8      2022-11-15      2022-12-20 Completed   84.0
#          3       1 Project Management Basics Professional     12      2024-08-12      2024-10-17 Completed   73.0
#   ... 418 rows total

# %% [markdown]
# ## Entity Relationship Diagram
#
# The database has these key relationships:
#
# ```
# departments ──┬── employees ──┬── salary_history
#               │               ├── performance_reviews
#               │               ├── training_records
#               │               └── project_assignments ── projects
#               │
#               ├── job_titles
#               └── projects
#
# employees.manager_id → employees.emp_id  (self-referencing hierarchy)
# ```
#
# **Key insight**: The `employees` table is the central hub. Most analytics questions will start there and JOIN to other tables.

# %%
# Warm-up queries to verify your understanding
# Run each and check the output makes sense

# How many active employees?
print("Active employees:")
print(execute_query("SELECT COUNT(*) as count FROM employees WHERE employment_status = 'Active'", conn))

# Departments and their employee counts
print("\nEmployees per department:")
print(execute_query("""
    SELECT d.dept_name, COUNT(e.emp_id) as emp_count
    FROM departments d
    LEFT JOIN employees e ON d.dept_id = e.dept_id
    GROUP BY d.dept_name
    ORDER BY emp_count DESC
""", conn))

# Average salary by career level
print("\nAverage salary by level:")
print(execute_query("""
    SELECT jt.level, ROUND(AVG(e.salary)) as avg_salary, COUNT(*) as count
    FROM employees e
    JOIN job_titles jt ON e.title_id = jt.title_id
    GROUP BY jt.level
    ORDER BY avg_salary DESC
""", conn))
# Out:
# Active employees:
#    count
# 0    107
#
# Employees per department:
#           dept_name  emp_count
# 0       Engineering         25
# 1             Sales         20
# 2      Data Science         19
# 3           Finance         13
# 4         Marketing         12
# 5  Customer Support         12
# 6           Product         11
# 7   Human Resources          8
#
# Average salary by level:
#        level  avg_salary  count
# 0  Executive    180000.0      7
# 1    Manager    131714.0     14
# 2     Senior    125375.0     24
# 3        Mid    101020.0     50
# 4      Entry     68680.0     25

# %% [markdown]
# > **Takeaway**: You now have a rich, 8-table HR database with 1,300+ rows. The data includes employee demographics, compensation history, project assignments, performance reviews, and training records — enough to answer real business questions.

# %% [markdown]
# ---
#
# # Part 2: Building the Text-to-SQL Engine
#
# Open `text2sql_engine.py` in your editor. It contains **17 TODOs** organized into 7 parts (A through G). You will implement the complete pipeline:
#
# ```
# Question (English) → Schema Context → AI Prompt → Generated SQL → Safety Check → Execute → Results
# ```
#
# Work through the TODOs in order. Each builds on the previous one.

# %% [markdown]
# ## Part 2A: Schema Context Builder (TODOs 1-3)
#
# The AI needs to understand your database to write correct SQL. The `get_schema_for_prompt()` function builds a text description of every table, column, and relationship.
#
# **Why it matters**: A vague schema description → vague SQL. A detailed schema → accurate SQL.
#
# Open `text2sql_engine.py` and complete TODOs 1, 2, and 3.

# %%
# Test your schema builder (after completing TODOs 1-3)
from text2sql_engine import get_schema_for_prompt

# Reload the module if you made changes
import importlib
import text2sql_engine
importlib.reload(text2sql_engine)
from text2sql_engine import get_schema_for_prompt

schema_text = get_schema_for_prompt(conn)
print(schema_text[:2000])  # Print first 2000 chars
print(f"\n... (total length: {len(schema_text)} characters)")

# Verify: Does it include CREATE TABLE statements?
assert "CREATE TABLE" in schema_text, "Missing CREATE TABLE statements (TODO 1)"
# Verify: Does it include sample data?
assert "Sample" in schema_text or "sample" in schema_text, "Missing sample data (TODO 2)"
# Verify: Does it include relationships?
assert "->" in schema_text or "RELATIONSHIP" in schema_text.upper(), "Missing relationships (TODO 3)"

print("\nAll schema tests passed!")
# Out:
# CREATE TABLE departments (
#     dept_id INTEGER,
#     dept_name TEXT,
#     location TEXT,
#     annual_budget INTEGER,
#     division TEXT,
#     established_date TEXT
# );
#
# -- Sample data from departments:
# --  dept_id   dept_name      location  annual_budget   division established_date
# --        1 Engineering San Francisco        3200000 Technology       2015-01-15
# --        2   Marketing      New York        1400000     Growth       2015-01-15
# --        3       Sales       Chicago        2100000    Revenue       2015-01-15
#
# CREATE TABLE employees (
#     emp_id INTEGER,
#     first_name TEXT,
#     last_name TEXT,
#     email TEXT,
#     dept_id INTEGER,
#     title_id INTEGER,
#     salary INTEGER,
#     hire_date TEXT,
#     gender TEXT,
#     employment_status TEXT,
#     termination_date TEXT,
#     work_mode TEXT,
#     manager_id REAL
# );
#
# -- Sample data from employees:
# --  emp_id first_name last_name                        email  dept_id  title_id  salary  hire_date gender employment_status termination_date work_mode  manager_id
# --       1      James   Sanchez   james.sanchez@techcorp.com        1         1  196000 2016-07-17      M            Active             None    Hybrid         NaN
# --       2    Timothy    Wright  timothy.wright@techcorp.com        1         2  151000 2017-03-07      M            Active             None    Hybrid         1.0
# --       3     Victor  Campbell victor.campbell@techcorp.com        1         2  168000 2020-12-07      M            Active             None    Remote         1.0
#
# CREATE TABLE job_titles (
#     title_id INTEGER,
#     title TEXT,
#     dept_id INTEGER,
#     level TEXT,
#     min_salary INTEGER,
#     max_salary INTEGER
# );
#
# -- Sample data from job_titles:
# --  title_id                    title  dept_id     level  min_salary  max_salary
# --         1           VP Engineering        1 Executive      180000      220000
# --         2      Engineering Manager        1   Manager      150000      180000
# --         3 Senior Software Engineer        1    Senior      13000
#
# ... (total length: 5698 characters)
#
# All schema tests passed!

# %% [markdown]
# ## Part 2B: SQL Safety Validator (TODOs 4-6)
#
# AI models can sometimes generate dangerous SQL (DROP TABLE, DELETE, etc.). Your validator must catch these before they reach the database.
#
# Open `text2sql_engine.py` and complete TODOs 4, 5, and 6.

# %%
# Test your SQL validator (after completing TODOs 4-6)
import importlib
import text2sql_engine
importlib.reload(text2sql_engine)
from text2sql_engine import validate_sql

# These should all PASS (return True)
safe_queries = [
    "SELECT * FROM employees",
    "SELECT dept_name, AVG(salary) FROM employees e JOIN departments d ON e.dept_id = d.dept_id GROUP BY dept_name",
    "WITH dept_avg AS (SELECT dept_id, AVG(salary) as avg FROM employees GROUP BY dept_id) SELECT * FROM dept_avg",
]

for q in safe_queries:
    valid, msg = validate_sql(q)
    status = "PASS" if valid else "FAIL"
    print(f"  [{status}] Safe query: {q[:60]}... -> {msg}")
    assert valid, f"Should be valid: {q}"

# These should all FAIL (return False)
dangerous_queries = [
    "DROP TABLE employees",
    "DELETE FROM employees WHERE emp_id = 1",
    "UPDATE employees SET salary = 0",
    "INSERT INTO employees VALUES (999, 'Hacker')",
    "SELECT 1; DROP TABLE employees",
    "",
]

for q in dangerous_queries:
    valid, msg = validate_sql(q)
    status = "PASS" if not valid else "FAIL"
    print(f"  [{status}] Dangerous query: {q[:60]}... -> {msg}")
    assert not valid, f"Should be blocked: {q}"

print("\nAll validator tests passed!")
# Out:
#   [PASS] Safe query: SELECT * FROM employees... -> Query is safe.
#   [PASS] Safe query: SELECT dept_name, AVG(salary) FROM employees e JOIN departme... -> Query is safe.
#   [PASS] Safe query: WITH dept_avg AS (SELECT dept_id, AVG(salary) as avg FROM em... -> Query is safe.
#   [PASS] Dangerous query: DROP TABLE employees... -> Query must start with SELECT or WITH
#   [PASS] Dangerous query: DELETE FROM employees WHERE emp_id = 1... -> Query must start with SELECT or WITH
#   [PASS] Dangerous query: UPDATE employees SET salary = 0... -> Query must start with SELECT or WITH
#   [PASS] Dangerous query: INSERT INTO employees VALUES (999, 'Hacker')... -> Query must start with SELECT or WITH
#   [PASS] Dangerous query: SELECT 1; DROP TABLE employees... -> Dangerous keyword detected: DROP
#   [PASS] Dangerous query: ... -> Empty query.
#
# All validator tests passed!

# %% [markdown]
# ## Part 2C: Response Parser (TODOs 7-8)
#
# When Gemini returns SQL, it might wrap it in markdown code blocks or add explanations. The parser extracts just the SQL.
#
# Complete TODOs 7 and 8 in `text2sql_engine.py`.

# %%
# Test your response parser (after completing TODOs 7-8)
import importlib
import text2sql_engine
importlib.reload(text2sql_engine)
from text2sql_engine import extract_sql_from_response

# Test 1: SQL in code block
response1 = "Here's the query:\n```sql\nSELECT dept_name, AVG(salary) AS avg_salary\nFROM employees e\nJOIN departments d ON e.dept_id = d.dept_id\nGROUP BY dept_name;\n```\nThis joins the employees and departments tables."

sql1 = extract_sql_from_response(response1)
print(f"Test 1 (code block): {sql1[:60]}...")
assert "SELECT" in sql1 and "GROUP BY" in sql1

# Test 2: Plain SQL with explanation
response2 = "The SQL query to answer this is: SELECT COUNT(*) FROM employees WHERE employment_status = 'Active'; This counts all active employees."
sql2 = extract_sql_from_response(response2)
print(f"Test 2 (plain text): {sql2[:60]}...")
assert "SELECT" in sql2

# Test 3: Just SQL
response3 = "SELECT * FROM departments ORDER BY annual_budget DESC;"
sql3 = extract_sql_from_response(response3)
print(f"Test 3 (raw SQL): {sql3[:60]}...")
assert sql3.startswith("SELECT")

print("\nAll parser tests passed!")
# Out:
# Test 1 (code block): SELECT dept_name, AVG(salary) AS avg_salary
# FROM employees e...
# Test 2 (plain text): SELECT COUNT(*) FROM employees WHERE employment_status = 'Ac...
# Test 3 (raw SQL): SELECT * FROM departments ORDER BY annual_budget DESC...
#
# All parser tests passed!

# %% [markdown]
# ## Part 2D-E: SQL Generator & Executor (TODOs 9-12)
#
# Now for the core AI integration:
# - **TODO 9**: Build the prompt that tells Gemini about the schema and rules
# - **TODO 10**: Call the Gemini API and extract the SQL
# - **TODO 11-12**: Validate and execute the generated SQL
#
# Complete TODOs 9 through 12 in `text2sql_engine.py`.

# %%
# Set up the Claude API (you need this for TODOs 9-10 testing)
from anthropic import Anthropic
from dotenv import load_dotenv
import os

# Load API key from .env file
load_dotenv()
ANTHROPIC_API_KEY = os.getenv('ANTHROPIC_API_KEY')

# Initialize Claude client
client = Anthropic(api_key=ANTHROPIC_API_KEY)

# Quick test
resp = client.messages.create(
    model="claude-sonnet-4-20250514",
    max_tokens=100,
    messages=[{"role": "user", "content": "Say hello in one word."}]
)
print(f"API test: {resp.content[0].text.strip()}")
# Out:
# API test: Hello!

# %%
# Test your SQL generator (after completing TODOs 9-12)
import importlib
import text2sql_engine
importlib.reload(text2sql_engine)
from text2sql_engine import generate_sql, execute_generated_sql, get_schema_for_prompt

schema_info = get_schema_for_prompt(conn)

# Test: Generate SQL for a simple question
sql = generate_sql("How many employees are in each department?", client, schema_info)
print(f"Generated SQL:\n{sql}\n")

# Test: Execute it
success, result = execute_generated_sql(sql, conn)
print(f"Success: {success}")
if success:
    print(result)
else:
    print(f"Error: {result}")
# Out:
# Generated SQL:
# SELECT
#     d.dept_name,
#     COUNT(e.emp_id) AS employee_count
# FROM departments d
# LEFT JOIN employees e ON d.dept_id = e.dept_id
# WHERE e.employment_status = 'Active'
# GROUP BY d.dept_id, d.dept_name
# ORDER BY employee_count DESC
#
# Success: True
#           dept_name  employee_count
# 0       Engineering              24
# 1             Sales              18
# 2      Data Science              17
# 3           Finance              12
# 4           Product              11
# 5  Customer Support              10
# 6         Marketing               9
# 7   Human Resources               6

# %% [markdown]
# ## Part 2F: Visualization Code Generator (TODOs 13-15)
#
# This is where it gets exciting — the AI will write Python visualization code based on query results. Given a question, the SQL, and the resulting DataFrame, it generates matplotlib/seaborn code to create an appropriate chart.
#
# Complete TODOs 13 through 15 in `text2sql_engine.py`.

# %%
# Test the visualization generator (after completing TODOs 13-15)
import importlib
import text2sql_engine
importlib.reload(text2sql_engine)
from text2sql_engine import generate_visualization_code

# First, get some data to visualize
test_sql = """
SELECT d.dept_name, COUNT(e.emp_id) as employee_count
FROM departments d
JOIN employees e ON d.dept_id = e.dept_id
GROUP BY d.dept_name
ORDER BY employee_count DESC
"""
test_df = pd.read_sql_query(test_sql, conn)
print("Data to visualize:")
print(test_df)

# Generate visualization code
viz_code = generate_visualization_code(
    "How many employees in each department?",
    test_sql,
    test_df,
    client
)
print(f"\nGenerated Python code:\n{viz_code}")

# Execute the visualization code
try:
    df = test_df  # Make 'df' available for the generated code
    exec(viz_code)
    if 'fig' in dir():
        plt.show()
    else:
        plt.show()
    print("\nVisualization generated successfully!")
except Exception as e:
    print(f"\nVisualization error: {e}")
    print("Check your generate_visualization_code() implementation.")
# Out:
# Data to visualize:
#           dept_name  employee_count
# 0       Engineering              25
# 1             Sales              20
# 2      Data Science              19
# 3           Finance              13
# 4         Marketing              12
# 5  Customer Support              12
# 6           Product              11
# 7   Human Resources               8
#
# Generated Python code:
# sns.set_style("darkgrid")
# plt.figure(figsize=(12, 7))
#
# plt.bar(df['dept_name'], df['employee_count'], color='steelblue', edgecolor='black', linewidth=1.2)
# plt.title('Number of Employees by Department', fontsize=16, fontweight='bold')
# plt.xlabel('Department', fontsize=12)
# plt.ylabel('Number of Employees', fontsize=12)
# plt.xticks(rotation=45, ha='right')
# plt.tick_params(axis='both', which='both', length=6, width=1.5)
#
# for i, v in enumerate(df['employee_count']):
#     plt.text(i, v + 0.3, str(v), ha='center', va='bottom', fontweight='bold')
#
# plt.tight_layout()
# fig = plt.gcf()
# Visualization generated successfully!

# %% [markdown]
# ## Part 2G: The Complete Engine (TODOs 16-17)
#
# Finally, wire everything together in the `Text2SQLEngine` class:
# - **TODO 16**: Initialize the schema and Gemini client
# - **TODO 17**: Implement the full `ask()` pipeline
#
# Complete TODOs 16 and 17 in `text2sql_engine.py`.

# %%
# Test the complete engine (after completing TODOs 16-17)
import importlib
import text2sql_engine
importlib.reload(text2sql_engine)
from text2sql_engine import Text2SQLEngine

# Create the engine with Claude API
engine = Text2SQLEngine(conn, api_key=ANTHROPIC_API_KEY)

# Test 1: Simple count
result = engine.ask("How many total employees does TechCorp have?")
print(f"\nSuccess: {result['success']}")

# Test 2: Aggregation with GROUP BY
result = engine.ask("What is the average salary by department? Include department name.")
print(f"\nSuccess: {result['success']}")

# Test 3: With visualization
result = engine.ask("Show employee count by career level", visualize=True)
if result.get('viz_code'):
    print(f"\nVisualization code generated ({len(result['viz_code'])} chars)")
    try:
        df = result['data']  # Make df available for the viz code
        exec(result['viz_code'])
        plt.show()
    except Exception as e:
        print(f"Viz error: {e}")
        print(f"\nGenerated code:\n{result['viz_code']}")  # Debug: show what was generated
        print(f"\nDataFrame columns: {result['data'].columns.tolist()}")  # Debug: show actual columns
# Out:
# Building schema context...
# ✓ Schema loaded: 5698 characters
# Initializing Claude API...
# ✓ Claude API connected: ready
#
# 🤔 Question: How many total employees does TechCorp have?
#
# 📝 Generated SQL:
# SELECT COUNT(*) AS total_employees
# FROM employees
# WHERE employment_status = 'Active'
#
# ✓ Query returned 1 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: Based on the query results, TechCorp currently has 107 total employees, indicating the company is in the small-to-medium enterprise category within the technology sector. This workforce size suggests TechCorp has moved beyond the startup phase but still maintains the agility and close-knit culture typical of growing tech companies.
#
# **Key insight:** With 107 employees, TechCorp is at a critical scaling point where organizational structure and processes become increasingly important for sustained growth.
#
# **Actionable recommendation:** Consider implementing formal departmental structures and standardized HR processes now, as companies typically experience growing pains when crossing the 100-employee threshold, and having proper systems in place will facilitate smoother expansion to the next growth phase.
#
#
# Success: True
#
# 🤔 Question: What is the average salary by department? Include department name.
#
# 📝 Generated SQL:
# SELECT
#     d.dept_name,
#     ROUND(AVG(e.salary), 2) AS average_salary
# FROM employees e
# JOIN departments d ON e.dept_id = d.dept_id
# WHERE e.employment_status = 'Active'
# GROUP BY d.dept_name
# ORDER BY average_salary DESC
#
# ✓ Query returned 8 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: The data reveals a clear salary hierarchy across departments, with Data Science leading at $140,176 average salary, followed by Product ($125,727) and Engineering ($121,958). There's a significant $51,176 gap between the highest-paid department (Data Science) and lowest-paid (Customer Support at $69,000), suggesting compensation may be tied to technical specialization and revenue impact.
#
# I recommend conducting a market analysis to ensure Customer Support salaries remain competitive for talent retention, as this department is crucial for customer satisfaction despite having the lowest average compensation.
#
#
# Success: True
#
# 🤔 Question: Show employee count by career level
#
# 📝 Generated SQL:
# SELECT
#     jt.level AS career_level,
#     COUNT(*) AS employee_count
# FROM employees e
# JOIN job_titles jt ON e.title_id = jt.title_id
# WHERE e.employment_status = 'Active'
# GROUP BY jt.level
# ORDER BY employee_count DESC
#
# ✓ Query returned 5 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: The data reveals a traditional pyramid structure with 45 mid-level employees representing the largest segment (42% of the workforce), while senior roles progressively decrease from 22 senior employees down to just 7 executives. A key insight is that the company has a healthy foundation with 21 entry-level employees but shows a potential talent pipeline bottleneck, as the gap between mid-level (45) and senior (22) employees suggests many mid-level staff may lack clear advancement opportunities. I recommend developing targeted leadership development programs and creating more senior-level positions to provide clearer career progression paths, which could improve retention of the substantial mid-level talent pool and ensure adequate succession planning for the limited executive tier.
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
#
# Visualization code generated (715 chars)

# %% [markdown]
# > **Takeaway**: You've built a complete AI-powered SQL engine from scratch\! The key insight is that each component (schema builder, validator, parser, generator, executor, visualizer) does one thing well, and the engine ties them all together. This modular design makes it easy to test, debug, and improve each piece independently.

# %% [markdown]
# ---
#
# # Part 3: Answer 12 Business Questions
#
# Now use your completed engine to answer real business questions. For each question:
#
# 1. **Ask** the engine using `engine.ask()`
# 2. **Review** the generated SQL — is it correct?
# 3. **Visualize** the results (use the engine's viz or write your own)
# 4. **Insight** — write a 1-2 sentence business takeaway
#
# **Tip**: If the AI generates incorrect SQL, refine your question and try again. Learning to prompt effectively IS the skill here.

# %% [markdown]
# ## Question 1: Compensation Overview
#
# *What is the average, minimum, and maximum salary for each department? Include the number of employees.*
#
# **Visualization hint**: Bar chart comparing departments

# %%
# Question 1: Compensation Overview
result_q1 = engine.ask('''
What is the average, minimum, and maximum salary for each department? 
Include the number of employees.
Create a grouped bar chart comparing average, minimum, and maximum salary for each department.
''', visualize=True)

# Display results
print("\n" + "="*80)
print("DATA RESULTS")
print("="*80)
print(result_q1['data'])

# NEW: Use safe_visualize instead of manual exec
from db_utils import safe_visualize
safe_visualize(result_q1)
# Out:
# 🤔 Question:
# What is the average, minimum, and maximum salary for each department?
# Include the number of employees.
# Create a grouped bar chart comparing average, minimum, and maximum salary for each department.
#
#
# 📝 Generated SQL:
# SELECT
#     d.dept_name,
#     ROUND(AVG(e.salary), 2) AS avg_salary,
#     MIN(e.salary) AS min_salary,
#     MAX(e.salary) AS max_salary,
#     COUNT(e.emp_id) AS employee_count
# FROM employees e
# JOIN departments d ON e.dept_id = d.dept_id
# WHERE e.employment_status = 'Active'
# GROUP BY d.dept_id, d.dept_name
# ORDER BY avg_salary DESC
#
# ✓ Query returned 8 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: ## Salary Analysis by Department
#
# **Key Insight:** Data Science leads in compensation with the highest average salary at $140,176, followed by Product ($125,727) and Engineering ($121,958), while Customer Support has the lowest average at $69,000 - creating a significant $71,176 gap between the highest and lowest-paid departments.
#
# **Actionable Recommendation:** The company should conduct a compensation equity review, particularly for Customer Support which shows both the lowest average salary and a narrow salary range ($47K-$100K), potentially limiting talent retention and growth in this critical customer-facing function.
#
# **Department Overview:** The 107 total employees are distributed across 8 departments, with Engineering having the largest team (24 employees) and HR the smallest (6 employees), suggesting different operational priorities and resource allocation across functions.
#
# *Note: A grouped bar chart visualization would effectively display the salary comparisons, with departments on the x-axis and three bars per department showing average, minimum, and maximum salaries.*
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
#
# ================================================================================
# DATA RESULTS
# ================================================================================
#           dept_name  avg_salary  min_salary  max_salary  employee_count
# 0      Data Science   140176.47       76000      193000              17
# 1           Product   125727.27       98000      200000              11
# 2       Engineering   121958.33       80000      196000              24
# 3         Marketing   100555.56       63000      160000               9
# 4           Finance    99666.67       56000      175000              12
# 5   Human Resources    94333.33       61000      161000               6
# 6             Sales    89000.00       54000      175000              18
# 7  Customer Support    69000.00       47000      100000              10
# ✓ Visualization generated successfully

# %%
# Business Insight for Question 1
from db_utils import generate_business_insight

print("\n" + "="*80)
print("GENERATING BUSINESS INSIGHT...")
print("="*80)

insight = generate_business_insight(result_q1, client)
print(insight)
# Out:
# ================================================================================
# GENERATING BUSINESS INSIGHT...
# ================================================================================
# BUSINESS INSIGHT - Departmental Salary Analysis Reveals Significant Compensation Disparities
#
# Key Findings:
# - Data Science leads compensation with an average salary of $140,176.47, while Customer Support trails at $69,000.00 - a gap of over $71,000 between highest and lowest paying departments
# - Engineering represents our largest department with 24 employees but ranks only 3rd in average compensation at $121,958.33
# - Sales has the second-largest headcount (18 employees) but the second-lowest average salary at $89,000.00, creating potential retention risks
# - Customer Support shows the narrowest salary range ($47,000-$100,000) while Product has the widest spread ($98,000-$200,000)
#
# Observations:
# - Technical departments (Data Science, Product, Engineering) consistently outpace business functions by $20,000-$50,000 in average compensation, reflecting market premiums for technical talent
# - Despite having smaller teams, specialized departments like Data Science (17) and Product (11) command premium compensation, suggesting successful talent competition strategies
# - Customer Support's compressed salary range and low averages may indicate limited career progression opportunities within the department
# - Finance and HR show moderate compensation levels but concerning salary ranges, with Finance spanning $56,000-$175,000, indicating potential internal equity issues
#
# Recommendations:
# - Conduct immediate market analysis for Sales and Customer Support roles to address potential 20-30% compensation gaps that could drive turnover in these customer-facing positions
# - Implement structured salary bands within Finance and HR to address the wide compensation ranges that may indicate inconsistent pay practices
# - Develop clear career progression frameworks for Customer Support to expand salary potential beyond the current $100,000 ceiling
# - Review Engineering compensation strategy given their large team size and critical business impact to ensure retention of our largest technical workforce
#
# Single Highest Impact:
# - Address Sales compensation immediately through market benchmarking and adjustment, as this 18-person revenue-generating team earning 36% less than technical roles poses the highest risk to business performance and talent retention.

# %% [markdown]
# ## Question 2: Pay Equity by Gender
#
# *Compare the average salary between male and female employees, broken down by career level (from job_titles).*
#
# **Visualization hint**: Grouped bar chart: level x gender

# %%
# Question 2: Pay Equity by Gender
result_q2 = engine.ask('''
Compare the average salary between male and female employees, 
broken down by career level.
Create a grouped bar chart with career levels on the x-axis and separate bars for male and female employees. Avoid using traditional gender color stereotypes (e.g., pink/blue). Instead, use a modern palette that is visually appealing and accessible to all viewers.
''', visualize=True)

# Display results
print("\n" + "="*80)
print("DATA RESULTS")
print("="*80)
print(result_q2['data'])

# Use safe_visualize
from db_utils import safe_visualize
safe_visualize(result_q2)
# Out:
# 🤔 Question:
# Compare the average salary between male and female employees,
# broken down by career level.
# Create a grouped bar chart with career levels on the x-axis and separate bars for male and female employees. Avoid using traditional gender color stereotypes (e.g., pink/blue). Instead, use a modern palette that is visually appealing and accessible to all viewers.
#
#
# 📝 Generated SQL:
# SELECT
#     jt.level AS career_level,
#     e.gender,
#     ROUND(AVG(e.salary), 2) AS avg_salary
# FROM employees e
# JOIN job_titles jt ON e.title_id = jt.title_id
# WHERE e.employment_status = 'Active'
#     AND e.gender IN ('M', 'F')
# GROUP BY jt.level, e.gender
# ORDER BY
#     CASE jt.level
#         WHEN 'Executive' THEN 1
#         WHEN 'Manager' THEN 2
#         WHEN 'Senior' THEN 3
#         WHEN 'Mid' THEN 4
#         WHEN 'Junior' THEN 5
#         ELSE 6
#     END,
#     e.gender
#
# ✓ Query returned 10 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: Looking at this salary data, there's a notable gender pay gap that varies significantly by career level. The most concerning disparity appears at the Senior level, where male employees earn an average of $130,200 compared to female employees at $114,857 - a gap of over $15,000. Interestingly, this pattern reverses at the Entry and Manager levels, where female employees actually earn slightly more ($69,167 vs $67,667 for Entry; $134,600 vs $134,286 for Manager).
#
# I recommend conducting a comprehensive pay equity audit focusing particularly on the Senior level, as this represents the largest gender pay gap and may indicate barriers to equitable compensation during mid-career advancement that could compound over time.
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
#
# ================================================================================
# DATA RESULTS
# ================================================================================
#   career_level gender  avg_salary
# 0    Executive      F   178666.67
# 1    Executive      M   181000.00
# 2      Manager      F   134600.00
# 3      Manager      M   134285.71
# 4       Senior      F   114857.14
# 5       Senior      M   130200.00
# 6          Mid      F    99454.55
# 7          Mid      M   104130.43
# 8        Entry      F    69166.67
# 9        Entry      M    67666.67
# ✓ Visualization generated successfully

# %%
# Business Insight for Question 2
from db_utils import generate_business_insight

print("\n" + "="*80)
print("GENERATING BUSINESS INSIGHT...")
print("="*80)

insight = generate_business_insight(result_q2, client)
print(insight)
# Out:
# ================================================================================
# GENERATING BUSINESS INSIGHT...
# ================================================================================
# BUSINESS INSIGHT - Gender Pay Gap Analysis Across Career Levels
#
# Key Findings:
# - Male employees earn more than female employees at Senior ($130,200 vs $114,857) and Mid-level ($104,130 vs $99,455) positions, representing gaps of $15,343 and $4,676 respectively.
# - Female employees slightly out-earn males at Executive ($178,667 vs $181,000), Manager ($134,600 vs $134,286), and Entry levels ($69,167 vs $67,667), though differences are minimal.
# - The largest absolute pay gap occurs at the Senior level where men earn 13.4% more than women.
# - Executive compensation shows the smallest gap with less than $2,400 difference between genders.
#
# Observations:
# - Pay equity appears strongest at entry and executive levels, suggesting potential bias emerges during mid-career progression phases.
# - The Senior level represents a critical inflection point where the gender pay gap is most pronounced, potentially impacting career advancement decisions.
# - Manager-level compensation shows near-perfect parity, indicating successful equity measures may already exist at this tier.
# - The pattern suggests systemic issues in mid-career compensation rather than organization-wide gender discrimination.
#
# Recommendations:
# - Conduct immediate pay equity audit for Senior and Mid-level positions to identify root causes of compensation disparities.
# - Implement standardized salary bands and transparent promotion criteria for mid-career roles to eliminate subjective compensation decisions.
# - Establish quarterly pay equity reviews with mandatory corrections when gaps exceed 5% without legitimate job-related justification.
# - Create mentorship and sponsorship programs specifically targeting female employees transitioning from Mid to Senior levels.
#
# Single Highest Impact:
# - Conduct comprehensive pay equity audit and implement immediate salary adjustments for Senior-level female employees to close the $15,343 gap, as this represents the most significant disparity and affects the pipeline to executive leadership.

# %% [markdown]
# ## Question 3: Top Performers vs. Compensation
#
# *For employees with a 2024 performance rating of 4 or 5, what is their average salary compared to those rated 1-3? Break it down by department.*
#
# **Visualization hint**: Show the gap between high and low performers

# %%
# Question 3: Top Performers vs. Compensation
result_q3 = engine.ask('''
For employees with a 2024 performance rating of 4 or 5, 
what is their average salary compared to those rated 1-3? 
Break it down by department.
Create a grouped bar chart comparing high performers (rating 4-5) vs average/low performers (rating 1-3) side by side for each department.
''', visualize=True)

# Display results
print("\n" + "="*80)
print("DATA RESULTS")
print("="*80)
print(result_q3['data'])

# Use safe_visualize
from db_utils import safe_visualize
safe_visualize(result_q3)
# Out:
# 🤔 Question:
# For employees with a 2024 performance rating of 4 or 5,
# what is their average salary compared to those rated 1-3?
# Break it down by department.
# Create a grouped bar chart comparing high performers (rating 4-5) vs average/low performers (rating 1-3) side by side for each department.
#
#
# 📝 Generated SQL:
# SELECT
#     d.dept_name,
#     CASE
#         WHEN pr.rating IN (4, 5) THEN 'High Performers (4-5)'
#         ELSE 'Average/Low Performers (1-3)'
#     END AS performance_group,
#     ROUND(AVG(e.salary), 2) AS avg_salary,
#     COUNT(*) AS employee_count
# FROM employees e
# JOIN departments d ON e.dept_id = d.dept_id
# JOIN performance_reviews pr ON e.emp_id = pr.emp_id
# WHERE pr.review_year = 2024
#     AND e.employment_status = 'Active'
#     AND pr.rating BETWEEN 1 AND 5
# GROUP BY d.dept_name,
#     CASE
#         WHEN pr.rating IN (4, 5) THEN 'High Performers (4-5)'
#         ELSE 'Average/Low Performers (1-3)'
#     END
# ORDER BY d.dept_name, performance_group;
#
# ✓ Query returned 16 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: **Key Insight**: The relationship between performance ratings and salary varies dramatically by department, with some departments showing counterintuitive patterns. Most notably, Finance shows high performers earning significantly less ($86,000) than average/low performers ($127,000), and Marketing follows a similar trend ($100,000 vs $123,000).
#
# **Actionable Recommendation**: HR should immediately review compensation structures in Finance and Marketing departments to ensure pay equity aligns with performance ratings, as the current inverse relationship may demotivate high performers and create retention risks.
#
# **Supporting Evidence**: While departments like Data Science ($151,333 vs $142,500) and Human Resources ($114,667 vs $80,500) show expected positive correlations between performance and pay, the salary gaps in underperforming departments are substantial - Finance shows a $41,000 disadvantage for high performers.
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
#
# ================================================================================
# DATA RESULTS
# ================================================================================
#            dept_name             performance_group  avg_salary  employee_count
# 0   Customer Support  Average/Low Performers (1-3)    67000.00               6
# 1   Customer Support         High Performers (4-5)    72000.00               4
# 2       Data Science  Average/Low Performers (1-3)   142500.00               6
# 3       Data Science         High Performers (4-5)   151333.33               9
# 4        Engineering  Average/Low Performers (1-3)   117888.89               9
# 5        Engineering         High Performers (4-5)   124400.00              15
# 6            Finance  Average/Low Performers (1-3)   127000.00               4
# 7            Finance         High Performers (4-5)    86000.00               8
# 8    Human Resources  Average/Low Performers (1-3)    80500.00               2
# 9    Human Resources         High Performers (4-5)   114666.67               3
# 10         Marketing  Average/Low Performers (1-3)   123000.00               3
# 11         Marketing         High Performers (4-5)   100000.00               4
# 12           Product  Average/Low Performers (1-3)   117000.00               2
# 13           Product         High Performers (4-5)   127666.67               9
# 14             Sales  Average/Low Performers (1-3)    86666.67               9
# 15             Sales         High Performers (4-5)    91333.33               9
# ✓ Visualization generated successfully

# %%
# Business Insight for Question 3
from db_utils import generate_business_insight

print("\n" + "="*80)
print("GENERATING BUSINESS INSIGHT...")
print("="*80)

insight = generate_business_insight(result_q3, client)
print(insight)
# Out:
# ================================================================================
# GENERATING BUSINESS INSIGHT...
# ================================================================================
# BUSINESS INSIGHT - Performance-Based Salary Analysis Reveals Compensation Misalignment
#
# Key Findings:
# - Finance shows a concerning inverse relationship with high performers earning $41,000 less than average/low performers ($86,000 vs $127,000), representing a 32% pay gap disadvantaging top talent
# - Data Science demonstrates the strongest positive correlation between performance and pay, with high performers earning $8,833 more on average ($151,333 vs $142,500)
# - Customer Support has the lowest overall salary ranges but maintains proper alignment with high performers earning $5,000 more than lower performers
# - Engineering leads in high performer retention with 15 top-rated employees earning $6,511 more than their lower-performing colleagues
#
# Observations:
# - Finance and Marketing departments both show negative correlations between performance and salary, creating significant retention risks for top talent in these critical business functions
# - Technical departments (Data Science, Engineering, Product) generally maintain better pay-for-performance alignment, suggesting more mature compensation structures
# - Human Resources shows strong performance-pay correlation with high performers earning 42% more, despite having the smallest team size (5 total employees)
# - Sales department shows minimal differentiation with only a $4,667 gap, potentially indicating compressed salary bands that may not adequately reward top performers
#
# Recommendations:
# - Immediately conduct salary equity reviews for Finance and Marketing departments to identify and correct the inverted compensation structures that penalize high performers
# - Implement performance-based salary adjustment guidelines across all departments, using Data Science's model as a benchmark for appropriate pay differentials
# - Establish minimum performance premium thresholds (suggest 5-10%) to ensure high performers receive meaningful compensation recognition compared to average performers
# - Create retention strategies specifically targeting the 12 high performers in Finance and Marketing who are currently earning below their lower-performing peers
#
# Single Highest Impact:
# - Conduct emergency salary adjustments for the 12 high performers in Finance and Marketing who are earning below market rate compared to their lower-performing colleagues, as this represents the highest flight risk and could result in losing top talent to competitors who properly compensate for performance.

# %% [markdown]
# ## Question 4: Hiring Trends Over Time
#
# *How many employees were hired each year? Show the trend from 2015 to 2025.*
#
# **Visualization hint**: Line chart showing hiring over time

# %%
# Question 4: Hiring Trends Over Time
result_q4 = engine.ask('''
How many employees were hired each year? 
Show the trend from 2015 to 2025.
Create a line chart showing hiring trends over time with years on the x-axis and number of hires on the y-axis.
''', visualize=True)

# Display results
print("\n" + "="*80)
print("DATA RESULTS")
print("="*80)
print(result_q4['data'])

from db_utils import safe_visualize
safe_visualize(result_q4)
# Out:
# 🤔 Question:
# How many employees were hired each year?
# Show the trend from 2015 to 2025.
# Create a line chart showing hiring trends over time with years on the x-axis and number of hires on the y-axis.
#
#
# 📝 Generated SQL:
# SELECT
#     CAST(strftime('%Y', hire_date) AS INTEGER) AS hire_year,
#     COUNT(*) AS hires_count
# FROM employees e
# WHERE hire_date IS NOT NULL
#     AND CAST(strftime('%Y', hire_date) AS INTEGER) BETWEEN 2015 AND 2025
# GROUP BY CAST(strftime('%Y', hire_date) AS INTEGER)
# ORDER BY hire_year
#
# ✓ Query returned 11 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: **Key Insight:** The company experienced significant growth in hiring from 2017-2021, peaking at 25 hires in 2021, but has seen a sharp decline since then, dropping to just 9 hires in 2024 and 3 in 2025.
#
# **Business Interpretation:** The hiring trend shows a clear growth phase from 2015-2021 (increasing from 2 to 25 annual hires), followed by a concerning downward trend from 2022-2025 (decreasing from 18 to 3 hires). This dramatic 88% reduction in hiring from peak levels suggests either successful organizational scaling, budget constraints, or market challenges impacting growth plans.
#
# **Recommendation:** Leadership should analyze whether the recent hiring slowdown aligns with strategic goals or indicates resource constraints that could limit future growth opportunities, particularly given the company's demonstrated ability to successfully scale hiring during the 2019-2021 period.
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
#
# ================================================================================
# DATA RESULTS
# ================================================================================
#     hire_year  hires_count
# 0        2015            2
# 1        2016            2
# 2        2017            4
# 3        2018            3
# 4        2019           18
# 5        2020           19
# 6        2021           25
# 7        2022           18
# 8        2023           17
# 9        2024            9
# 10       2025            3
# ✓ Visualization generated successfully

# %%
# Business Insight for Question 4
from db_utils import generate_business_insight

print("\n" + "="*80)
print("GENERATING BUSINESS INSIGHT...")
print("="*80)

insight = generate_business_insight(result_q4, client)
print(insight)
# Out:
# ================================================================================
# GENERATING BUSINESS INSIGHT...
# ================================================================================
# BUSINESS INSIGHT - Employee Hiring Trends Analysis (2015-2025)
#
# Key Findings:
# - TechCorp experienced dramatic hiring growth from 2015-2021, peaking at 25 hires in 2021 (a 1,150% increase from 2015's 2 hires)
# - Total hiring volume reached 120 employees over the 11-year period, with 62% of all hires occurring during the high-growth period of 2019-2021 (62 employees)
# - Hiring has declined significantly since 2021, dropping 64% to just 9 hires in 2024
# - The 2025 projection of 3 hires would represent the second-lowest hiring year in the dataset, matching early-stage company levels
#
# Observations:
# - The company shows a clear growth phase (2019-2021) followed by a contraction phase (2022-2025), suggesting potential market challenges or strategic shifts
# - Pre-2019 hiring was minimal and steady (2-4 hires annually), indicating TechCorp was likely in startup or early-stage mode during 2015-2018
# - The sharp decline from 25 hires (2021) to 18 hires (2022) marks the beginning of a consistent downward trend that continues through 2025
# - Current hiring levels are approaching the company's earliest operational years, which may impact growth capacity and competitive positioning
#
# Recommendations:
# - Conduct immediate workforce planning analysis to determine if current hiring levels align with business objectives and revenue targets
# - Implement retention strategies for existing employees, as the hiring slowdown increases the importance of maintaining institutional knowledge and key talent
# - Evaluate whether the hiring decline is strategic cost management or an unintended consequence of market conditions requiring course correction
# - Develop scenario-based hiring models for 2025-2026 to ensure adequate staffing for anticipated business needs and growth opportunities
#
# Single Highest Impact:
# - Launch a comprehensive workforce strategy review to determine optimal hiring levels for 2025, as the current trajectory toward minimal hiring (3 employees) may severely limit TechCorp's ability to execute growth initiatives and maintain competitive market position after building significant organizational capacity during 2019-2021.

# %% [markdown]
# ## Question 5: Salary Growth Analysis
#
# *What is the average total salary increase (from first to latest salary in salary_history) per department? Which department gives the biggest raises?*
#
# **Visualization hint**: Horizontal bar chart

# %%
# Question 5: Salary Growth Analysis
result_q5 = engine.ask('''
What is the average total salary increase (from first to latest salary in salary_history) 
per department? Which department gives the biggest raises?
Create a horizontal bar chart showing average salary increase by department, sorted from highest to lowest.
''', visualize=True)

# Display results
print("\n" + "="*80)
print("DATA RESULTS")
print("="*80)
print(result_q5['data'])

from db_utils import safe_visualize
safe_visualize(result_q5)
# Out:
# 🤔 Question:
# What is the average total salary increase (from first to latest salary in salary_history)
# per department? Which department gives the biggest raises?
# Create a horizontal bar chart showing average salary increase by department, sorted from highest to lowest.
#
#
# 📝 Generated SQL:
# SELECT
#     d.dept_name,
#     ROUND(AVG(salary_increase), 2) AS avg_salary_increase
# FROM (
#     SELECT
#         e.dept_id,
#         e.emp_id,
#         MAX(sh.new_salary) - MIN(sh.old_salary) AS salary_increase
#     FROM employees e
#     JOIN salary_history sh ON e.emp_id = sh.emp_id
#     GROUP BY e.dept_id, e.emp_id
#     HAVING COUNT(sh.history_id) > 0
# ) emp_increases
# JOIN departments d ON emp_increases.dept_id = d.dept_id
# GROUP BY d.dept_id, d.dept_name
# ORDER BY avg_salary_increase DESC
#
# ✓ Query returned 8 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: **Business Interpretation:**
#
# Data Science leads in salary growth with an average increase of $28,467, followed closely by Human Resources at $25,833, while Customer Support lags significantly behind at only $11,833. This 140% gap between the highest and lowest departments suggests inconsistent career progression opportunities across the organization.
#
# **Recommendation:** The company should investigate why Customer Support and Sales (at $17,211) have substantially lower salary growth trajectories and consider implementing more structured career advancement programs for these departments to improve retention and employee satisfaction.
#
# Here's the horizontal bar chart showing average salary increase by department:
#
# ```python
# import matplotlib.pyplot as plt
# import pandas as pd
#
# # Data from query results
# data = {
#     'dept_name': ['Data Science', 'Human Resources', 'Engineering', 'Product',
#                   'Finance', 'Marketing', 'Sales', 'Customer Support'],
#     'avg_salary_increase': [28466.67, 25833.33, 23840.00, 22000.00,
#                            19076.92, 18800.00, 17210.53, 11833.33]
# }
#
# df = pd.DataFrame(data)
#
# # Create horizontal bar chart
# plt.figure(figsize=(10, 6))
# bars = plt.barh(df['dept_name'], df['avg_salary_increase'], color='steelblue')
# plt.xlabel('Average Salary Increase ($)')
# plt.title('Average Salary Increase by Department')
# plt.gca().invert_yaxis()  # Highest at top
#
# # Add value labels on bars
# for i, bar in enumerate(bars):
#     width = bar.get_width()
#     plt.text(width + 500, bar.get_y() + bar.get_height()/2,
#              f'${width:,.0f}', ha='left', va='center')
#
# plt.tight_layout()
# plt.show()
# ```
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
#
# ================================================================================
# DATA RESULTS
# ================================================================================
#           dept_name  avg_salary_increase
# 0      Data Science             28466.67
# 1   Human Resources             25833.33
# 2       Engineering             23840.00
# 3           Product             22000.00
# 4           Finance             19076.92
# 5         Marketing             18800.00
# 6             Sales             17210.53
# 7  Customer Support             11833.33
# ✓ Visualization generated successfully

# %%
# Business Insight for Question 5
from db_utils import generate_business_insight

print("\n" + "="*80)
print("GENERATING BUSINESS INSIGHT...")
print("="*80)

insight = generate_business_insight(result_q5, client)
print(insight)
# Out:
# ================================================================================
# GENERATING BUSINESS INSIGHT...
# ================================================================================
# BUSINESS INSIGHT - Department Salary Increase Analysis
#
# Key Findings:
# - Data Science leads with the highest average salary increases at $28,466.67, followed closely by Human Resources at $25,833.33
# - Customer Support shows significantly lower salary growth at $11,833.33, representing 58% less than the top-performing department
# - There's a $16,633.34 gap between the highest (Data Science) and lowest (Customer Support) average salary increases across departments
# - Sales department, despite being revenue-generating, ranks second-lowest at $17,210.53 average increase
#
# Observations:
# - Technical and strategic departments (Data Science, HR, Engineering) consistently outpace customer-facing departments in salary progression
# - The salary increase disparity suggests potential retention risks in lower-growth departments like Customer Support and Sales
# - Product and Finance departments fall in the middle range ($19K-$22K), indicating moderate but consistent salary growth
# - The data reveals a clear tier system where specialized skills command significantly higher salary advancement
#
# Recommendations:
# - Conduct immediate compensation equity review for Customer Support and Sales to address retention risks and ensure competitive positioning
# - Implement standardized salary progression frameworks across all departments to reduce the $16K+ gap between highest and lowest increases
# - Benchmark Customer Support and Sales compensation against market rates, as these departments may be experiencing talent flight
# - Create cross-departmental mentorship programs to help lower-growth departments understand career advancement strategies used in higher-growth areas
#
# Single Highest Impact:
# - Launch a comprehensive compensation audit and market benchmarking study for Customer Support and Sales departments, with immediate budget allocation for salary adjustments, as these customer-facing roles are critical for revenue generation and retention yet show the lowest growth potential.

# %% [markdown]
# ## Question 6: Project Staffing & Budget
#
# *For each active project, show the project name, budget, number of team members, and budget per team member. Which projects are most/least resourced?*
#
# **Visualization hint**: Bar chart of budget per head

# %%
# Question 6: Project Staffing & Budget
result_q6 = engine.ask('''
For each active project, show the project name, budget, number of team members, 
and budget per team member. Which projects are most or least resourced?
Create a bar chart showing budget per team member for each project, sorted from highest to lowest.
''', visualize=True)

# Display results
print("\n" + "="*80)
print("DATA RESULTS")
print("="*80)
print(result_q6['data'])

# Use safe_visualize
from db_utils import safe_visualize
safe_visualize(result_q6)
# Out:
# 🤔 Question:
# For each active project, show the project name, budget, number of team members,
# and budget per team member. Which projects are most or least resourced?
# Create a bar chart showing budget per team member for each project, sorted from highest to lowest.
#
#
# 📝 Generated SQL:
# SELECT
#     p.project_name,
#     p.budget,
#     COUNT(pa.emp_id) AS team_members,
#     ROUND(CAST(p.budget AS REAL) / COUNT(pa.emp_id), 2) AS budget_per_member
# FROM projects p
# JOIN project_assignments pa ON p.project_id = pa.project_id
# WHERE p.status IN ('Active', 'In Progress')
# GROUP BY p.project_id, p.project_name, p.budget
# ORDER BY budget_per_member DESC;
#
# ✓ Query returned 8 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: **Key Insight:** There's a significant resource allocation disparity across active projects, with budget per team member ranging from $100,000 (ML Recommendation Engine) to just $13,571 (Social Media Expansion and Budget Forecasting Tool) - a 7x difference.
#
# **Actionable Recommendation:** Consider reviewing the resource allocation for the two lowest-funded projects (Social Media Expansion and Budget Forecasting Tool at $13,571 per member each), as this may indicate either under-resourcing that could impact delivery quality, or an opportunity to reallocate budget from higher-resourced projects like ML Recommendation Engine ($100,000 per member).
#
# The data suggests that technical infrastructure projects (ML, Cloud Migration, West Coast Expansion) receive significantly more resources than operational tools and customer-facing features. Management should evaluate whether this allocation aligns with strategic priorities and project complexity requirements.
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
#
# ================================================================================
# DATA RESULTS
# ================================================================================
#                project_name  budget  team_members  budget_per_member
# 0  ML Recommendation Engine  500000             5          100000.00
# 1      West Coast Expansion  450000             6           75000.00
# 2   Cloud Migration Phase 2  520000             7           74285.71
# 3       Self-Service Portal  200000             6           33333.33
# 4  Customer Feedback System  160000             6           26666.67
# 5     Onboarding Automation  110000             5           22000.00
# 6    Social Media Expansion   95000             7           13571.43
# 7   Budget Forecasting Tool   95000             7           13571.43
# ✓ Visualization generated successfully

# %%
# Business Insight for Question 6
from db_utils import generate_business_insight

print("\n" + "="*80)
print("GENERATING BUSINESS INSIGHT...")
print("="*80)

insight = generate_business_insight(result_q6, client)
print(insight)
# Out:
# ================================================================================
# GENERATING BUSINESS INSIGHT...
# ================================================================================
# BUSINESS INSIGHT - Project Resource Allocation Analysis
#
# Key Findings:
# - ML Recommendation Engine is the most resourced project at $100,000 per team member, significantly higher than the average of $44,803 per member across all projects
# - Two projects (Social Media Expansion and Budget Forecasting Tool) are severely under-resourced at only $13,571 per team member each
# - There's a dramatic 7.4x difference between the highest and lowest resourced projects, indicating major resource allocation inconsistencies
# - West Coast Expansion and Cloud Migration Phase 2 represent mid-tier resource allocation at $75,000 and $74,286 per member respectively
#
# Observations:
# - Higher budget projects don't necessarily correlate with higher per-member allocation, as Cloud Migration Phase 2 has the largest total budget ($520,000) but ranks third in per-member resources
# - Four projects fall below $30,000 per team member, suggesting potential resource constraints that could impact delivery quality and timelines
# - Team sizes are relatively consistent (5-7 members), indicating the resource disparity is driven by budget allocation rather than team composition
# - The bottom two projects have identical budgets ($95,000) but both are managing 7-person teams, raising concerns about project scope versus available resources
#
# Recommendations:
# - Conduct immediate resource rebalancing by either increasing budgets for under-resourced projects or reducing their scope to match available funding
# - Establish standardized resource allocation guidelines based on project complexity, strategic importance, and required skill levels to prevent future disparities
# - Review the Social Media Expansion and Budget Forecasting Tool projects for potential consolidation or timeline extension given their limited per-member budgets
# - Implement quarterly resource allocation reviews to identify and address resource imbalances before they impact project outcomes
#
# Single Highest Impact:
# - Immediately reassess and rebalance resources for the four projects below $30,000 per member, as this severe under-resourcing likely threatens project success and team productivity, potentially causing strategic initiatives to fail or deliver subpar results.

# %% [markdown]
# ## Question 7: Remote Work Distribution
#
# *How does work mode (Remote/Hybrid/On-site) vary across departments? Show the count for each combination.*
#
# **Visualization hint**: Stacked bar chart or heatmap

# %%
# Question 7: Remote Work Distribution
result_q7 = engine.ask('''
How does work mode (Remote/Hybrid/On-site) vary across departments? 
Show the count for each combination.
Create a stacked bar chart showing the distribution of work modes within each department.
Also Create a heatmap showing the distribution of work modes within each department.
Side by side
''', visualize=True)

# Display results
print("\n" + "="*80)
print("DATA RESULTS")
print("="*80)
print(result_q7['data'])

# Use safe_visualize
from db_utils import safe_visualize
safe_visualize(result_q7)
# Out:
# 🤔 Question:
# How does work mode (Remote/Hybrid/On-site) vary across departments?
# Show the count for each combination.
# Create a stacked bar chart showing the distribution of work modes within each department.
# Also Create a heatmap showing the distribution of work modes within each department.
# Side by side
#
#
# 📝 Generated SQL:
# SELECT
#     d.dept_name,
#     e.work_mode,
#     COUNT(*) AS employee_count
# FROM employees e
# JOIN departments d ON e.dept_id = d.dept_id
# WHERE e.employment_status = 'Active'
# GROUP BY d.dept_name, e.work_mode
# ORDER BY d.dept_name, e.work_mode
#
# ✓ Query returned 22 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: Looking at the work mode distribution across departments, **Engineering shows the most flexibility with equal split between Remote (9) and Hybrid (9) workers, while Sales leans heavily toward On-site work (8 out of 18 employees)**. Notably, Marketing and Product departments have no On-site employees, operating entirely in Remote/Hybrid models.
#
# **Key insight**: There's significant variation in work mode preferences across departments, with customer-facing roles like Sales favoring on-site presence, while technical departments like Engineering embrace more flexible arrangements.
#
# **Recommendation**: Consider standardizing remote work policies within similar department types - Sales and Customer Support could benefit from Engineering's balanced hybrid approach to improve employee satisfaction while maintaining necessary face-to-face interactions.
#
# Here are the visualizations showing work mode distribution:
#
# ```python
# import matplotlib.pyplot as plt
# import seaborn as sns
# import pandas as pd
# import numpy as np
#
# # Create the data
# data = {
#     'dept_name': ['Customer Support', 'Customer Support', 'Customer Support',
#                   'Data Science', 'Data Science', 'Data Science',
#                   'Engineering', 'Engineering', 'Engineering',
#                   'Finance', 'Finance', 'Finance',
#                   'Human Resources', 'Human Resources', 'Human Resources',
#                   'Marketing', 'Marketing',
#                   'Product', 'Product',
#                   'Sales', 'Sales', 'Sales'],
#     'work_mode': ['Hybrid', 'On-site', 'Remote',
#                   'Hybrid', 'On-site', 'Remote',
#                   'Hybrid', 'On-site', 'Remote',
#                   'Hybrid', 'On-site', 'Remote',
#                   'Hybrid', 'On-site', 'Remote',
#                   'Hybrid', 'Remote',
#                   'Hybrid', 'Remote',
#                   'Hybrid', 'On-site', 'Remote'],
#     'employee_count': [2, 5, 3, 5, 6, 6, 9, 6, 9, 5, 4, 3, 2, 3, 1, 5, 4, 7, 4, 6, 8, 4]
# }
#
# df = pd.DataFrame(data)
#
# # Create figure with subplots
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))
#
# # 1. Stacked Bar Chart
# pivot_df = df.pivot(index='dept_name', columns='work_mode', values='employee_count').fillna(0)
# pivot_df.plot(kind='bar', stacked=True, ax=ax1,
#               color=['#FF6B6B', '#4ECDC4', '#45B7D1'])
# ax1.set_title('Work Mode Distribution by Department\n(Stacked Bar Chart)', fontsize=14, fontweight='bold')
# ax1.set_xlabel('Department', fontweight='bold')
# ax1.set_ylabel('Number of Employees', fontweight='bold')
# ax1.legend(title='Work Mode', bbox_to_anchor=(1.05, 1), loc='upper left')
# ax1.tick_params(axis='x', rotation=45)
#
# # 2. Heatmap
# pivot_df_pct = pivot_df.div(pivot_df.sum(axis=1), axis=0) * 100
# sns.heatmap(pivot_df_pct.T, annot=True, fmt='.1f', cmap='YlOrRd',
#             ax=ax2, cbar_kws={'label': 'Percentage'})
# ax2.set_title('Work Mode Distribution by Department\n(Heatmap - Percentage)', fontsize=14, fontweight='bold')
# ax2.set_xlabel('Department', fontweight='bold')
# ax2.set_ylabel('Work Mode', fontweight='bold')
# ax2.tick_params(axis='x', rotation=45)
#
# plt.tight_layout()
# plt.show()
#
# # Print summary statistics
# print("\nSummary Statistics:")
# print("="*50)
# print(f"Total employees: {df['employee_count'].sum()}")
# print(f"Departments with no on-site workers: {len(pivot_df[pivot_
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
#
# ================================================================================
# DATA RESULTS
# ================================================================================
#            dept_name work_mode  employee_count
# 0   Customer Support    Hybrid               2
# 1   Customer Support   On-site               5
# 2   Customer Support    Remote               3
# 3       Data Science    Hybrid               5
# 4       Data Science   On-site               6
# 5       Data Science    Remote               6
# 6        Engineering    Hybrid               9
# 7        Engineering   On-site               6
# 8        Engineering    Remote               9
# 9            Finance    Hybrid               5
# 10           Finance   On-site               4
# 11           Finance    Remote               3
# 12   Human Resources    Hybrid               2
# 13   Human Resources   On-site               3
# 14   Human Resources    Remote               1
# 15         Marketing    Hybrid               5
# 16         Marketing    Remote               4
# 17           Product    Hybrid               7
# 18           Product    Remote               4
# 19             Sales    Hybrid               6
# 20             Sales   On-site               8
# 21             Sales    Remote               4
# ✓ Visualization generated successfully

# %%
# Business Insight for Question 7
from db_utils import generate_business_insight

print("\n" + "="*80)
print("GENERATING BUSINESS INSIGHT...")
print("="*80)

insight = generate_business_insight(result_q7, client)
print(insight)
# Out:
# ================================================================================
# GENERATING BUSINESS INSIGHT...
# ================================================================================
# BUSINESS INSIGHT - Work Mode Distribution Analysis Across Departments
#
# Key Findings:
# - Engineering shows the highest adoption of flexible work arrangements with 18 employees working remotely or hybrid (75% of the department) versus only 6 on-site
# - Customer Support heavily favors on-site work with 5 out of 10 employees (50%) working on-site, compared to just 2 hybrid and 3 remote
# - Marketing and Product departments have eliminated on-site work entirely, operating with only hybrid and remote arrangements
# - Sales maintains the highest on-site presence with 8 employees (44% of department), suggesting client-facing roles still require physical presence
#
# Observations:
# - Technical departments (Engineering, Data Science, Product) demonstrate greater work mode flexibility, with Data Science showing perfect balance across all three modes
# - Customer-facing departments show mixed patterns: Sales retains high on-site presence while Marketing has gone fully flexible
# - Human Resources shows the least remote work adoption (only 1 employee) despite being a support function, indicating potential policy implementation challenges
# - Total workforce distribution shows 43% working in flexible arrangements (hybrid/remote) versus 40% on-site across active employees
#
# Recommendations:
# - Investigate Customer Support's high on-site requirement to identify opportunities for hybrid arrangements that could improve employee satisfaction without compromising service quality
# - Develop department-specific work mode guidelines that acknowledge the operational differences between technical, customer-facing, and administrative functions
# - Address the Human Resources department's low remote work adoption, as this may signal inconsistency in policy implementation or modeling for other departments
# - Establish regular reviews of work mode effectiveness by department to ensure arrangements align with both business needs and employee preferences
#
# Single Highest Impact:
# - Conduct a comprehensive review of Customer Support operations to enable hybrid work options, as this department shows the lowest flexibility despite having roles that could potentially support remote work, which could significantly improve retention in a traditionally high-turnover function.

# %% [markdown]
# ## Question 8: Training Completion Rates
#
# *What percentage of training enrollments are completed vs. in progress vs. enrolled? Break down by training category.*
#
# **Visualization hint**: Stacked bar chart by category

# %%
# Question 8: Training Completion Rates
result_q8 = engine.ask('''
What percentage of training enrollments are completed vs. in progress vs. planned? 
Break down by training category.

Return data with columns: category, status, percentage
where status is one of: Completed, In Progress, Planned
and percentage is the percent of total for that category.

IMPORTANT: Write a simple query using subqueries in the FROM clause.
Do NOT use WITH clauses or CTEs - they are causing syntax errors.
Use inline subqueries instead.
''', visualize=False)

# Display results
print("\n" + "="*80)
print("DATA RESULTS")
print("="*80)
print(result_q8['data'])

# Manual stacked bar chart with percentages
if result_q8['success'] and result_q8['data'] is not None:
    import matplotlib.pyplot as plt
    import seaborn as sns
    
    df = result_q8['data']
    
    # Pivot for stacked bar
    pivot_df = df.pivot(index='category', columns='status', values='percentage')
    
    # Create stacked bar
    sns.set_style("darkgrid")
    fig, ax = plt.subplots(figsize=(12, 7))
    
    pivot_df.plot(kind='bar', stacked=True, ax=ax,
                  color=['mediumseagreen', 'coral', 'steelblue'],
                  edgecolor='black', linewidth=1.2)
    
    # Add percentage labels on each segment
    for container in ax.containers:
        ax.bar_label(container, fmt='%.0f%%', label_type='center', fontsize=10)
    
    ax.set_xlabel('Training Category', fontsize=12)
    ax.set_ylabel('Percentage (%)', fontsize=12)
    ax.set_title('Training Status Distribution by Category', fontsize=16, fontweight='bold')
    ax.legend(title='Status', fontsize=10)
    plt.xticks(rotation=45, ha='right')
    plt.tick_params(axis='both', which='both', length=6, width=1.5)
    plt.tight_layout()
    plt.show()
# Out:
# 🤔 Question:
# What percentage of training enrollments are completed vs. in progress vs. planned?
# Break down by training category.
#
# Return data with columns: category, status, percentage
# where status is one of: Completed, In Progress, Planned
# and percentage is the percent of total for that category.
#
# IMPORTANT: Write a simple query using subqueries in the FROM clause.
# Do NOT use WITH clauses or CTEs - they are causing syntax errors.
# Use inline subqueries instead.
#
#
# 📝 Generated SQL:
# SELECT
#     category,
#     status,
#     ROUND(COUNT(*) * 100.0 / (
#         SELECT COUNT(*)
#         FROM training_records tr2
#         WHERE tr2.category = tr.category
#     ), 2) AS percentage
# FROM training_records tr
# GROUP BY category, status
# ORDER BY category, status
#
# ✓ Query returned 18 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: ## Business Interpretation
#
# The data reveals that training completion rates are consistently strong across all categories, ranging from 58.46% (Compliance) to 65.43% (Soft Skills), indicating effective training delivery and engagement. However, Compliance training shows the lowest completion rate at 58.46% and highest enrollment rate at 21.54%, suggesting potential bottlenecks in this critical area.
#
# **Key Insight:** Sales training has the highest rate of learners in progress (22.58%), which may indicate either high engagement or potential completion challenges in this category.
#
# **Recommendation:** Focus immediate attention on Compliance training by investigating barriers to completion and implementing targeted interventions, as regulatory training completion is typically mandatory and the 58.46% completion rate may pose compliance risks.
#
#
# ================================================================================
# DATA RESULTS
# ================================================================================
#         category       status  percentage
# 0     Compliance    Completed       58.46
# 1     Compliance     Enrolled       21.54
# 2     Compliance  In Progress       20.00
# 3     Leadership    Completed       65.00
# 4     Leadership     Enrolled       20.00
# 5     Leadership  In Progress       15.00
# 6   Professional    Completed       64.77
# 7   Professional     Enrolled       14.77
# 8   Professional  In Progress       20.45
# 9          Sales    Completed       61.29
# 10         Sales     Enrolled       16.13
# 11         Sales  In Progress       22.58
# 12   Soft Skills    Completed       65.43
# 13   Soft Skills     Enrolled       14.81
# 14   Soft Skills  In Progress       19.75
# 15     Technical    Completed       64.66
# 16     Technical     Enrolled       17.29
# 17     Technical  In Progress       18.05

# %%
# Business Insight for Question 8
from db_utils import generate_business_insight

print("\n" + "="*80)
print("GENERATING BUSINESS INSIGHT...")
print("="*80)

insight = generate_business_insight(result_q8, client)
print(insight)
# Out:
# ================================================================================
# GENERATING BUSINESS INSIGHT...
# ================================================================================
# BUSINESS INSIGHT - Training Completion and Engagement Analysis
#
# Key Findings:
# - Compliance training shows the lowest completion rate at 58.46%, significantly trailing other categories which average 64-65% completion
# - Leadership and Soft Skills training demonstrate the highest completion rates at 65.00% and 65.43% respectively
# - Sales training has the highest in-progress rate at 22.58%, indicating active engagement but potential completion challenges
# - Enrolled status (not yet started) ranges from 14.77% to 21.54%, with Compliance showing the highest percentage of employees who haven't begun training
#
# Observations:
# - There's a concerning inverse relationship between mandatory nature and completion rates - Compliance (likely mandatory) has the worst completion while discretionary Leadership/Soft Skills excel
# - Professional and Technical training show balanced engagement with moderate completion rates (64.77% and 64.66%) and reasonable in-progress rates around 18-20%
# - The 20+ percentage point gap between highest and lowest completion rates suggests systemic issues with certain training programs rather than universal engagement problems
# - Sales training's high in-progress rate combined with moderate completion suggests learners may be struggling with content difficulty or time allocation
#
# Recommendations:
# - Redesign Compliance training delivery method and content engagement - consider microlearning modules or gamification to improve the 58.46% completion rate
# - Investigate Sales training bottlenecks causing high in-progress rates (22.58%) through learner feedback and completion time analysis
# - Implement automated reminder systems for enrolled learners, particularly in Compliance where 21.54% haven't started their assigned training
# - Create completion incentive programs modeled after successful Leadership/Soft Skills approaches for struggling categories
#
# Single Highest Impact:
# - Immediately audit and redesign the Compliance training program structure and delivery method, as its 7+ percentage point completion gap likely represents the largest population of incomplete mandatory training, creating both regulatory risk and resource waste.

# %% [markdown]
# ## Question 9: Manager Effectiveness
#
# *For each manager, show how many direct reports they have and the average performance rating of their team (from 2024 reviews).*
#
# **Visualization hint**: Scatter plot: team size vs avg rating

# %%
# Question 9: Manager Effectiveness
result_q9 = engine.ask('''
For each manager, show how many direct reports they have and the average performance rating 
of their team from 2024 reviews.
Create a scatter plot with team size on the x-axis and average team performance rating on the y-axis.
''', visualize=True)

# Display results
print("\n" + "="*80)
print("DATA RESULTS")
print("="*80)
print(result_q9['data'])

# Use safe_visualize
from db_utils import safe_visualize
safe_visualize(result_q9)
# Out:
# 🤔 Question:
# For each manager, show how many direct reports they have and the average performance rating
# of their team from 2024 reviews.
# Create a scatter plot with team size on the x-axis and average team performance rating on the y-axis.
#
#
# 📝 Generated SQL:
# SELECT
#     m.first_name || ' ' || m.last_name AS manager_name,
#     COUNT(e.emp_id) AS team_size,
#     ROUND(AVG(pr.rating), 2) AS avg_team_rating
# FROM employees m
# JOIN employees e ON m.emp_id = e.manager_id
# LEFT JOIN performance_reviews pr ON e.emp_id = pr.emp_id AND pr.review_year = 2024
# WHERE m.employment_status = 'Active'
#     AND e.employment_status = 'Active'
# GROUP BY m.emp_id, m.first_name, m.last_name
# HAVING COUNT(e.emp_id) > 0
# ORDER BY team_size DESC
#
# ✓ Query returned 18 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: Based on the data, there appears to be a weak negative correlation between team size and average performance ratings, with larger teams generally showing lower performance scores. For example, Robert Carter manages the largest team (16 people) but has a below-average rating of 3.64, while smaller teams like Miguel Brooks' (4 people, 4.00 rating) and Nicole Johnson's (3 people, 4.67 rating) achieve higher performance scores.
#
# The standout concern is Steven Garcia's team of 3 people with an average rating of only 2.33 - significantly lower than all other managers. I recommend conducting a targeted review of Steven Garcia's management practices and providing additional leadership support or training, as his team's performance is substantially below the company average regardless of team size.
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
#
# ================================================================================
# DATA RESULTS
# ================================================================================
#        manager_name  team_size  avg_team_rating
# 0     Robert Carter         16             3.64
# 1    Timothy Wright         12             3.67
# 2    Jessica Howard         11             3.82
# 3   Victor Campbell          9             3.89
# 4       Megan Clark          7             3.29
# 5         Elena Lee          5             3.80
# 6     Miguel Brooks          4             4.00
# 7       Grace Moore          4             3.50
# 8   Nathan Thompson          3             3.00
# 9      Brian Wright          3             3.50
# 10    Steven Garcia          3             2.33
# 11    Ashley Wright          3             3.67
# 12   Nicole Johnson          3             4.67
# 13    James Sanchez          2             3.00
# 14   Timothy Garcia          2             3.50
# 15       Omar Lewis          2             3.00
# 16  Michael Roberts          2             4.50
# 17   Sophia Stewart          1             4.00
# ✓ Visualization generated successfully

# %%
# Business Insight for Question 9
from db_utils import generate_business_insight

print("\n" + "="*80)
print("GENERATING BUSINESS INSIGHT...")
print("="*80)

insight = generate_business_insight(result_q9, client)
print(insight)
# Out:
# ================================================================================
# GENERATING BUSINESS INSIGHT...
# ================================================================================
# BUSINESS INSIGHT - Manager Performance and Team Size Analysis
#
# Key Findings:
# - 18 active managers oversee teams ranging from 1-16 direct reports, with the largest teams led by Robert Carter (16) and Timothy Wright (12)
# - Average team performance ratings span from 2.33 to 4.67, indicating significant variation in team performance across managers
# - Smaller teams show the highest performance ratings, with Nicole Johnson's 3-person team achieving 4.67 and Michael Roberts' 2-person team at 4.50
# - Larger teams (10+ members) consistently perform in the mid-range (3.64-3.89), suggesting potential management capacity constraints
#
# Observations:
# - No clear correlation exists between team size and performance, as both high and low ratings appear across various team sizes
# - Three managers have teams with concerning ratings below 3.5: Steven Garcia (2.33), Megan Clark (3.29), and Nathan Thompson (3.00)
# - The most balanced performance comes from mid-sized teams (4-9 members), with managers like Victor Campbell and Miguel Brooks achieving strong results
# - Performance variance is highest among smaller teams (1-3 members), ranging from 3.00 to 4.67, indicating inconsistent management effectiveness at this scale
#
# Recommendations:
# - Implement immediate performance coaching for Steven Garcia, Megan Clark, and Nathan Thompson to address underperforming teams
# - Establish mentoring partnerships between high-performing managers (Nicole Johnson, Michael Roberts, Miguel Brooks) and those with lower ratings
# - Review workload distribution for managers with 12+ direct reports to ensure adequate attention and development time per employee
# - Create standardized team management practices and success metrics to reduce the wide performance variance across similar-sized teams
#
# Single Highest Impact:
# - Provide intensive management development training for Steven Garcia (2.33 rating) as his team's performance is critically low and poses the greatest risk to overall organizational productivity and employee retention.

# %% [markdown]
# ## Question 10: Tenure vs. Performance
#
# *Is there a relationship between how long an employee has been at the company (tenure in years) and their latest performance rating?*
#
# **Visualization hint**: Scatter plot with trend line

# %%
# Question 10: Tenure vs. Performance
result_q10 = engine.ask('''
Show the relationship between employee tenure and performance rating.
Calculate tenure as years since hire_date.
Get the most recent performance rating for each employee.

Return ONLY two columns: tenure_years and latest_rating

IMPORTANT: Use a simple query with inline subqueries.
Do NOT use WITH clauses or CTEs.

Create a scatter plot with tenure on x-axis and rating on y-axis with trend line.
''', visualize=True)

# Display results
print("\n" + "="*80)
print("DATA RESULTS")
print("="*80)
print(result_q10['data'])

# Use safe_visualize
from db_utils import safe_visualize
safe_visualize(result_q10)
# Out:
# 🤔 Question:
# Show the relationship between employee tenure and performance rating.
# Calculate tenure as years since hire_date.
# Get the most recent performance rating for each employee.
#
# Return ONLY two columns: tenure_years and latest_rating
#
# IMPORTANT: Use a simple query with inline subqueries.
# Do NOT use WITH clauses or CTEs.
#
# Create a scatter plot with tenure on x-axis and rating on y-axis with trend line.
#
#
# 📝 Generated SQL:
# SELECT
#     ROUND((julianday('now') - julianday(e.hire_date)) / 365.25, 2) AS tenure_years,
#     (SELECT pr.rating
#      FROM performance_reviews pr
#      WHERE pr.emp_id = e.emp_id
#      ORDER BY pr.review_year DESC, pr.review_date DESC
#      LIMIT 1) AS latest_rating
# FROM employees e
# WHERE e.employment_status = 'Active'
#     AND (SELECT pr.rating
#          FROM performance_reviews pr
#          WHERE pr.emp_id = e.emp_id
#          ORDER BY pr.review_year DESC, pr.review_date DESC
#          LIMIT 1) IS NOT NULL
#
# ✓ Query returned 102 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: Looking at the data, there appears to be a weak relationship between employee tenure and performance ratings, with most employees clustered around ratings of 3-4 regardless of their years of service. Notably, some of the company's longest-tenured employees (9+ years) are receiving average ratings of 3, while several newer employees (under 3 years) are achieving top ratings of 5.
#
# **Key Insight**: High performers can be found across all tenure levels, but there may be a concerning pattern of performance stagnation among long-term employees, as evidenced by veterans like the 11.2-year employee with only a rating of 3.
#
# **Recommendation**: Implement targeted development programs for mid-to-senior tenure employees (5+ years) to re-engage and challenge them, while also studying what drives the high performance of newer employees to replicate those conditions company-wide.
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
#
# ================================================================================
# DATA RESULTS
# ================================================================================
#      tenure_years  latest_rating
# 0            9.70              4
# 1            9.06              3
# 2            5.31              3
# 3            7.35              4
# 4            6.11              5
# ..            ...            ...
# 97           1.89              5
# 98           2.48              3
# 99           6.39              2
# 100          6.48              4
# 101          5.20              5
#
# [102 rows x 2 columns]
# ✓ Visualization generated successfully

# %%
# Business Insight for Question 10
from db_utils import generate_business_insight

print("\n" + "="*80)
print("GENERATING BUSINESS INSIGHT...")
print("="*80)

insight = generate_business_insight(result_q10, client)
print(insight)
# Out:
# ================================================================================
# GENERATING BUSINESS INSIGHT...
# ================================================================================
# BUSINESS INSIGHT - Employee Tenure vs Performance Relationship Analysis
#
# Key Findings:
# - Dataset includes 102 active employees with tenure ranging from 1.84 to 11.20 years and performance ratings from 1-5 scale
# - High performers (rating 5) are distributed across all tenure levels, with 13 employees achieving top ratings regardless of years of service
# - Concerning performance issues identified: 4 employees with poor ratings (1-2), including one long-tenured employee at 5.13 years with rating of 1
# - Mid-level performers (rating 3-4) represent the majority at 85 employees, suggesting potential for performance improvement initiatives
#
# Observations:
# - No clear correlation exists between tenure and performance rating, indicating that longevity doesn't automatically translate to higher performance
# - Several newer employees (under 3 years) achieved rating 5, while some veterans (6+ years) scored rating 3, suggesting onboarding and development programs may be more impactful than experience alone
# - The 4-6 year tenure range shows mixed performance outcomes, potentially indicating a critical period where employees either excel or plateau
# - Distribution shows most employees cluster around rating 4, suggesting either grade inflation or need for more differentiated performance evaluation criteria
#
# Recommendations:
# - Implement targeted development programs for the 85 mid-level performers (ratings 3-4) to unlock their potential for advancement to top-tier performance
# - Conduct immediate performance improvement plans for the 4 employees with ratings 1-2, especially focusing on root cause analysis for the underperforming long-tenured employee
# - Analyze and replicate success factors from the 13 high-performing employees across different tenure levels to create mentorship or best practice sharing programs
# - Review performance evaluation methodology to ensure ratings accurately reflect contribution differences and aren't skewed toward the middle of the scale
#
# Single Highest Impact:
# - Create a structured mentorship program pairing the 13 top performers (rating 5) with mid-level employees (rating 3-4) to accelerate development, as this leverages existing talent to improve the largest group of employees and can drive organization-wide performance gains without external hiring costs.

# %% [markdown]
# ## Question 11: Department Budget Utilization
#
# *Compare each department's annual budget to its total payroll (sum of salaries). Which departments are over/under budget?*
#
# **Visualization hint**: Grouped bar: budget vs payroll

# %%
# Question 11: Department Budget Utilization
result_q11 = engine.ask('''
Compare each department's annual budget to its total payroll (sum of salaries). 
Which departments are over or under budget?
Create a grouped bar chart with departments on the x-axis and separate bars for annual budget and total payroll.
''', visualize=True)

# Display results
print("\n" + "="*80)
print("DATA RESULTS")
print("="*80)
print(result_q11['data'])

# Use safe_visualize
from db_utils import safe_visualize
safe_visualize(result_q11)
# Out:
# 🤔 Question:
# Compare each department's annual budget to its total payroll (sum of salaries).
# Which departments are over or under budget?
# Create a grouped bar chart with departments on the x-axis and separate bars for annual budget and total payroll.
#
#
# 📝 Generated SQL:
# SELECT
#     d.dept_name,
#     d.annual_budget,
#     COALESCE(SUM(e.salary), 0) AS total_payroll,
#     d.annual_budget - COALESCE(SUM(e.salary), 0) AS budget_difference,
#     CASE
#         WHEN d.annual_budget > COALESCE(SUM(e.salary), 0) THEN 'Under Budget'
#         WHEN d.annual_budget < COALESCE(SUM(e.salary), 0) THEN 'Over Budget'
#         ELSE 'At Budget'
#     END AS budget_status
# FROM departments d
# LEFT JOIN employees e ON d.dept_id = e.dept_id
#     AND e.employment_status = 'Active'
# GROUP BY d.dept_id, d.dept_name, d.annual_budget
# ORDER BY d.dept_name
#
# ✓ Query returned 8 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: **Key Business Insight & Recommendation**
#
# Most departments (6 out of 8) are operating under budget, with Sales showing the largest absolute savings of $498,000. However, Data Science is significantly over budget by $883,000 (59% over their $1.5M allocation), which is concerning and requires immediate attention.
#
# **Recommendation:** Conduct an urgent review of Data Science's spending patterns and consider reallocating some of the substantial budget surplus from other departments (particularly the $495K from Marketing and $498K from Sales) to cover the Data Science shortfall while implementing stricter budget controls for that department.
#
# Here's the grouped bar chart visualization:
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # Data
# departments = ['Customer\nSupport', 'Data\nScience', 'Engineering', 'Finance',
#                'Human\nResources', 'Marketing', 'Product', 'Sales']
# annual_budget = [850000, 1500000, 3200000, 1100000, 900000, 1400000, 1800000, 2100000]
# total_payroll = [690000, 2383000, 2927000, 1196000, 566000, 905000, 1383000, 1602000]
#
# # Create grouped bar chart
# x = np.arange(len(departments))
# width = 0.35
#
# fig, ax = plt.subplots(figsize=(12, 6))
# bars1 = ax.bar(x - width/2, annual_budget, width, label='Annual Budget', color='steelblue', alpha=0.8)
# bars2 = ax.bar(x + width/2, total_payroll, width, label='Total Payroll', color='orange', alpha=0.8)
#
# ax.set_xlabel('Departments')
# ax.set_ylabel('Amount ($)')
# ax.set_title('Department Annual Budget vs Total Payroll Comparison')
# ax.set_xticks(x)
# ax.set_xticklabels(departments)
# ax.legend()
# ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, p: f'${x/1000000:.1f}M'))
#
# # Add grid for better readability
# ax.grid(True, alpha=0.3, axis='y')
#
# plt.xticks(rotation=45, ha='right')
# plt.tight_layout()
# plt.show()
# ```
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
#
# ================================================================================
# DATA RESULTS
# ================================================================================
#           dept_name  annual_budget  total_payroll  budget_difference  \
# 0  Customer Support         850000         690000             160000
# 1      Data Science        1500000        2383000            -883000
# 2       Engineering        3200000        2927000             273000
# 3           Finance        1100000        1196000             -96000
# 4   Human Resources         900000         566000             334000
# 5         Marketing        1400000         905000             495000
# 6           Product        1800000        1383000             417000
# 7             Sales        2100000        1602000             498000
#
#   budget_status
# 0  Under Budget
# 1   Over Budget
# 2  Under Budget
# 3   Over Budget
# 4  Under Budget
# 5  Under Budget
# 6  Under Budget
# 7  Under Budget
# ✓ Visualization generated successfully

# %%
# Business Insight for Question 11
from db_utils import generate_business_insight

print("\n" + "="*80)
print("GENERATING BUSINESS INSIGHT...")
print("="*80)

insight = generate_business_insight(result_q11, client)
print(insight)
# Out:
# ================================================================================
# GENERATING BUSINESS INSIGHT...
# ================================================================================
# BUSINESS INSIGHT - Department Budget vs. Payroll Analysis
#
# Key Findings:
# - Data Science department is significantly over budget by $883,000 (159% of budget), representing the most critical budget variance
# - Six out of eight departments are under budget, with Sales showing the largest dollar surplus of $498,000
# - Finance department is over budget by $96,000, though this represents a smaller percentage variance (109% of budget)
# - Total company-wide budget surplus is $298,000 ($12.85M budgeted vs. $12.55M in payroll)
#
# Observations:
# - Data Science's budget overrun suggests either unrealistic initial budgeting or uncontrolled hiring/compensation growth
# - Under-budget departments like Sales ($498K under) and Product ($417K under) may indicate understaffing or conservative compensation structures
# - The two over-budget departments (Data Science and Finance) represent critical functions that require immediate attention
# - Marketing shows the second-largest absolute surplus ($495K), which could represent missed growth opportunities
#
# Recommendations:
# - Conduct immediate review of Data Science headcount and compensation levels to understand root causes of the $883K overrun
# - Assess whether under-budget departments have adequate staffing to meet business objectives, particularly Sales and Product
# - Implement quarterly budget monitoring with variance thresholds (e.g., ±10%) to catch deviations earlier
# - Reallocate surplus funds from significantly under-budget departments to support strategic initiatives or address over-budget situations
#
# Single Highest Impact:
# - Address Data Science's $883,000 budget overrun through immediate headcount and compensation audit, as this represents 69% of total budget variance and could indicate systemic issues with talent acquisition costs or budget planning in critical technical roles.

# %% [markdown]
# ## Question 12: Cross-Functional Collaboration
#
# *Which employees work on projects outside their own department? Show their name, home department, and the project department.*
#
# **Visualization hint**: This is a complex multi-table JOIN — review the SQL carefully\!

# %%
# Question 12: Cross-Functional Collaboration
result_q12 = engine.ask('''
Which employees work on projects outside their own department? 
Show their name, home department, and the project department.
Create a bar chart showing the count of cross-functional collaborations by department.
''', visualize=True)

# Display results
print("\n" + "="*80)
print("DATA RESULTS")
print("="*80)
print(result_q12['data'])

# Use safe_visualize
from db_utils import safe_visualize
safe_visualize(result_q12)
# Out:
# 🤔 Question:
# Which employees work on projects outside their own department?
# Show their name, home department, and the project department.
# Create a bar chart showing the count of cross-functional collaborations by department.
#
#
# 📝 Generated SQL:
# SELECT
#     e.first_name || ' ' || e.last_name AS employee_name,
#     d1.dept_name AS home_department,
#     d2.dept_name AS project_department,
#     COUNT(*) AS collaboration_count
# FROM employees e
# JOIN departments d1 ON e.dept_id = d1.dept_id
# JOIN project_assignments pa ON e.emp_id = pa.emp_id
# JOIN projects p ON pa.project_id = p.project_id
# JOIN departments d2 ON p.dept_id = d2.dept_id
# WHERE e.dept_id != p.dept_id
# GROUP BY e.emp_id, e.first_name, e.last_name, d1.dept_name, d2.dept_name
# ORDER BY d1.dept_name, employee_name
#
# ✓ Query returned 24 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: Based on the analysis of 24 cross-functional collaborations, Data Science leads in cross-departmental project work with 6 employees collaborating outside their home department, followed by Marketing, Product, and Sales with 4 employees each. The most common collaboration pattern shows employees frequently working with Marketing (6 collaborations) and Sales (4 collaborations), suggesting these departments serve as central hubs for cross-functional initiatives.
#
# **Key Insight**: Data Science demonstrates the strongest cross-functional engagement, with team members like Carlos Peterson working across multiple departments (Customer Support and Finance), indicating this department's versatile skill set and broad organizational impact.
#
# **Recommendation**: Consider formalizing cross-functional collaboration processes, particularly leveraging Data Science expertise and Marketing's central role, to create structured knowledge-sharing programs that could increase innovation and break down departmental silos across the organization.
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
#
# ================================================================================
# DATA RESULTS
# ================================================================================
#       employee_name   home_department project_department  collaboration_count
# 0     Rachel Morris  Customer Support        Engineering                    1
# 1     Ashley Howard      Data Science    Human Resources                    1
# 2   Carlos Peterson      Data Science   Customer Support                    1
# 3   Carlos Peterson      Data Science            Finance                    1
# 4      Matthew Chen      Data Science        Engineering                    1
# 5          Omar Lee      Data Science            Finance                    1
# 6        Robert Lee      Data Science            Product                    1
# 7   Ashley Thompson       Engineering          Marketing                    1
# 8       Miguel Hill       Engineering          Marketing                    1
# 9       Omar Garcia       Engineering              Sales                    1
# 10      Ananya Reed           Finance        Engineering                    1
# 11        Omar Gray           Finance    Human Resources                    1
# 12        Omar Gray           Finance          Marketing                    1
# 13        Lisa Wang         Marketing    Human Resources                    1
# 14  Michelle Wright         Marketing            Product                    1
# 15      Omar Brooks         Marketing              Sales                    1
# 16   Timothy Garcia         Marketing   Customer Support                    1
# 17    Ashley Wright           Product          Marketing                    1
# 18     Chloe Nelson           Product              Sales                    1
# 19    Hannah Carter           Product              Sales                    1
# 20   Nicole Johnson           Product              Sales                    1
# 21       David Gray             Sales        Engineering                    1
# 22   Rachel Ramirez             Sales          Marketing                    1
# 23     Sarah Taylor             Sales    Human Resources                    1
# ✓ Visualization generated successfully

# %%
# Business Insight for Question 12
from db_utils import generate_business_insight

print("\n" + "="*80)
print("GENERATING BUSINESS INSIGHT...")
print("="*80)

insight = generate_business_insight(result_q12, client)
print(insight)
# Out:
# ================================================================================
# GENERATING BUSINESS INSIGHT...
# ================================================================================
# # BUSINESS INSIGHT - Cross-Functional Collaboration Analysis
#
# ## Key Findings:
# - 24 employees across all 8 departments are actively engaged in cross-functional projects, demonstrating healthy inter-departmental collaboration
# - Data Science leads cross-functional participation with 5 employees (21% of collaborations), followed by Product department with 4 employees
# - Customer Support shows minimal cross-functional engagement with only 1 employee working outside their department
# - Each collaboration involves single project assignments, suggesting focused rather than scattered cross-functional work
#
# ## Observations:
# - Data Science employees show the most diverse collaboration patterns, working across 4 different departments (HR, Customer Support, Finance, Engineering), indicating their versatile skill applications
# - Product department employees concentrate their external collaborations primarily in Sales (3 out of 4 collaborations), revealing a strong product-sales pipeline relationship
# - Omar Gray from Finance demonstrates exceptional cross-functional engagement, working on both HR and Marketing projects - a notable individual contributor pattern
# - Engineering and Marketing show balanced bidirectional collaboration, with each department having employees working in the other's projects
#
# ## Recommendations:
# - Expand Customer Support's cross-functional involvement by identifying projects where their customer insights could benefit other departments, particularly Product development
# - Create structured rotation programs for high-performing cross-functional contributors like Omar Gray to formally mentor and develop similar capabilities in other employees
# - Establish regular cross-departmental project showcases to highlight successful collaborations and encourage knowledge sharing between departments
# - Develop metrics to track the business impact of these cross-functional projects to justify continued investment in inter-departmental collaboration
#
# ## Single Highest Impact:
# - **Implement a formal Cross-Functional Excellence Program** that pairs high-performing collaborative employees (like those from Data Science) with departments showing low engagement (like Customer Support) to systematically build cross-departmental capabilities and break down organizational silos.

# %% [markdown]
# ---
#
# # Part 4: Building the LLM-Powered Auto-Visualizer
#
# You already implemented  (TODO 13-14). Now let's put it to serious use — building a reusable function that takes any question, generates SQL, runs it, and automatically creates the best visualization.

# %%
def ask_and_visualize(engine, question):
    """
    Complete pipeline: question -> SQL -> data -> auto-visualization.

    Uses the engine to generate SQL and data, then uses Claude to
    generate appropriate matplotlib/seaborn code for the results.
    """
    # Step 1: Get the data
    result = engine.ask(question, show_sql=True, interpret=True, visualize=True)

    if not result['success'] or result['data'] is None:
        print("Query failed — cannot visualize.")
        return result

    df = result['data']

    # Step 2: Try auto-generated visualization
    if result.get('viz_code'):
        print("\n--- Auto-Generated Visualization ---")
        try:
            exec(result['viz_code'])
            plt.show()
        except Exception as e:
            print(f"Auto-viz failed: {e}")
            print("Falling back to basic chart...")

            # Fallback: simple automatic chart
            numeric_cols = df.select_dtypes(include='number').columns.tolist()
            non_numeric = [c for c in df.columns if c not in numeric_cols]

            if numeric_cols and non_numeric:
                fig, ax = plt.subplots(figsize=(10, 5))
                df.plot(x=non_numeric[0], y=numeric_cols[0], kind='bar', ax=ax)
                ax.set_title(question[:60])
                plt.tight_layout()
                plt.show()

    return result

# %%
# Demo: Ask a complex question and get auto-visualization
result = ask_and_visualize(engine, 
    "Show the average salary and average performance rating by department for 2024"
)
# Out:
# 🤔 Question: Show the average salary and average performance rating by department for 2024
#
# 📝 Generated SQL:
# SELECT
#     d.dept_name,
#     ROUND(AVG(e.salary), 2) AS avg_salary,
#     ROUND(AVG(pr.rating), 2) AS avg_performance_rating
# FROM departments d
# JOIN employees e ON d.dept_id = e.dept_id
# LEFT JOIN performance_reviews pr ON e.emp_id = pr.emp_id AND pr.review_year = 2024
# WHERE e.employment_status = 'Active'
# GROUP BY d.dept_id, d.dept_name
# ORDER BY d.dept_name
#
# ✓ Query returned 8 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: **Key Insight:** There's a strong correlation between compensation and performance, with Data Science ($140,176) and Product ($125,727) departments showing both the highest salaries and top performance ratings (3.67 and 3.91 respectively).
#
# **Critical Finding:** Customer Support significantly underperforms with the lowest salary ($69,000) and poorest performance rating (3.20), creating a potential service quality risk.
#
# **Recommendation:** Immediately investigate and address the Customer Support department's compensation and performance gaps, as this directly impacts customer experience and retention—consider salary adjustments and targeted performance improvement programs to bring their 3.20 rating closer to the company average of 3.63.
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
#
# --- Auto-Generated Visualization ---

# %%
# Another demo with a different chart type
result = ask_and_visualize(engine,
    "What percentage of employees are Remote, Hybrid, and On-site in each department?"
)
# Out:
# 🤔 Question: What percentage of employees are Remote, Hybrid, and On-site in each department?
#
# 📝 Generated SQL:
# SELECT
#     d.dept_name,
#     e.work_mode,
#     COUNT(*) AS employee_count,
#     ROUND(COUNT(*) * 100.0 / dept_totals.total_employees, 2) AS percentage
# FROM employees e
# JOIN departments d ON e.dept_id = d.dept_id
# JOIN (
#     SELECT
#         dept_id,
#         COUNT(*) AS total_employees
#     FROM employees
#     WHERE employment_status = 'Active'
#     GROUP BY dept_id
# ) dept_totals ON e.dept_id = dept_totals.dept_id
# WHERE e.employment_status = 'Active'
# GROUP BY d.dept_name, e.work_mode, dept_totals.total_employees
# ORDER BY d.dept_name, e.work_mode
#
# ✓ Query returned 22 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: Based on the data, there's significant variation in work arrangements across departments, with Marketing (55.6% hybrid) and Product (63.6% hybrid) being the most hybrid-focused, while Customer Support maintains the highest on-site presence at 50%. A key insight is that Marketing and Product departments have completely eliminated on-site work, suggesting these roles may be inherently more suitable for flexible work arrangements.
#
# I recommend conducting a comprehensive review of role requirements across all departments, particularly examining why Customer Support requires 50% on-site presence while similar customer-facing roles in other departments operate successfully with remote/hybrid models. This analysis could help optimize work arrangements and potentially reduce real estate costs while maintaining productivity.
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
#
# --- Auto-Generated Visualization ---

# %%
# Test with another question
result = engine.ask("How many employees per department?", visualize=True)
df = result['data']
exec(result['viz_code'])
plt.show()
# Out:
# 🤔 Question: How many employees per department?
#
# 📝 Generated SQL:
# SELECT
#     d.dept_name,
#     COUNT(e.emp_id) AS employee_count
# FROM departments d
# LEFT JOIN employees e ON d.dept_id = e.dept_id
# WHERE e.employment_status = 'Active' OR e.employment_status IS NULL
# GROUP BY d.dept_id, d.dept_name
# ORDER BY employee_count DESC
#
# ✓ Query returned 8 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: **Key Insight:** Engineering dominates our workforce with 24 employees, representing over twice the size of our smallest departments like Human Resources (6) and Marketing (9), indicating a strong technical focus in our organizational structure.
#
# **Actionable Recommendation:** Consider expanding the Marketing team, as the 9-person department may be understaffed relative to our 18-person Sales team - typically a 2:1 sales-to-marketing ratio suggests we could benefit from additional marketing support to generate more qualified leads for our substantial sales force.
#
# 📊 Generating visualization code...
# ✓ Visualization code generated

# %% [markdown]
# ## Challenge: Improve the Visualizer
#
# The auto-visualizer works but isn't perfect. Try improving it:
#
# 1. **Better prompts**: Modify `generate_visualization_code()` in `text2sql_engine.py` to produce better charts. Add rules about color schemes, figure sizes, and annotation.
#
# 2. **Error recovery**: What happens when the generated code fails? Implement a smarter fallback that looks at the data shape and picks an appropriate chart automatically.
#
# 3. **Multiple charts**: For complex queries (e.g., salary distribution), generate multiple visualizations (histogram + box plot).

# %%
# ============================================================================
# BONUS QUESTION: Multi-Chart Salary Distribution Analysis
# ============================================================================
# Demonstrating multiple complementary visualizations for distribution data

print("\n" + "="*80)
print("BONUS: SALARY DISTRIBUTION - MULTI-CHART ANALYSIS")
print("="*80)

result_bonus = engine.ask('''
Show the distribution of all employee salaries.
Return only the salary column for active employees.
''', visualize=False)

# Display results
print("\n" + "="*80)
print("DATA RESULTS")
print("="*80)
print(f"Total employees: {len(result_bonus['data'])}")
print(f"Salary range: ${result_bonus['data']['salary'].min():,.0f} - ${result_bonus['data']['salary'].max():,.0f}")
print(f"Mean: ${result_bonus['data']['salary'].mean():,.0f}")
print(f"Median: ${result_bonus['data']['salary'].median():,.0f}")

# Multi-Chart Visualization
if result_bonus['success'] and result_bonus['data'] is not None:
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np
    
    df = result_bonus['data']
    
    # Create figure with 3 subplots
    sns.set_style("darkgrid")
    fig, axes = plt.subplots(1, 3, figsize=(18, 7))
    
    # Chart 1: Histogram
    axes[0].hist(df['salary'], bins=20, color='steelblue', edgecolor='black', linewidth=1.2)
    axes[0].set_xlabel('Salary ($)', fontsize=12)
    axes[0].set_ylabel('Frequency', fontsize=12)
    axes[0].set_title('Histogram\n(Distribution Shape)', fontsize=14, fontweight='bold')
    axes[0].tick_params(axis='both', which='both', length=6, width=1.5)
    
    # Add mean/median lines
    axes[0].axvline(df['salary'].mean(), color='coral', linestyle='--', linewidth=2, label=f'Mean: ${df["salary"].mean():,.0f}')
    axes[0].axvline(df['salary'].median(), color='mediumseagreen', linestyle='--', linewidth=2, label=f'Median: ${df["salary"].median():,.0f}')
    axes[0].legend(fontsize=10)
    
    # Chart 2: Box Plot
    bp = axes[1].boxplot(df['salary'], patch_artist=True, widths=0.5,
                         boxprops=dict(facecolor='steelblue', edgecolor='black', linewidth=1.2),
                         whiskerprops=dict(color='black', linewidth=1.2),
                         capprops=dict(color='black', linewidth=1.2),
                         medianprops=dict(color='coral', linewidth=2))
    axes[1].set_ylabel('Salary ($)', fontsize=12)
    axes[1].set_title('Box Plot\n(Quartiles & Outliers)', fontsize=14, fontweight='bold')
    axes[1].tick_params(axis='both', which='both', length=6, width=1.5)
    axes[1].set_xticks([1])
    axes[1].set_xticklabels(['Salaries'])
    
    # Chart 3: Violin Plot
    parts = axes[2].violinplot([df['salary']], showmeans=True, showmedians=True, widths=0.7)
    for pc in parts['bodies']:
        pc.set_facecolor('steelblue')
        pc.set_edgecolor('black')
        pc.set_linewidth(1.2)
        pc.set_alpha(0.8)
    parts['cmeans'].set_color('coral')
    parts['cmedians'].set_color('mediumseagreen')
    axes[2].set_ylabel('Salary ($)', fontsize=12)
    axes[2].set_title('Violin Plot\n(Density Distribution)', fontsize=14, fontweight='bold')
    axes[2].tick_params(axis='both', which='both', length=6, width=1.5)
    axes[2].set_xticks([1])
    axes[2].set_xticklabels(['Salaries'])
    
    # Overall title
    plt.suptitle('Employee Salary Distribution - Multiple Perspectives', 
                 fontsize=18, fontweight='bold', y=1.02)
    plt.tight_layout()
    plt.show()
    
    print("\n✓ Multi-chart visualization displayed")
    print("  - Histogram shows the distribution shape")
    print("  - Box plot reveals quartiles and outliers")
    print("  - Violin plot shows density at different salary levels")
# Out:
# ================================================================================
# BONUS: SALARY DISTRIBUTION - MULTI-CHART ANALYSIS
# ================================================================================
#
# 🤔 Question:
# Show the distribution of all employee salaries.
# Return only the salary column for active employees.
#
#
# 📝 Generated SQL:
# SELECT salary
# FROM employees
# WHERE employment_status = 'Active'
#
# ✓ Query returned 107 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: Based on the salary distribution of 101 active employees, there's a significant pay disparity with salaries ranging from $47,000 to $200,000 - a gap of over $150,000. The data shows a wide spread across different compensation levels, suggesting employees span various roles, experience levels, and departments within the organization.
#
# **Key insight:** The company has substantial salary variation, with roughly 20% of employees earning below $70,000 while about 15% earn above $150,000, indicating a diverse workforce structure.
#
# **Recommendation:** Conduct a comprehensive pay equity analysis by role, department, and experience level to ensure fair compensation practices and identify any potential gaps that may impact retention and recruitment efforts.
#
#
# ================================================================================
# DATA RESULTS
# ================================================================================
# Total employees: 107
# Salary range: $47,000 - $200,000
# Mean: $108,897
# Median: $102,000
# ✓ Multi-chart visualization displayed
#   - Histogram shows the distribution shape
#   - Box plot reveals quartiles and outliers
#   - Violin plot shows density at different salary levels

# %%
# ============================================================================
# PART 4 CHALLENGE 3: Automatic Multi-Chart Detection Test
# ============================================================================
# Demonstrating the engine's ability to automatically detect distribution
# queries and generate multiple complementary visualizations (histogram, 
# box plot, and violin plot) for comprehensive data analysis.
# ============================================================================
print("\n" + "="*80)
print("TESTING AUTOMATIC MULTI-CHART GENERATION")
print("="*80)

# Reload engine with updated TODO 13
import importlib
import text2sql_engine
importlib.reload(text2sql_engine)
from text2sql_engine import Text2SQLEngine

engine = Text2SQLEngine(conn, api_key=ANTHROPIC_API_KEY)

# Test 1: Should trigger multi-chart (distribution keyword + RAW DATA)
print("\n📊 Test 1: Distribution with raw continuous data")
result_dist1 = engine.ask('''
Calculate the tenure in years for each active employee (from hire_date to today).
Return one row per employee with: emp_id, tenure_years
Do NOT group, bin, or aggregate - return individual employee tenure values.
This is for distribution analysis showing spread of tenure across all employees.
''', visualize=True)

if result_dist1['success']:
    print(f"\nData shape: {result_dist1['data'].shape}")
    print(f"Columns: {result_dist1['data'].columns.tolist()}")
    print("\nFirst 5 rows:")
    print(result_dist1['data'].head())
    
    if result_dist1['viz_code']:
        print("\n" + "="*80)
        print("Generated code contains 'subplots'?", 'subplots' in result_dist1['viz_code'])
        print("="*80)
        
        df = result_dist1['data']
        exec(result_dist1['viz_code'])
        plt.show()

# Test 2: Should NOT trigger multi-chart (comparison)
print("\n📊 Test 2: Category comparison (should be single chart)")
result_single = engine.ask('''
How many employees in each department?
''', visualize=True)

if result_single['viz_code']:
    print("Generated code length:", len(result_single['viz_code']))
    print("Contains 'subplots':", 'subplots' in result_single['viz_code'])
    df = result_single['data']
    exec(result_single['viz_code'])
    plt.show()
# Out:
# ================================================================================
# TESTING AUTOMATIC MULTI-CHART GENERATION
# ================================================================================
# Building schema context...
# ✓ Schema loaded: 5698 characters
# Initializing Claude API...
# ✓ Claude API connected: ready
#
# 📊 Test 1: Distribution with raw continuous data
#
# 🤔 Question:
# Calculate the tenure in years for each active employee (from hire_date to today).
# Return one row per employee with: emp_id, tenure_years
# Do NOT group, bin, or aggregate - return individual employee tenure values.
# This is for distribution analysis showing spread of tenure across all employees.
#
#
# 📝 Generated SQL:
# SELECT
#     emp_id,
#     ROUND((julianday('now') - julianday(hire_date)) / 365.25, 2) AS tenure_years
# FROM employees
# WHERE employment_status = 'Active'
#
# ✓ Query returned 107 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: **Business Interpretation:**
#
# The employee tenure data reveals a well-distributed workforce with tenures ranging from 1.0 to 11.2 years, indicating healthy mix of experience levels. A key insight is that the company has strong mid-level retention, with many employees in the 4-7 year range, but notably fewer very senior employees (only 4 employees with 9+ years tenure out of 101 total).
#
# **Recommendation:** Focus on senior talent retention strategies, as there appears to be attrition among longer-tenured employees after the 7-8 year mark. Consider implementing specialized retention programs, career advancement opportunities, or enhanced benefits for employees approaching their 7th year to bridge them into senior roles and preserve institutional knowledge.
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
#
# Data shape: (107, 2)
# Columns: ['emp_id', 'tenure_years']
#
# First 5 rows:
#    emp_id  tenure_years
# 0       1          9.70
# 1       2          9.06
# 2       3          5.31
# 3       4          7.35
# 4       5          6.11
#
# ================================================================================
# Generated code contains 'subplots'? True
# ================================================================================
# <string>:29: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
# 📊 Test 2: Category comparison (should be single chart)
#
# 🤔 Question:
# How many employees in each department?
#
#
# 📝 Generated SQL:
# SELECT
#     d.dept_name,
#     COUNT(e.emp_id) AS employee_count
# FROM departments d
# LEFT JOIN employees e ON d.dept_id = e.dept_id
# WHERE e.employment_status = 'Active' OR e.employment_status IS NULL
# GROUP BY d.dept_id, d.dept_name
# ORDER BY employee_count DESC
#
# ✓ Query returned 8 rows
#
# 🧠 Generating interpretation...
#
# 💡 Insight: The data reveals that Engineering dominates our workforce with 24 employees, representing over 20% of our total staff, while customer-facing departments like Sales (18) and Customer Support (10) combined account for 28 employees. This distribution suggests we're heavily invested in product development and technical capabilities, which aligns with a technology company's core focus.
#
# However, I recommend evaluating whether our Customer Support team of 10 employees is adequately sized relative to our Sales team of 18, as maintaining strong customer relationships typically requires robust support capacity to match sales growth and ensure customer satisfaction.
#
# 📊 Generating visualization code...
# ✓ Visualization code generated
#
# Generated code length: 788
# Contains 'subplots': False

# %% [markdown]
# ---
#
# # Part 5: Prompt Engineering for Better SQL
#
# The quality of your question determines the quality of the SQL. Let's practice.

# %% [markdown]
# ## Prompt Engineering Strategies
#
# | Strategy | Vague | Specific |
# |----------|-------|----------|
# | **Name columns** | "Show salary info" | "Show first_name, last_name, salary, dept_name" |
# | **Specify aggregation** | "Department salaries" | "Average salary per department" |
# | **Request ordering** | "Show departments" | "Order by average salary descending" |
# | **Indicate JOINs** | "Employee projects" | "Show employees with their assigned project names" |
# | **Handle edge cases** | "Department employees" | "Include departments with zero employees (LEFT JOIN)" |
# | **Set limits** | "High earners" | "Top 10 employees by salary" |
# | **Specify date handling** | "Recent hires" | "Employees hired in 2024 or later" |

# %%
# Watch how prompt quality affects SQL quality

# VAGUE — unpredictable results
vague_sql = engine.get_sql_only("Tell me about employees")
print("VAGUE:")
print(vague_sql)
print()

# SPECIFIC — precise, correct SQL
specific_sql = engine.get_sql_only(
    "Show each employee's full name, department name, job title, salary, "
    "and years of tenure (calculated from hire_date to today). "
    "Only include active employees. Order by tenure descending. Limit to top 15."
)
print("SPECIFIC:")
print(specific_sql)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 4
#       1 # Watch how prompt quality affects SQL quality
#       2
#       3 # VAGUE — unpredictable results
# ----> 4 vague_sql = engine.get_sql_only("Tell me about employees")
#       5 print("VAGUE:")
#       6 print(vague_sql)
#
# File c:\Users\Drizz\Desktop\School Work\sessions\sessions\Text2SQL Project\text2sql_engine.py:705, in Text2SQLEngine.get_sql_only(self, question)
#     703 if not hasattr(self, 'client') or self.client is None:
#     704     return "-- Error: Claude API not configured"
# --> 705 return generate_sql(question, self.client, self.schema_info, self.model)
#
# File c:\Users\Drizz\Desktop\School Work\sessions\sessions\Text2SQL Project\text2sql_engine.py:295, in generate_sql(question, client, schema_info, model, provider)
#     292     sql = response.text
#     293 else:
#     294     # Claude API call
# --> 295     response = client.messages.create(
#     296         model=model,
#     297         max_tokens=2048,
#     298         system="CRITICAL SQL RULE: If your query uses CTEs (Common Table Expressions), it MUST start with the keyword WITH. A query that looks like 'SELECT ... ) SELECT ...' is INVALID - it needs 'WITH cte_name AS (SELECT ...) SELECT ...' instead. Prefer simple queries with inline subqueries over CTEs when possible.",
#     299         messages=[
#     300             {"role": "user", "content": prompt}
#     301         ]
#     302     )
#     303     # Extract the SQL from Claude's response
#     304     sql = response.content[0].text
#
# File c:\Users\Drizz\AppData\Local\Programs\Python\Python313\Lib\site-packages\anthropic\_utils\_utils.py:282, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     280             msg = f"Missing required argument: {quote(missing[0])}"
#     281     raise TypeError(msg)
# --> 282 return func(*args, **kwargs)
#
# File c:\Users\Drizz\AppData\Local\Programs\Python\Python313\Lib\site-packages\anthropic\resources\messages\messages.py:996, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     989 if model in MODELS_TO_WARN_WITH_THINKING_ENABLED and thinking and thinking["type"] == "enabled":
#     990     warnings.warn(
#     991         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#     992         UserWarning,
#     993         stacklevel=3,
#     994     )
# --> 996 return self._post(
#     997     "/v1/messages",
#     998     body=maybe_transform(
#     999         {
#    1000             "max_tokens": max_tokens,
#    1001             "messages": messages,
#    1002             "model": model,
#    1003             "cache_control": cache_control,
#    1004             "container": container,
#    1005             "inference_geo": inference_geo,
#    1006             "metadata": metadata,
#    1007             "output_config": output_config,
#    1008             "service_tier": service_tier,
#    1009             "stop_sequences": stop_sequences,
#    1010             "stream": stream,
#    1011             "system": system,
#    1012             "temperature": temperature,
#    1013             "thinking": thinking,
#    1014             "tool_choice": tool_choice,
#    1015             "tools": tools,
#    1016             "top_k": top_k,
#    1017             "top_p": top_p,
#    1018         },
#    1019         message_create_params.MessageCreateParamsStreaming
#    1020         if stream
#    1021         else message_create_params.MessageCreateParamsNonStreaming,
#    1022     ),
#    1023     options=make_request_options(
#    1024         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1025     ),
#    1026     cast_to=Message,
#    1027     stream=stream or False,
#    1028     stream_cls=Stream[RawMessageStreamEvent],
#    1029 )
#
# File c:\Users\Drizz\AppData\Local\Programs\Python\Python313\Lib\site-packages\anthropic\_base_client.py:1364, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1355     warnings.warn(
#    1356         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1357         "Please pass raw bytes via the `content` parameter instead.",
#    1358         DeprecationWarning,
#    1359         stacklevel=2,
#    1360     )
#    1361 opts = FinalRequestOptions.construct(
#    1362     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1363 )
# -> 1364 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\Drizz\AppData\Local\Programs\Python\Python313\Lib\site-packages\anthropic\_base_client.py:1072, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1070 response = None
#    1071 try:
# -> 1072     response = self._client.send(
#    1073         request,
#    1074         stream=stream or self._should_stream_response_body(request=request),
#    1075         **kwargs,
#    1076     )
#    1077 except httpx.TimeoutException as err:
#    1078     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File c:\Users\Drizz\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File c:\Users\Drizz\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File c:\Users\Drizz\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File c:\Users\Drizz\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File c:\Users\Drizz\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File c:\Users\Drizz\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File c:\Users\Drizz\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File c:\Users\Drizz\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File c:\Users\Drizz\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpcore\_sync\http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File c:\Users\Drizz\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpcore\_sync\http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File c:\Users\Drizz\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpcore\_sync\http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File c:\Users\Drizz\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\Drizz\AppData\Local\Programs\Python\Python313\Lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File c:\Users\Drizz\AppData\Local\Programs\Python\Python313\Lib\ssl.py:1285, in SSLSocket.recv(self, buflen, flags)
#    1281     if flags != 0:
#    1282         raise ValueError(
#    1283             "non-zero flags not allowed in calls to recv() on %s" %
#    1284             self.__class__)
# -> 1285     return self.read(buflen)
#    1286 else:
#    1287     return super().recv(buflen, flags)
#
# File c:\Users\Drizz\AppData\Local\Programs\Python\Python313\Lib\ssl.py:1140, in SSLSocket.read(self, len, buffer)
#    1138         return self._sslobj.read(len, buffer)
#    1139     else:
# -> 1140         return self._sslobj.read(len)
#    1141 except SSLError as x:
#    1142     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Exercise: Rewrite These Vague Prompts
#
# For each vague prompt below, rewrite it to be specific enough to generate correct multi-table SQL.

# %%
# Vague: "Show me raises"
# Improved: Specific version using salary_history + employees + departments
improved_raises = engine.ask('''
Show each employee's salary increases from the salary_history table.
Include: employee first name, last name, department name, old salary, new salary, 
salary increase amount, change date, and reason for the increase.
Join with employees and departments tables to get full context.
Only show increases from the past 2 years.
Order by increase amount (highest to lowest).
Limit to top 20 raises.
''', visualize=False)

print("\n" + "="*80)
print("IMPROVED RAISES QUERY RESULTS")
print("="*80)
if improved_raises['success']:
    print(improved_raises['data'])

# %%
# Vague: "Who's performing well?"
# Improved: Specific version using performance_reviews + employees + job_titles
improved_performance = engine.ask('''
Show employees who received "Exceeds Expectations" or "Outstanding" ratings 
in their most recent performance review (2024).
Include: employee first name, last name, job title name, career level, 
current salary, latest performance rating, and review date.
Join performance_reviews with employees and job_titles tables.
Order by career level (highest first), then by salary (highest first).
Only include active employees.
''', visualize=False)

print("\n" + "="*80)
print("IMPROVED PERFORMANCE QUERY RESULTS")
print("="*80)
if improved_performance['success']:
    print(improved_performance['data'])

# %%
# Vague: "Training status"
# Improved: Specific version using training_records + employees + departments
improved_training = engine.ask('''
Show training completion status by department.
For each department, show:
- Department name
- Total training enrollments
- Number of completed trainings
- Number of in-progress trainings
- Number of planned trainings
- Completion rate (percentage of enrollments that are completed)
Join training_records with employees and departments tables.
Group by department name.
Order by completion rate (highest to lowest).
''', visualize=False)

print("\n" + "="*80)
print("IMPROVED TRAINING QUERY RESULTS")
print("="*80)
if improved_training['success']:
    print(improved_training['data'])

# %%
# Challenge: Write YOUR SQL for this question, then compare with the AI
question = "Find the top 5 managers whose teams have the highest average performance rating in 2024, including the number of direct reports"

# AI version:
print("="*80)
print("AI-GENERATED SQL")
print("="*80)
ai_sql = engine.get_sql_only(question)
print(ai_sql)
print()

# YOUR version:
my_sql = '''
SELECT 
    m.emp_id AS manager_id,
    m.first_name || ' ' || m.last_name AS manager_name,
    COUNT(DISTINCT e.emp_id) AS direct_reports,
    ROUND(AVG(pr.rating), 2) AS avg_team_rating
FROM employees m
JOIN employees e ON e.manager_id = m.emp_id
JOIN performance_reviews pr ON pr.emp_id = e.emp_id
WHERE pr.review_year = 2024
    AND e.employment_status = 'Active'
GROUP BY m.emp_id, m.first_name, m.last_name
ORDER BY avg_team_rating DESC, direct_reports DESC
LIMIT 5;
'''

print("="*80)
print("HUMAN-WRITTEN SQL")
print("="*80)
print(my_sql)
print()

# Compare results
print("="*80)
print("RESULTS COMPARISON")
print("="*80)

print("\nAI Results:")
print("-"*80)
ai_df = engine.execute_custom_sql(ai_sql)
print(ai_df)

print("\n\nYour Results:")
print("-"*80)
# Import the function we need
from db_utils import execute_query
my_df = execute_query(my_sql, conn)
print(my_df)

# Quick comparison
print("\n" + "="*80)
print("COMPARISON SUMMARY")
print("="*80)
print(f"AI returned: {len(ai_df)} rows")
print(f"Human SQL returned: {len(my_df)} rows")

if len(ai_df) > 0 and len(my_df) > 0:
    print("\nTop manager from AI:", ai_df.iloc[0].to_dict())
    print("Top manager from Human SQL:", my_df.iloc[0].to_dict())

# %% [markdown]
# ---
#
# # Part 6: Building the Streamlit Web App
#
# Open `text2sql_app.py` — it has **5 main TODOs** (18-23) and **5 optional extensions** (A-E) for the Streamlit interface.
#
# The app should let users:
# 1. Enter their Gemini API key
# 2. See the database schema in the sidebar
# 3. Type questions in a chat interface
# 4. View SQL, data tables, and auto-generated charts
#
# **Before you start**: Make sure your `text2sql_engine.py` TODOs are complete, because the app depends on it!

# %%
# Verify your text2sql_engine.py is importable
import importlib
import text2sql_engine
importlib.reload(text2sql_engine)

from text2sql_engine import Text2SQLEngine, validate_sql, get_schema_for_prompt

# Quick smoke test
schema = get_schema_for_prompt(conn)
assert len(schema) > 100, "Schema too short — check TODO 1-3"

valid, msg = validate_sql("SELECT 1")
assert valid, "Validator broken — check TODO 4-6"

print("text2sql_engine.py is ready for the Streamlit app!")

# %% [markdown]
# ## Streamlit App TODOs
#
# Open `text2sql_app.py` and complete:
#
# | TODO | What to Build |
# |------|-------------|
# | **18** | Database connection with caching |
# | **19** | Schema display in sidebar |
# | **20** | Session state initialization |
# | **21** | Engine initialization |
# | **22** | Chat history display |
# | **23** | Chat input & query processing |
#
# ### Optional Extensions (do after main TODOs work):
#
# | Extension | What to Add |
# |-----------|-------------|
# | **A** | SQL query history in sidebar |
# | **B** | Custom SQL tab for manual queries |
# | **C** | Conversation memory (context from previous questions) |
# | **D** | CSV download button for results |
# | **E** | Suggested starter questions |

# %%
# Once you've completed the TODOs, run the app:
# Open a terminal and run:
#   streamlit run text2sql_app.py
#
# Or run from the solution:
#   streamlit run solution/text2sql_app.py

print("Ready to run! Use the command above in your terminal.")
print("The app will open in your browser at http://localhost:8501")

# %% [markdown]
# ---
#
# # Part 7: Reflection & Analysis

# %%
# Review your complete session history
engine.show_history()

# %% [markdown]
# ## Reflection Questions
#
# Answer each question thoughtfully (3-5 sentences each):
#
# 1. **Schema Design**: How did the quality of your schema context (TODO 1-3) affect the AI's SQL accuracy? What information was most important to include?
#
# 2. **SQL Safety**: Your validator blocks dangerous queries. Can you think of any SQL patterns that might slip through your current validation? How would you improve it?
#
# 3. **Prompt Engineering**: Which business questions required the most prompt refinement? What makes a question "hard" for the AI to translate to SQL?
#
# 4. **Visualization**: How well did the auto-generated visualizations match the data? When should you write custom visualization code vs. trusting the AI?
#
# 5. **AI vs. Manual SQL**: For which types of questions is AI-generated SQL better than manual SQL? When is manual SQL still preferable?
#
# 6. **Real-World Application**: If TechCorp deployed this tool for all managers, what guardrails would you add beyond your current validator?

# %%
# Your reflections:
reflections = '''
1. Schema Design:
Building a better schema was one of the first priorities, because the AI can only write correct SQL
if it understands the database structure. The default schema was too sparse — adding CREATE TABLE
statements, sample data rows, and explicit foreign key relationships transformed the quality of
generated queries. Of those additions, the foreign key relationships were probably the most critical:
without them the AI had no way to know how to JOIN tables like project_assignments back to employees.
The sample data rows were a close second, because they showed the AI what actual column values looked
like — catching things like date formats and status strings that a bare schema wouldn't reveal.
 
 
2. SQL Safety:
The validator blocks the most obvious attack vectors — dangerous keywords like DROP and DELETE, and
stacked queries via semicolons in the middle of a statement. A few patterns could still slip through:
a carefully crafted subquery that modifies data through a writable CTE on a database that supports
them, or a query that uses ATTACH DATABASE to reach outside the intended SQLite file. The
word-boundary regex is also only as good as the keyword list — something like PRAGMA writable_schema
isn't covered. To improve it, you'd want to add a read-only connection flag at the SQLite level
itself, so no matter what SQL gets through the validator, the database physically cannot be modified.
 
 
3. Prompt Engineering:
Complex multi-table joins and CTEs caused the most trouble — the AI consistently handled simple
aggregation questions on a single table, but when questions required combining salary history with
performance reviews and employees in the same query, the SQL quality degraded. CTEs were a specific
recurring problem: Claude Sonnet would generate syntactically broken CTEs missing the WITH keyword,
requiring multiple rounds of prompt hardening including a system-level instruction and nuclear-option
warnings in the user prompt. What makes a question "hard" for the AI is when the intent requires
inferring unstated business logic — like "latest rating" meaning the most recent row per employee
rather than an average — combined with a multi-table JOIN path it has to figure out from the schema.
 
 
4. Visualization:
Garbage in, garbage out was the lesson here — the more specific the prompt about what the chart
should look like and what columns to return, the better the result. Simple two-column results
(category + value) produced reliable bar charts with no intervention. Questions 8 and 10 required
the most work: Question 8 needed a 100% stacked bar by training category, and the AI kept returning
a grouped bar instead until the column structure was explicitly specified in the prompt. For charts
with specific requirements like stacked bars with percentage labels or scatter plots with trend lines,
writing the visualization manually and disabling visualize=True was the more reliable path than
trusting the AI to generate it.
 
 
5. AI vs. Manual SQL:
For the straightforward analytical queries that make up most day-to-day business intelligence work —
aggregations, rankings, department comparisons — the AI is faster and the output is just as good as
hand-written SQL, assuming the schema context is solid. Where manual SQL still has the edge is in
queries that require precise business logic the AI can't infer, like carefully constructed window
functions or queries that depend on domain knowledge about what the data actually means. That said,
even for complex queries the AI gets you 80-90% of the way there and the remaining refinement is
faster than starting from scratch. The real value isn't replacing SQL knowledge — it's making data
accessible to people who don't have it.
 
 
6. Real-World Application:
The business insights output needed tuning — it leaned heavily toward recommending raises regardless
of context, which would get repetitive fast if every query result came back with the same suggestion.
Beyond that, a production deployment for managers would need role-based access control so a manager
in Engineering can't accidentally query salary data for HR. Audit logging of every query would be
essential for compliance, and a more aggressive SQL validator that operates at the database
connection level rather than just regex matching would close the gaps the current validator leaves
open. Finally, the Gemini free tier would need to be replaced or rate-limited in production —
free API keys cycling out mid-demo is not a good look in front of leadership.
 
'''
print(reflections)

# %% [markdown]
# ---
#
# ## Project Summary
#
# ### What You Built
# - **Schema context builder** that gives AI models the information they need to write correct SQL
# - **SQL safety validator** that blocks dangerous queries (DROP, DELETE, etc.)
# - **Response parser** that extracts clean SQL from AI responses
# - **Text-to-SQL generator** using Google Gemini
# - **LLM-powered auto-visualizer** that generates appropriate charts for query results
# - **Streamlit web app** with a chat interface for non-technical users
#
# ### Key Skills Practiced
# - SQL (SELECT, JOIN, GROUP BY, HAVING, subqueries, CTEs, window functions)
# - Python-SQL integration (sqlite3, pandas)
# - Prompt engineering for code generation
# - AI safety and validation
# - Web app development with Streamlit
# - Data visualization with matplotlib/seaborn
#
# ### What's Next
# - Try deploying your Streamlit app (Streamlit Community Cloud is free)
# - Extend the app with the optional TODOs (memory, custom SQL, export)
# - Apply these patterns to other databases and business domains
